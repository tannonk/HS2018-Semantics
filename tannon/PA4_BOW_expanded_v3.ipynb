# %% [markdown]
# ### this script sets a baseline for relation extraction using frequency-based BOW model
#
# #### add additional features

# %%
import gzip
import numpy as np
import random
import os
import json

from collections import Counter, defaultdict, namedtuple
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_fscore_support, fbeta_score, make_scorer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.model_selection import cross_val_score, StratifiedKFold, KFold
from sklearn.preprocessing import FunctionTransformer,LabelEncoder
import numpy as np
from sklearn.pipeline import FeatureUnion
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction import DictVectorizer

##### additional imports
import networkx as nx
import spacy
nlp = spacy.load('en')

# %%
##################################################################################################
# 1. LOAD DATA
##################################################################################################

PairExample = namedtuple('PairExample',
    'entity_1, entity_2, snippet')
Snippet = namedtuple('Snippet',
    'left, mention_1, middle, mention_2, right, direction')
def load_data(file, verbose=True):
    f = open(file,'r', encoding='utf-8')
    data = []
    labels = []
    for i,line in enumerate(f):
        instance = json.loads(line)
        if i==0:
            if verbose:
                print('json example:')
                print(instance)
        #'relation, entity_1, entity_2, snippet' fileds for each example
        #'left, mention_1, middle, mention_2, right, direction' for each snippet
        instance_tuple = PairExample(instance['entity_1'],instance['entity_2'],[])
        for snippet in instance['snippet']:
            try:
                snippet_tuple = Snippet(snippet['left'],snippet['mention_1'],snippet['middle'],
                                   snippet['mention_2'],snippet['right'],
                                    snippet['direction'])
                instance_tuple.snippet.append(snippet_tuple)
            except:
                print(instance)
        if i==0:
            if verbose:
                print('\nexample transformed as a named tuple:')
                print(instance_tuple)
        data.append(instance_tuple)
        labels.append(instance['relation'])
    return data,labels
    
train_data, train_labels = load_data('../data/train.json.txt')
# Out:
# json example:
# {'relation': 'has_spouse', 'entity_1': 'Judy_Garland', 'entity_2': 'David_Rose', 'snippet': [{'left': 'thirty and his life and career were riding high . In 1941 , shortly after the death of his father , Mercer began an intense affair with nineteen-year-old', 'mention_1': 'Judy Garland', 'middle': 'while she was engaged to composer', 'mention_2': 'David Rose', 'right': '. Garland married Rose to temporarily stop the affair , but the effect on Mercer lingered , adding to the emotional depth of his lyrics . Their affair', 'direction': 'fwd'}]}
#
# example transformed as a named tuple:
# PairExample(entity_1='Judy_Garland', entity_2='David_Rose', snippet=[Snippet(left='thirty and his life and career were riding high . In 1941 , shortly after the death of his father , Mercer began an intense affair with nineteen-year-old', mention_1='Judy Garland', middle='while she was engaged to composer', mention_2='David Rose', right='. Garland married Rose to temporarily stop the affair , but the effect on Mercer lingered , adding to the emotional depth of his lyrics . Their affair', direction='fwd')])

# %%
# Statistics over relations
def print_stats(labels):
    labels_counts = Counter(labels)
    print('{:20s} {:>10s} {:>10s}'.format('', '', 'rel_examples'))
    print('{:20s} {:>10s} {:>10s}'.format('relation', 'examples', '/all_examples'))
    print('{:20s} {:>10s} {:>10s}'.format('--------', '--------', '-------'))
    for k,v in labels_counts.items():
        print('{:20s} {:10d} {:10.2f}'.format(k, v, v /len(labels)))
    print('{:20s} {:>10s} {:>10s}'.format('--------', '--------', '-------'))
    print('{:20s} {:10d} {:10.2f}'.format('Total', len(labels), len(labels) /len(labels)))

print('Train set statistics:')
print_stats(train_labels)
# Out:
# Train set statistics:
#                                 rel_examples
# relation               examples /all_examples
# --------               --------    -------
# has_spouse                 3019       0.31
# author                     2653       0.27
# NO_REL                     2300       0.24
# capital                     510       0.05
# worked_at                  1178       0.12
# --------               --------    -------
# Total                      9660       1.00

# %%
# check that each entity pair is assigned only one relation
pair_dict={}
rel_dict={}
for example, label in zip(train_data,train_labels):
    if (example.entity_1,example.entity_2) not in pair_dict.keys():
        pair_dict[(example.entity_1,example.entity_2)] = [label]
        
    else:
        pair_dict[(example.entity_1,example.entity_2)].append(label)
        print(example.entity_1,example.entity_2,label)
    if label not in rel_dict.keys():
        rel_dict[label] = [example]
    else:
        rel_dict[label].append(example)
print("Done building dictionary")  
    
# example for each relation
for rel in rel_dict.keys():
    ex = rel_dict[rel][0]
    print(rel,ex.entity_1,ex.entity_2)
# Out:
# Done building dictionary
# has_spouse Judy_Garland David_Rose
# author Charlie_and_the_Chocolate_Factory Roald_Dahl
# NO_REL Sichuan Tibet
# capital Andalusia Seville
# worked_at Carl-Henric_Svanberg Ericsson

# %%
# how to reconstruct full context

# ex = train_data[0]
# print(ex)
# print("\n full context:")
# s = ex.snippet[0]
# print(' '.join((s.left, s.mention_1, s.middle, s.mention_2, s.right)))

# %%
# def rebuild_text(ex):
#     rebuilt_ex = []
#     for s in ex.snippet:
#         text = ' '.join((s.left, s.mention_1, s.middle, s.mention_2, s.right))
#         rebuilt_ex.append(text)
#     return rebuilt_ex

# %%
# def build_text_from_snippet(s):
#     text = ' '.join((s.left, s.mention_1, s.middle, s.mention_2, s.right))
#     return text

# %%
# def rebuild_corpus(data):
#     corpus = []
#     for ex in data:
#         corpus.append(rebuild_text(ex)) 
#     return corpus

# %%
# def extract_key_sents(data):
#     key_sents = []
#     for ex in data:
#         m1 = ex.snippet[0].mention_1
#         m2 = ex.snippet[0].mention_2
#         text = build_text_from_snippet(ex.snippet[0])
#         doc = nlp(text)
#         for sent in doc.sents:
# #             print(sent)
#             if m1 in sent.string and m2 in sent.string:
#                 key_sents.append(sent)
#                 continue
                
#     return key_sents

# %%
# key_sents = extract_key_sents(train_data[:100])
# print(type(key_sents[0]))
# for sent in key_sents:
#     for chunk in sent.noun_chunks:
#         print(chunk.label_, chunk.text, chunk.root.text, chunk.root.dep_,
#           chunk.root.head.text)
#     for token in sent: 
#         print(token.text, token.dep_, token.head.text, token.head.pos_,
#               [child for child in token.children])

# %%
def tag_tokens(doc):
    tagged_ex = []
    
    for w in doc:
        if w.orth_ == "m_1" or w.orth_ == "m_2":
            tagged_ex.append(w.orth_)
        else:
            tagged_ex.append(w.pos_)
            
    tagged_ex = " ".join(tagged_ex)
    
    return tagged_ex

# %%
def lemmatize(doc):
    lemmas = []
    
    for w in doc:
        if w.lemma_ == "-PRON-" or w.orth_ == "m_1" or w.orth_ == "m_2":
            lemmas.append(w.orth_)
        else:
            lemmas.append(w.lemma_)
    
    lemmas = " ".join(lemmas)
    
    return lemmas

# %%
##################################################################################################
# 2.1 PERFORM NLP ON CORPUS DATA
##################################################################################################

def perform_nlp(data, verbose=True):
    
    if verbose:
        print("{} instances in data".format(len(data)))
        print("first instance looks like {}".format(data[0]))
        
    c = 0
    docs = []
    for instance in data:
        instance_context = []
        for s in instance.snippet:
            context = nlp(s.left + " m_1 " + s.middle + " m_2 " + s.right)
            instance_context.append(context)
        docs.append(instance_context)
        c += 1
    
        if verbose:
            if c % 1000 == 0:
                print("{} instances processed.".format(c))
        
    if verbose:
        print(len(docs))
        print(docs[0])
        print("Structure of context data is: {}-{}-{}".format(type(docs),
                                                              type(docs[0]),
                                                              type(docs[0][0])
                                                             )
             )
    
    return docs

# %%
def SelectContext(data, verbose=True):
    """BOW feature extraction"""
    only_context_data = []
    for instance in data:
        instance_context = []
        for s in instance.snippet:
            context = s.left + " m_1 " + s.middle + " m_2 " + s.right
            instance_context.append(context)
        only_context_data.append(' '.join(instance_context))
    if verbose:
        print(len(data))
        print(len(only_context_data))
        print(data[0])
        print(only_context_data[0])
    return only_context_data

# %%
def ExractSimpleFeatures(data, verbose=True):
    featurized_data = []
    for instance in data:
        featurized_instance = {'mid_words':'', 'distance':np.inf, 'mid_pos': ''}
        for s in instance.snippet:
            if len(s.middle.split()) < featurized_instance['distance']:
                featurized_instance['mid_words'] = s.middle
                featurized_instance['distance'] = len(s.middle.split())
                featurized_instance['mid_pos'] = ' '.join([w.pos_ for w in nlp(s.middle)])
        featurized_data.append(featurized_instance)
    if verbose:
        print(len(data))
        print(len(featurized_data))
        print(data[0])
        print(featurized_data[0])
        print(featurized_data[1])
    return featurized_data

# %%
def LengthOfEntities(data, verbose=True):
    featurized_data = []
    for instance in data:
        featurized_instance = {
            'entity1_len': len(instance.entity_1.split("_")),
            'entity2_len': len(instance.entity_2.split("_")),
            'combined_len': len(instance.entity_1.split("_")) + len(instance.entity_2.split("_"))
        }
        featurized_data.append(featurized_instance)
    if verbose:
        print(len(data))
        print(len(featurized_data))
        print(data[0])
        print(featurized_data[0])
        print(featurized_data[1])
    return featurized_data

# %%
def FindDepPath(data, verbose=True):
    only_context_data = []
    for instance in data:
        instance_context = []
        for s in instance.snippet:
            context = s.left + " m_1 " + s.middle + " m_2 " + s.right
#             print(context)
            document = nlp(context)
            edges = []
            for token in document:
                # FYI https://spacy.io/docs/api/token
                for child in token.children:
                    edges.append(('{0}-{1}'.format(token.lower_,token.i),
                                  '{0}-{1}'.format(child.lower_,child.i)))

            graph = nx.Graph(edges)
#             print(graph)
            for w in graph:
#                 print(w)
                if "m_1" in w:
                    s = w
                if "m_2" in w:
                    t = w
            
#             print("s: ", len(s), "\t", "t: ", len(t))
#             if len(s) > 7 or len(t) > 7:
#                 pass
#             else:
            try:
                instance_context.append(nx.shortest_path_length(graph, source=s, target=t))
            except nx.NetworkXNoPath:
                instance_context.append(0)
            except nx.NodeNotFound:
                pass
        try:                                
            only_context_data.append(sum(instance_context)/len(instance_context))
        except ZeroDivisionError:
            only_context_data.append(0)
            
    if verbose:
        print(len(data))
        print(len(only_context_data))
        print(data[0])
        print(only_context_data[0])

    return only_context_data

# %%
# test_feat = LengthOfEntities(train_data)
# test_feat = ExractSimpleFeatures(train_data[:10])
# 
# test_feat = FindDepPath(train_data)

# %%
# print(len(test_feat))
# print(test_feat)

# %%
# def SelectTaggedContext(data, verbose=True):
    
#     processed_data = perform_nlp(data)
    
#     tagged_data = []
#     for processed_instance in processed_data:
#         instance_tags = []
#         for doc in processed_instance:  
#             tags = tag_tokens(doc)
#             instance_tags.append(tags)
#         tagged_data.append(' '.join(instance_tags))
#     if verbose:
#         print(len(processed_data))
#         print(len(tagged_data))
#         print(processed_data[0])
#         print(tagged_data[0])
#     return tagged_data

# %%
class SimpleFeaturizer(BaseEstimator, TransformerMixin):
    def __init__(self, featurizer):
        self.featurizers = featurizer

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        return ExractSimpleFeatures(X, verbose=False)

# %%
class EntityLengthFeaturizer(BaseEstimator, TransformerMixin):
    """Extract features from each isntance for DictVectorizer"""
    def __init__(self, featurizer):
        self.featurizers = featurizer
        
    def fit(self, x, y=None):
        return self

    def transform(self, X):
        return LengthOfEntities(X, verbose=False)

# %%
class BowFeaturizer(BaseEstimator, TransformerMixin):
    """BOW featurizer"""
    def __init__(self, featurizer):
        self.featurizers = featurizer
        
    def fit(self, x, y=None):
        return self

    def transform(self, X):
        return SelectContext(X, verbose=False)

# %%
class DependencyPath(BaseEstimator, TransformerMixin):
    """BOW featurizer"""
    def __init__(self, featurizer):
        self.featurizers = featurizer
        
    def fit(self, x, y=None):
        return self

    def transform(self, X):
        return FindDepPath(X, verbose=False)

# %%
# Transform labels to numeric values
le = LabelEncoder()
train_labels_featurized = le.fit_transform(train_labels)

# Fit model one vs rest logistic regression    
# clf = make_pipeline(DictVectorizer(), LogisticRegression())

# clf = make_pipeline(union, LogisticRegression())

# length_pipe = Pipeline([
#   ('ent_length', EntityLengthFeaturizer(LengthOfEntities)),
#   ('ent_length_vectorize', DictVectorizer())
#   ])

# bow_pipe = Pipeline([
#   ('context_data', BowFeaturizer(SelectContext)),
#   ('context_data_vectorize', CountVectorizer())
#   ])

# clf = Pipeline([
#     ('feat_union', FeatureUnion(transformer_list=[
#           ('length_pipeline', length_pipe),
#           ('bow_pipeline', bow_pipe)
#           ])),
#     ('classify', LogisticRegression())
#     ])


length_pipe = make_pipeline(EntityLengthFeaturizer(LengthOfEntities), DictVectorizer())

# bow_pipe = make_pipeline(BowFeaturizer(SelectContext), CountVectorizer(ngram_range=(1,3)))
bow_pipe = make_pipeline(BowFeaturizer(SelectContext), CountVectorizer())

simple_pipe = make_pipeline(SimpleFeaturizer(ExractSimpleFeatures), DictVectorizer())

# dep_pipe = make_pipeline(DependencyPath(FindDepPath))

clf = make_pipeline(FeatureUnion(transformer_list=[
    ('length_pipeline', length_pipe),
    ('bow_pipeline', bow_pipe),
    ('simple_pipeline', simple_pipe),
    ('dependency_pipeline', DependencyPath(FindDepPath))]),
    LogisticRegression())

# %%
##################################################################################################
# 3. TRAIN CLASSIFIER AND EVALUATE (CV)
##################################################################################################

def print_statistics_header():
    print('{:20s} {:>10s} {:>10s} {:>10s} {:>10s}'.format(
        'relation', 'precision', 'recall', 'f-score', 'support'))
    print('{:20s} {:>10s} {:>10s} {:>10s} {:>10s}'.format(
        '-' * 18, '-' * 9, '-' * 9, '-' * 9, '-' * 9))

def print_statistics_row(rel, result):
    print('{:20s} {:10.3f} {:10.3f} {:10.3f} {:10d}'.format(rel, *result))

def print_statistics_footer(avg_result):
    print('{:20s} {:>10s} {:>10s} {:>10s} {:>10s}'.format(
        '-' * 18, '-' * 9, '-' * 9, '-' * 9, '-' * 9))
    print('{:20s} {:10.3f} {:10.3f} {:10.3f} {:10d}'.format('macro-average', *avg_result))

def macro_average_results(results):
    avg_result = [np.average([r[i] for r in results.values()]) for i in range(3)]
    avg_result.append(np.sum([r[3] for r in results.values()]))
    return avg_result

def average_results(results):
    avg_result = [np.average([r[i] for r in results]) for i in range(3)]
    avg_result.append(np.sum([r[3] for r in results]))
    return avg_result
    
def evaluateCV(classifier, label_encoder, X, y, verbose=True):
    """
    classifier: clf - pipeline with CountVevtorizer and Logistic regression
    label_encoder: le - label encoder
    X: train data featurized
    y: train labels featurized
    """
    results = {}
    for rel in le.classes_:
#         print(rel)
        results[rel] = []
    if verbose:
        print_statistics_header()
        kfold = StratifiedKFold(n_splits = 5, shuffle=True, random_state=0) 
        for train_index, test_index in kfold.split(X, y):
            #print("TRAIN:", train_index, "TEST:", test_index)
            X_train, X_test = [X[i] for i in train_index], [X[i] for i in test_index]
            y_train, y_test = [y[i] for i in train_index], [y[i] for i in test_index]
            clf.fit(X_train, y_train)
            pred_labels = classifier.predict(X_test)
            stats = precision_recall_fscore_support(y_test, pred_labels, beta=0.5)
            #print(stats)
            for rel in label_encoder.classes_:
                rel_id = label_encoder.transform([rel])[0]
#             print(rel_id,rel)
                stats_rel = [stat[rel_id] for stat in stats]
                results[rel].append(stats_rel)
        for rel in label_encoder.classes_:
            results[rel] = average_results(results[rel])
            if verbose:
                print_statistics_row(rel, results[rel])
    avg_result = macro_average_results(results)
    if verbose:
        print_statistics_footer(avg_result)
    return avg_result[2]  # return f_0.5 score as summary statistic

# %%
evaluateCV(clf, le, train_data, train_labels_featurized)
# Out:
# relation              precision     recall    f-score    support
# ------------------    ---------  ---------  ---------  ---------
# thirty-0
# and-1
# life-3
# his-2
# and-4
# career-5
# riding-7
# were-6
# high-8
# .-9
# in-10
# 1941-11
# after-14
# shortly-13
# death-16
# the-15
# of-17
# father-19
# his-18
# began-22
# ,-12
# ,-20
# mercer-21
# affair-25
# engaged-36
# .-40
# an-23
# intense-24
# with-26
# m_1-32
# year-29
# nineteen-27
# --28
# old-31
# --30
# while-33
# she-34
# was-35
# to-37
# m_2-39
# composer-38
# married-42
# garland-41
# rose-43
# stop-46
# ,-49
# but-50
# lingered-55
# to-44
# temporarily-45
# affair-48
# the-47
# effect-52
# the-51
# on-53
# mercer-54
# ,-56
# adding-57
# .-65
# to-58
# depth-61
# the-59
# emotional-60
# of-62
# lyrics-64
# his-63
# affair-67
# their-66
# activity-1
# latest-0
# summary-8
# wikia-7
# sweet-4
# --5
# treat-6
# 4-2
# other-3
# of-9
# and-15
# factory-18
# charlie-14
# adventure-12
# sweet-11
# a-10
# edit-13
# the-16
# chocolate-17
# is-19
# adaptation-23
# .-30
# a-20
# 2005-21
# film-22
# of-24
# by-28
# m_1-27
# the-25
# 1964-26
# m_2-29
# directed-31
# by-32
# burton-34
# tim-33
# film-37
# the-36
# stars-38
# ,-35
# highmore-40
# as-41
# .-50
# freddie-39
# bucket-43
# charlie-42
# and-44
# depp-46
# as-47
# johnny-45
# wonka-49
# willy-48
# storyline-52
# the-51
# concerns-53
# a-54
# actors-2
# screen-1
# award-4
# guild-3
# nomination-5
# a-0
# .-6
# in-7
# 2005-8
# played-11
# ,-9
# he-10
# part-13
# (-27
# adapted-28
# )-33
# .-34
# the-12
# of-14
# bucket-20
# working-18
# hard-16
# --17
# the-15
# charlie-19
# in-21
# charlie-22
# and-23
# factory-26
# the-24
# chocolate-25
# from-29
# by-31
# m_1-30
# m_2-32
# recommended-38
# he-35
# was-36
# reportedly-37
# for-39
# role-41
# the-40
# by-42
# star-46
# film-44
# the-43
# 's-45
# depp-48
# johnny-47
# ,-49
# starred-51
# who-50
# in-52
# and-55
# impressed-57
# neverland-54
# finding-53
# was-56
# by-58
# the-59
# actors-0
# scheduled-3
# .-11
# who-1
# were-2
# make-6
# to-4
# not-5
# it-7
# on-8
# saturday-10
# a-9
# episode-14
# the-13
# 's-15
# title-16
# both-12
# and-17
# episode-19
# the-18
# itself-20
# based-22
# is-21
# off-23
# ,-26
# ``-27
# m_1-28
# .-32
# novel-25
# the-24
# ``-29
# by-30
# m_2-31
# during-33
# episode-35
# the-34
# adventurers-40
# the-37
# final-38
# seven-39
# eliminated-42
# ,-36
# are-41
# from-43
# at-46
# .-52
# challenge-45
# the-44
# places-48
# various-47
# in-49
# factory-51
# the-50
# falls-54
# leshawna-53
# into-55
# river-58
# a-56
# chocolate-57
# into-0
# revelation-5
# a-3
# factory-2
# the-1
# surprising-4
# about-6
# masterpiece-9
# dahl-7
# 's-8
# researching-11
# while-10
# adventure-15
# my-12
# first-13
# mg-14
# took-18
# ,-16
# i-17
# look-22
# .-46
# close-21
# really-20
# a-19
# at-23
# structure-25
# the-24
# of-26
# m_1-27
# ,-28
# inspired-33
# which-29
# m_2-30
# was-31
# apparently-32
# right-35
# to-34
# by-36
# as-40
# experiences-39
# his-37
# childhood-38
# tester-43
# a-41
# chocolate-42
# at-44
# school-45
# tell-50
# i-47
# ca-48
# n't-49
# you-51
# was-55
# surprised-53
# how-52
# i-54
# find-57
# to-56
# mark-0
# work-2
# as-3
# .-9
# this-1
# show-5
# a-4
# of-6
# promise-8
# great-7
# james-10
# and-11
# peach-14
# the-12
# giant-13
# was-15
# one-16
# ,-22
# so-25
# .-35
# of-17
# books-21
# my-18
# favorite-19
# childhood-20
# even-23
# more-24
# than-26
# m_1-27
# ,-28
# is-30
# which-29
# also-31
# by-32
# author-33
# m_2-34
# was-37
# i-36
# excited-38
# heard-52
# hear-40
# to-39
# about-41
# ,-48
# version-44
# a-42
# musical-43
# in-45
# works-47
# the-46
# particularly-49
# when-50
# i-51
# folks-55
# the-54
# at-56
# ,-58
# one-59
# pilobolus-57
# of-60
# my-61
# introduced-0
# .-1
# caterpillar-5
# the-2
# very-3
# hungry-4
# and-6
# plum-10
# each-7
# peach-8
# pear-9
# were-11
# ,-12
# and-13
# remain-14
# .-19
# favourites-18
# children-16
# firm-15
# 's-17
# augmented-22
# puffin-20
# further-21
# position-24
# with-25
# by-30
# its-23
# hits-26
# as-28
# such-27
# m_1-29
# m_2-31
# and-32
# watership-33
# down-34
# by-35
# .-38
# adams-37
# richard-36
# 1-40
# [-39
# ]-41
# 1980s-43
# the-42
# saw-44
# taking-46
# puffin-45
# advantage-48
# with-52
# ,-58
# forming-59
# full-47
# of-49
# culture-51
# popular-50
# publishing-57
# tie-54
# --55
# in-56
# film-53
# links-61
# close-60
# punjab-0
# .-1
# was-3
# he-2
# also-4
# voice-6
# and-16
# provided-18
# .-29
# the-5
# of-7
# in-11
# ray-8
# in-9
# bear-10
# house-15
# the-12
# big-13
# blue-14
# also-17
# narration-19
# for-20
# version-24
# burton-22
# tim-21
# 's-23
# of-25
# m_2-28
# m_1-26
# 's-27
# 11-31
# [-30
# ]-32
# reprised-34
# he-33
# role-36
# as-37
# his-35
# spokesman-41
# 7-39
# up-40
# the-38
# in-42
# finale-46
# season-45
# 2011-44
# the-43
# of-47
# apprentice-50
# the-48
# celebrity-49
# ,-51
# appeared-54
# where-52
# he-53
# as-55
# add-1
# to-0
# quarter-3
# and-11
# felt-13
# a-2
# of-4
# drop-6
# a-5
# of-7
# oil-10
# lemon-8
# essential-9
# i-12
# like-14
# beauregarde-16
# violet-15
# (-17
# girl-19
# the-18
# chews-21
# who-20
# gum-22
# day-24
# in-25
# all-23
# m_1-26
# children-29
# ’-30
# books-32
# m_2-33
# followed-42
# .-59
# )-34
# taste-37
# the-36
# of-38
# dragonwell-40
# the-39
# as-35
# was-41
# closely-43
# by-44
# and-47
# came-50
# peppermint-46
# the-45
# lemon-49
# the-48
# through-51
# on-52
# at-56
# taste-54
# the-53
# right-55
# end-58
# the-57
# charlie-2
# chocolate-0
# factory-1
# and-3
# factory-6
# the-4
# chocolate-5
# is-7
# film-11
# .-20
# a-8
# 2005-9
# fantasy-10
# directed-12
# by-13
# and-16
# starring-17
# burton-15
# tim-14
# depp-19
# johnny-18
# based-21
# on-22
# childre-26
# the-23
# 1964-24
# m_1-25
# m_2-27
# film-30
# the-29
# stars-32
# ,-28
# also-31
# highmore-34
# as-35
# and-38
# is-39
# .-47
# freddie-33
# bucket-37
# charlie-36
# adaptation-43
# the-40
# second-41
# film-42
# of-44
# book-46
# the-45
# is-49
# it-48
# also-50
# film-53
# the-51
# second-52
# from-0
# !-1
# )-2
# west-6
# master-3
# mime-4
# wild-5
# ,-7
# swords-9
# legendary-8
# wait-11
# but-10
# !-12
# 's-14
# there-13
# more-15
# !-16
# have-18
# i-17
# reason-19
# s-41
# )-42
# .-43
# ...-44
# ...-45
# ...-46
# believe-21
# to-20
# based-28
# island-25
# the-23
# next-24
# that-22
# will-26
# be-27
# on-29
# book-33
# m_1-30
# 's-31
# 1964-32
# m_2-34
# (-35
# or-36
# one-37
# of-38
# movie-40
# the-39
# wait-48
# hey-47
# !-49
# come-50
# back-51
# !-52
# have-54
# i-53
# proof-55
# !-56
# look-57
# here-58
# ...-59
# aanndd-60
# ...-61
# da-64
# ta-62
# --63
# !-65
# get-68
# do-66
# n't-67
# it-69
# ?-70
# okay-71
# ...-72
# hollow-0
# ,-1
# or-2
# filled-3
# .-9
# with-4
# sweets-6
# other-5
# or-7
# fondant-8
# books-10
# and-11
# film-12
# chocolate-13
# been-15
# has-14
# center-17
# .-25
# the-16
# of-18
# adaptations-24
# book-21
# successful-20
# and-22
# film-23
# several-19
# in-26
# 1964-27
# published-30
# ,-28
# m_1-29
# children-32
# ’-33
# s-34
# novel-35
# .-38
# a-31
# titled-36
# m_2-37
# centers-41
# the-39
# novel-40
# on-42
# boy-45
# a-43
# poor-44
# named-46
# takes-50
# bucket-48
# charlie-47
# who-49
# tour-52
# through-53
# a-51
# factory-57
# the-54
# greatest-55
# chocolate-56
# in-58
# ,-61
# owned-62
# world-60
# the-59
# by-63
# item-0
# :-1
# hide-3
# gnauga-2
# chance-7
# )-8
# %-6
# 10.1-5
# (-4
# gain-11
# *-9
# you-10
# 9-12
# substat-14
# .-16
# <-13
# >-15
# occurs-17
# at-18
# .-20
# thugnderdome-19
# strike-23
# references-21
# ``-22
# that-24
# .-25
# reverse-26
# it-27
# .-28
# ''-29
# is-30
# reference-32
# .-50
# a-31
# to-33
# book-39
# m_1-34
# 's-35
# children-37
# 1964-36
# 's-38
# ,-40
# m_2-41
# reversed-46
# wonka-44
# willy-43
# where-42
# occasionally-45
# meant-49
# what-47
# he-48
# gnauga-52
# the-51
# itself-53
# refers-54
# to-55
# ,-60
# naugahyde-56
# and-57
# mascot-59
# its-58
# naugahyde-61
# itself-62
# being-63
# pleather-64
# .-65
# naugahyde-67
# early-66
# marketing-68
# road-3
# 8300-0
# pleasant-1
# plains-2
# in-4
# .-6
# towson-5
# goers-9
# theater-7
# --8
# invited-11
# are-10
# enjoy-13
# based-29
# .-38
# to-12
# story-16
# the-14
# sweet-15
# of-17
# willy-18
# ,-19
# bucket-21
# ,-27
# charlie-20
# ,-22
# and-23
# loompas-26
# the-24
# oompa-25
# all-28
# on-30
# novel-36
# m_1-31
# 's-32
# children-34
# 1964-33
# 's-35
# m_2-37
# contact-39
# :-40
# jasper-42
# stephen-41
# or-43
# partilla-45
# ,-46
# school-50
# 410.887.3549-52
# monday-53
# maureen-44
# pleasant-47
# plains-48
# elementary-49
# ,-51
# ,-54
# april-55
# 30-56
# red-57
# ,-58
# white-59
# ,-60
# and-61
# blue-62
# prevails-63
# at-64
# school-68
# the-65
# kingsville-66
# elementary-67
# candies-1
# chocolate-0
# ,-2
# variants-4
# .-9
# usually-3
# of-5
# fare-8
# their-6
# standard-7
# books-10
# and-11
# film-12
# chocolate-13
# been-15
# has-14
# center-17
# .-25
# the-16
# of-18
# adaptations-24
# book-21
# successful-20
# and-22
# film-23
# several-19
# in-26
# 1964-27
# published-30
# ,-28
# m_1-29
# novel-34
# .-37
# children-32
# a-31
# 's-33
# titled-35
# m_2-36
# centers-40
# the-38
# novel-39
# on-41
# boy-44
# a-42
# poor-43
# named-45
# takes-49
# bucket-47
# charlie-46
# who-48
# tour-51
# through-52
# a-50
# factory-56
# the-53
# greatest-54
# chocolate-55
# in-57
# ,-60
# owned-61
# world-59
# the-58
# by-62
# contact-0
# email2-1
# url-3
# contact-2
# subscribe-4
# to-5
# blog-6
# remember-7
# photo-10
# chocolate-19
# my-8
# info-9
# of-11
# ``-12
# mleczko-14
# ptasie-13
# ,-15
# ''-16
# a-17
# polish-18
# ~-20
# commons-22
# wikimedia-21
# satirical-25
# the-23
# most-24
# of-26
# novels-29
# all-27
# m_1-28
# for-30
# children-31
# are-32
# m_2-33
# and-34
# sequel-36
# .-44
# its-35
# ,-37
# charlie-38
# and-39
# elevator-43
# the-40
# great-41
# glass-42
# in-45
# addition-46
# to-47
# scrutiny-50
# his-48
# intense-49
# of-51
# issues-54
# many-52
# prevalent-53
# in-55
# society-56
# author-59
# the-58
# completes-60
# ,-57
# scintillating-62
# his-61
# sauses-0
# etc-1
# .-2
# page-3
# 547-4
# '-5
# ...-6
# engulfed-7
# .-17
# '-18
# in-8
# mayonnaise-16
# smelling-15
# sour-13
# --14
# thick-9
# ,-10
# slick-11
# ,-12
# kit-21
# the-19
# whole-20
# 's-22
# experience-23
# in-24
# factory-27
# the-25
# mayonnaise-26
# is-28
# reminiscent-31
# .-36
# much-30
# very-29
# to-32
# m_2-35
# m_1-33
# 's-34
# cazzo-37
# ,-38
# cretino-39
# .-46
# ''-47
# literally-40
# ,-41
# ``-42
# cretin-45
# dick-43
# ,-44
# is-49
# cazzo-48
# obscenity-54
# .-60
# a-50
# common-51
# italian-52
# interjectionary-53
# ,-55
# in-57
# especially-56
# south-59
# the-58
# cretino-64
# ``-61
# cazzo-62
# ,-63
# ,-65
# ''-66
# is-67
# akin-68
# to-69
# someone-70
# saying-71
# ,-72
# ``-73
# well-74
# boy-2
# a-0
# poor-1
# wins-4
# .-18
# who-3
# opportunity-6
# the-5
# tour-8
# to-7
# factory-15
# eccentric-11
# most-10
# and-12
# wonderful-13
# the-9
# candy-14
# of-16
# all-17
# directed-19
# by-20
# .-23
# stuart-22
# mel-21
# written-24
# by-25
# .-33
# m_1-26
# ,-27
# based-28
# on-29
# book-31
# his-30
# m_2-32
# 's-35
# it-34
# 's-37
# !-52
# everybody-36
# factory-49
# --39
# non-38
# pollutionary-40
# ,-41
# anti-42
# --43
# ,-45
# institutionary-44
# pro-46
# --47
# confectionery-48
# of-50
# fun-51
# contents-54
# taglines-53
# 1-55
# wonka-57
# willy-56
# 2-58
# loompas-60
# oompa-59
# 3-61
# dialogue-62
# cast-66
# taglines-64
# 4-63
# 5-65
# 6-67
# external-68
# were-1
# children-0
# grateful-2
# .-16
# be-4
# to-3
# able-5
# stay-7
# to-6
# together-8
# with-9
# '-12
# as-13
# edwards-11
# the-10
# children-15
# their-14
# patricia-19
# edit-18
# neal-20
# trivia-17
# played-22
# who-21
# julia-23
# married-25
# was-24
# to-26
# .-38
# ?-39
# m_1-27
# ,-28
# author-29
# of-30
# books-37
# m_2-31
# and-32
# other-33
# children-35
# famous-34
# 's-36
# told-42
# what-40
# julia-41
# alden-44
# read-46
# reverend-43
# to-45
# at-47
# funeral-49
# her-48
# read-51
# was-50
# at-52
# .-57
# ?-58
# funeral-56
# landon-54
# michael-53
# 's-55
# used-0
# .-1
# few-5
# a-4
# times-6
# room-9
# an-7
# ames-8
# shown-13
# however-2
# ,-3
# has-10
# also-11
# been-12
# explicitly-14
# .-15
# room-18
# an-16
# ames-17
# depicted-20
# is-19
# in-21
# .-31
# adaptation-25
# the-22
# 1971-23
# film-24
# of-26
# novel-29
# the-27
# m_1-28
# m_2-30
# show-35
# the-32
# 1960s-33
# television-34
# voyage-36
# to-37
# bottom-39
# the-38
# of-40
# sea-42
# the-41
# used-43
# room-46
# in-47
# show-51
# ,-57
# an-44
# ames-45
# episode-49
# one-48
# to-50
# ,-52
# than-54
# declare-56
# rather-53
# just-55
# in-0
# touch-1
# .-2
# letters-4
# follow-3
# of-5
# ...-7
# note-6
# |-9
# rss-8
# email-10
# |-11
# |-14
# tumblr-13
# twitter-12
# monday-16
# facebook-15
# ,-17
# october-19
# 12-18
# 2009-20
# unrest-21
# at-22
# factory-25
# the-23
# chocolate-24
# 1964-26
# m_1-28
# 's-29
# m_2-30
# released-32
# :-27
# is-31
# loompa-36
# oompa-35
# characters-37
# its-34
# depicted-38
# ,-33
# as-39
# tribe-43
# a-40
# 3,000-41
# strong-42
# of-44
# ,-50
# imported-51
# pygmies-46
# black-45
# (-47
# pic-48
# )-49
# by-52
# wonka-54
# willy-53
# from-55
# african-57
# the-56
# places-1
# various-0
# claim-2
# title-4
# .-25
# the-3
# ,-5
# as-7
# such-6
# parts-8
# of-9
# in-12
# ,-16
# including-17
# kham-11
# southern-10
# province-15
# northwestern-13
# yunnan-14
# destinations-20
# the-18
# tourist-19
# of-21
# lijiang-22
# and-23
# zhongdian-24
# places-26
# like-27
# m_1-28
# and-29
# m_2-30
# claim-32
# also-31
# was-38
# .-42
# la-37
# the-33
# real-34
# shangri-35
# --36
# in-39
# territory-41
# its-40
# in-43
# 2001-44
# region-48
# tibet-46
# autonomous-47
# put-49
# ,-45
# forward-50
# proposal-52
# la-61
# a-51
# optimise-57
# regions-56
# the-54
# three-55
# that-53
# all-58
# shangri-59
# --60
# research-1
# more-0
# .-2
# taxonomists-4
# some-3
# group-5
# nosed-8
# snub-6
# --7
# monkeys-9
# with-11
# .-15
# together-10
# genus-14
# the-12
# pygathrix-13
# nosed-18
# snub-16
# --17
# monkeys-19
# live-20
# in-21
# ,-23
# with-24
# .-49
# asia-22
# range-26
# a-25
# covering-27
# china-29
# southern-28
# (-30
# m_1-32
# especially-31
# ,-33
# m_2-34
# )-40
# as-43
# part-46
# ,-35
# yunnan-36
# ,-37
# and-38
# guizhou-39
# as-41
# well-42
# the-44
# northern-45
# of-47
# vietnam-48
# 09/03/16-50
# 08:11:15-51
# from-52
# archive-61
# radarchive-53
# (-54
# from-56
# )-58
# originally-55
# shelbot-57
# 153-59
# notes-60
# rounds-1
# full-0
# believes-4
# ,-2
# zoe-3
# aimed-8
# .-12
# she-5
# would-6
# have-7
# it-9
# at-10
# daniel-11
# begs-14
# she-13
# lacy-15
# help-17
# .-27
# to-16
# escape-19
# soon-20
# ,-21
# does-24
# her-18
# before-22
# she-23
# rash-26
# something-25
# notes-28
# is-30
# .-38
# m_1-29
# work-35
# --33
# non-32
# fiction-34
# a-31
# by-36
# m_2-37
# among-39
# themes-41
# its-40
# are-42
# tendency-45
# ,-50
# and-51
# override-70
# man-43
# 's-44
# towards-46
# destruction-49
# self-47
# --48
# primitive-55
# more-54
# parts-56
# the-53
# of-57
# ghost-63
# brain-59
# the-58
# (-60
# the-61
# ``-62
# in-64
# ''-67
# )-68
# machine-66
# the-65
# that-52
# can-69
# ghost-1
# their-0
# retain-4
# ,-2
# they-3
# humanity-6
# .-9
# their-5
# and-7
# individuality-8
# concept-11
# the-10
# of-12
# ghost-14
# the-13
# borrowed-16
# was-15
# by-17
# from-20
# ,-25
# ``-26
# m_1-27
# .-31
# shirow-19
# masamune-18
# essay-22
# an-21
# on-23
# structuralism-24
# ``-28
# by-29
# m_2-30
# title-33
# the-32
# used-42
# ,-47
# mock-51
# ghost-35
# the-34
# in-36
# machine-38
# the-37
# itself-39
# was-40
# originally-41
# by-43
# philosopher-46
# an-44
# english-45
# ryle-49
# gilbert-48
# to-50
# paradox-53
# the-52
# of-54
# conventional-55
# experience-0
# over-1
# .-6
# series-3
# a-2
# of-4
# blogposts-5
# post-8
# this-7
# shares-9
# principle-12
# .-15
# the-10
# underlying-11
# of-13
# holocracy-14
# holocracy-16
# ?-17
# roots-19
# its-18
# stem-20
# from-21
# .-57
# observation-23
# an-22
# from-24
# m_1-28
# psychologist-25
# and-26
# philosopher-27
# ,-29
# spoke-39
# in-32
# book-34
# his-33
# m_2-35
# (-36
# 1967-37
# )-38
# who-30
# ,-31
# about-40
# and-49
# are-50
# are-52
# holons-41
# ,-42
# units-44
# individual-43
# whole-46
# that-45
# unto-47
# themselves-48
# also-51
# part-53
# of-54
# whole-56
# the-55
# said-59
# simply-58
# be-63
# business-61
# a-60
# can-62
# koestler-3
# search-1
# arthur-2
# properties-6
# |-0
# some-4
# general-5
# of-7
# 1969-18
# from-20
# order-13
# regulating-10
# self-8
# --9
# open-11
# hierarchic-12
# (-14
# soho-15
# )-16
# (-17
# )-19
# note-22
# panarchy-21
# idea-24
# the-23
# of-25
# holon-28
# the-26
# ``-27
# ''-29
# introduced-31
# was-30
# by-32
# in-34
# and-39
# presented-41
# .-66
# m_1-33
# m_2-35
# (-36
# 1967-37
# )-38
# was-40
# again-42
# at-43
# in-50
# symposium-46
# the-44
# alpbach-45
# (-47
# 1968-48
# )-49
# paper-52
# a-51
# titled-53
# :-54
# ``-55
# concept-62
# beyond-56
# atomism-57
# and-58
# holism-59
# --60
# the-61
# of-63
# holon-65
# the-64
# application-0
# of-1
# to-4
# ,-13
# but-14
# luhmann-17
# .-23
# beer-3
# stafford-2
# cybernetics-8
# order-7
# second-5
# --6
# and-9
# theory-12
# viable-10
# system-11
# also-15
# niklas-16
# in-18
# theory-22
# systems-21
# social-20
# his-19
# word-25
# the-24
# coined-27
# was-26
# by-28
# in-30
# .-34
# m_1-29
# book-32
# his-31
# m_2-33
# compelled-37
# koestler-35
# was-36
# by-38
# in-41
# .-48
# observations-40
# two-39
# proposing-42
# notion-44
# the-43
# of-45
# holon-47
# the-46
# observation-51
# the-49
# first-50
# influenced-53
# was-52
# by-54
# .-60
# a-59
# prize-56
# nobel-55
# winner-57
# herbert-58
# function-1
# to-0
# in-2
# ,-7
# but-8
# are-14
# parallel-3
# with-4
# action-6
# physical-5
# means-11
# their-10
# of-12
# interaction-13
# where-9
# unknown-15
# or-16
# ,-17
# speculative-21
# .-22
# best-19
# at-18
# ,-20
# argument-24
# the-23
# developed-27
# was-25
# further-26
# by-28
# .-35
# m_1-29
# (-30
# m_2-31
# )-34
# ,-32
# 1967-33
# examples-37
# such-36
# imply-38
# designed-49
# ignorance-40
# of-41
# kind-43
# one-42
# or-44
# another-45
# that-39
# is-46
# effectively-47
# ``-48
# into-50
# in-55
# models-53
# ''-51
# global-52
# ---54
# manner-58
# a-56
# questionable-57
# of-59
# which-60
# greek-0
# :-1
# ,-2
# form-5
# holon-3
# neuter-4
# of-6
# whole-9
# a-7
# ``-8
# ''-10
# is-11
# something-12
# .-21
# is-14
# that-13
# simultaneously-15
# whole-17
# a-16
# and-18
# part-20
# a-19
# word-23
# the-22
# coined-25
# was-24
# by-26
# in-28
# .-38
# m_1-27
# book-30
# his-29
# m_2-31
# 1967-33
# p.-35
# )-37
# (-32
# ,-34
# 48-36
# compelled-41
# koestler-39
# was-40
# by-42
# in-45
# .-52
# observations-44
# two-43
# proposing-46
# notion-48
# the-47
# of-49
# holon-51
# the-50
# observation-55
# the-53
# first-54
# influenced-57
# was-56
# by-58
# winner-61
# prize-60
# nobel-59
# swell-0
# .-1
# 2005/02/15-2
# :-3
# redux-5
# rabbit-4
# ,-6
# updike-8
# :-9
# john-7
# liked-11
# i-10
# it-12
# better-13
# .-21
# than-14
# book-17
# the-15
# first-16
# in-18
# series-20
# this-19
# stuff-25
# definitely-22
# some-23
# good-24
# here-26
# .-27
# m_1-30
# :-29
# ,-31
# m_2-32
# :-33
# interesting-34
# and-35
# worth-36
# reading-37
# .-38
# did-41
# do-39
# /-40
# class-45
# most-42
# middle-43
# --44
# americans-46
# live-48
# really-47
# like-49
# ?-51
# this-50
# 2005/10/22-52
# :-53
# bound-55
# zuckerman-54
# ,-56
# roth-58
# :-59
# philip-57
# good-61
# more-60
# stuff-62
# .-63
# 2005/10/18-64
# :-65
# lila-66
# magnate-2
# american-0
# business-1
# ,-3
# philanthropist-4
# .-17
# ,-5
# author-6
# ,-7
# and-8
# is-9
# chairman-10
# of-11
# microsoft-12
# ,-13
# company-16
# the-14
# software-15
# born-20
# gates-18
# was-19
# in-21
# ,-25
# to-26
# .-41
# seattle-22
# ,-23
# washington-24
# m_1-27
# and-28
# m_2-29
# ,-30
# of-31
# descent-40
# english-32
# ,-33
# german-34
# ,-35
# and-36
# irish-39
# scotch-37
# --38
# family-43
# his-42
# was-44
# class-47
# upper-45
# middle-46
# father-50
# his-49
# was-51
# ;-48
# lawyer-54
# a-52
# prominent-53
# mother-57
# his-56
# served-58
# ,-55
# on-59
# slim-0
# 's-1
# wealth-2
# until-3
# .-6
# year-5
# next-4
# 12-8
# [-7
# type=-12
# ]-9
# <-10
# script-11
# ''-13
# javascript-16
# text-14
# /-15
# ''-17
# >-18
# //-19
# life-24
# early-23
# iii-28
# william-25
# henry-26
# gates-27
# born-30
# <-20
# /script-21
# >-22
# was-29
# in-31
# ,-35
# to-36
# .-45
# seattle-32
# ,-33
# washington-34
# m_1-37
# and-43
# m_2-44
# (-38
# sr-40
# .-41
# )-42
# now-39
# family-47
# his-46
# was-48
# wealthy-49
# father-52
# his-51
# was-53
# ;-50
# lawyer-56
# a-54
# prominent-55
# mother-59
# his-58
# served-60
# ,-57
# on-61
# the-71
# board-63
# the-62
# of-64
# for-66
# directors-65
# bank-69
# first-67
# interstate-68
# and-70
# philanthropy-0
# recognition-2
# bibliography-6
# 3.2-1
# investments-4
# 3.3-3
# 4-5
# notes-8
# 5-7
# 6-9
# references-10
# links-13
# 7-11
# external-12
# life-15
# early-14
# born-18
# gates-16
# was-17
# in-19
# ,-23
# to-24
# .-28
# seattle-20
# ,-21
# washington-22
# m_1-25
# and-26
# m_2-27
# family-30
# his-29
# was-31
# class-34
# upper-32
# middle-33
# father-37
# his-36
# was-38
# ;-35
# lawyer-41
# a-39
# prominent-40
# mother-44
# his-43
# served-45
# ,-42
# on-46
# board-48
# the-47
# of-49
# for-51
# directors-50
# bancsystem-54
# interstate-53
# first-52
# mexico-1
# new-0
# police-2
# in-3
# after-5
# 1977-4
# violation-8
# a-6
# traffic-7
# (-9
# details-10
# of-11
# which-12
# lost-15
# have-13
# been-14
# over-16
# )-18
# .-19
# time-17
# born-22
# gates-20
# was-21
# in-23
# ,-27
# to-28
# .-32
# seattle-24
# ,-25
# washington-26
# m_1-29
# and-30
# m_2-31
# parents-34
# his-33
# are-35
# of-36
# .-46
# descent-45
# english-37
# ,-38
# german-39
# ,-40
# and-41
# irish-44
# scots-42
# --43
# 13-48
# [-47
# ]-49
# 14-51
# [-50
# ]-52
# father-54
# his-53
# was-55
# lawyer-58
# ,-59
# and-60
# his-61
# a-56
# prominent-57
# programs-3
# scientific-1
# research-2
# through-4
# bill-6
# the-5
# &-7
# foundation-10
# melinda-8
# gates-9
# established-12
# and-0
# ,-11
# in-13
# .-15
# 2000-14
# iii-19
# william-16
# henry-17
# gates-18
# born-21
# was-20
# in-22
# ,-24
# washington-25
# .-35
# seattle-23
# to-26
# )-32
# and-33
# m_2-34
# m_1-27
# (-28
# sr-30
# .-31
# now-29
# family-37
# his-36
# was-38
# wealthy-39
# father-42
# his-41
# was-43
# ;-40
# lawyer-46
# a-44
# prominent-45
# mother-49
# his-48
# served-50
# ,-47
# on-51
# the-61
# board-53
# the-52
# of-54
# for-56
# directors-55
# bank-59
# first-57
# interstate-58
# and-60
# investments-1
# 4.3-0
# 5-2
# bibliography-3
# notes-5
# 6-4
# 7-6
# references-7
# 8-8
# further-9
# reading-10
# links-13
# life-15
# ,-23
# to-24
# .-34
# 9-11
# external-12
# early-14
# born-18
# gates-16
# was-17
# in-19
# seattle-20
# ,-21
# washington-22
# m_1-25
# and-26
# m_2-27
# ,-28
# was-30
# who-29
# of-31
# descent-33
# scottish-32
# 8-36
# [-35
# ]-37
# .-38
# family-40
# his-39
# was-41
# class-44
# upper-42
# middle-43
# father-47
# his-46
# was-48
# ;-45
# lawyer-51
# a-49
# prominent-50
# mother-54
# his-53
# served-55
# ,-52
# time-2
# full-0
# --1
# day-3
# at-4
# microsoft-5
# was-6
# june-7
# .-11
# 27-8
# ,-9
# 2008-10
# remains-13
# he-12
# at-14
# as-16
# .-21
# microsoft-15
# chairman-20
# executive-19
# non-17
# --18
# life-23
# early-22
# born-26
# gates-24
# was-25
# in-27
# ,-31
# to-32
# .-47
# seattle-28
# ,-29
# washington-30
# m_1-33
# and-34
# m_2-35
# ,-36
# of-37
# descent-46
# english-38
# ,-39
# german-40
# ,-41
# and-42
# irish-45
# scotch-43
# --44
# 9-49
# [-48
# ]-50
# 10-52
# [-51
# ]-53
# family-55
# his-54
# was-56
# class-59
# upper-57
# middle-58
# father-62
# his-61
# was-63
# ;-60
# lawyer-66
# ,-67
# a-64
# prominent-65
# investments-1
# 4.3-0
# 5-2
# bibliography-3
# notes-5
# 6-4
# 7-6
# references-7
# 8-8
# further-9
# reading-10
# links-13
# life-15
# ,-23
# to-24
# .-39
# 9-11
# external-12
# early-14
# born-18
# gates-16
# was-17
# in-19
# seattle-20
# ,-21
# washington-22
# m_1-25
# and-26
# m_2-27
# ,-28
# of-29
# descent-38
# english-30
# ,-31
# german-32
# ,-33
# and-34
# irish-37
# scotch-35
# --36
# 8-41
# [-40
# ]-42
# 9-44
# [-43
# ]-45
# family-47
# his-46
# was-48
# class-51
# upper-49
# middle-50
# father-54
# his-53
# was-55
# ;-52
# a-56
# mexico-1
# new-0
# police-2
# in-3
# after-5
# 1977-4
# violation-8
# a-6
# traffic-7
# (-9
# details-10
# of-11
# which-12
# lost-15
# have-13
# been-14
# over-16
# )-18
# .-19
# time-17
# born-22
# gates-20
# was-21
# in-23
# ,-27
# to-28
# .-32
# seattle-24
# ,-25
# washington-26
# m_1-29
# and-30
# m_2-31
# parents-34
# his-33
# are-35
# of-36
# .-46
# descent-45
# english-37
# ,-38
# german-39
# ,-40
# and-41
# irish-44
# scotch-42
# --43
# 10-48
# [-47
# ]-49
# 11-51
# was-55
# [-50
# ]-52
# father-54
# his-53
# lawyer-58
# ,-59
# and-60
# served-63
# a-56
# prominent-57
# mother-62
# his-61
# on-64
# the-65
# to-0
# fourteen-1
# .-2
# 's-5
# evidently-3
# there-4
# much-8
# stand-15
# only-6
# so-7
# going-12
# cinema-10
# --11
# sensibility-13
# the-9
# can-14
# .-16
# read-18
# i-17
# review-20
# ,-31
# and-32
# think-34
# a-19
# suggested-22
# which-21
# represents-26
# book-25
# this-24
# that-23
# flipside-28
# to-29
# the-27
# m_1-30
# i-33
# 's-36
# uses-47
# conventional-71
# there-35
# lot-38
# in-41
# a-37
# of-39
# truth-40
# that-42
# m_2-44
# 's-45
# book-46
# :-43
# language-50
# tell-60
# some-48
# ripe-49
# and-51
# descriptions-54
# of-55
# carnal-53
# bluntly-52
# act-58
# the-56
# sexual-57
# to-59
# story-62
# a-61
# is-64
# ,-69
# that-63
# ,-65
# at-66
# heart-68
# its-67
# pretty-70
# for-0
# hundred-2
# .-26
# one-1
# and-3
# days-6
# in-7
# show-10
# eighty-4
# --5
# susa-8
# to-9
# off-11
# wealth-14
# the-12
# vast-13
# of-15
# kingdom-17
# his-16
# and-18
# beauty-20
# the-19
# and-21
# wonder-22
# of-23
# majesty-25
# his-24
# m_1-28
# the-27
# ordered-29
# queen-31
# come-35
# .-51
# his-30
# ,-32
# m_2-33
# to-34
# before-36
# wearing-41
# him-37
# and-38
# guests-40
# his-39
# crown-43
# show-45
# her-42
# to-44
# off-46
# was-50
# beautiful-48
# how-47
# she-49
# but-52
# delivered-59
# king-55
# the-54
# 's-56
# command-57
# when-53
# was-58
# ,-60
# queen-61
# themes-1
# but-2
# plot-6
# a-3
# simple-4
# enough-5
# and-7
# humor-8
# appeal-10
# and-0
# to-9
# to-11
# .-13
# children-12
# made-15
# it-14
# use-17
# notable-16
# of-18
# music-20
# popular-19
# soundtrack-23
# the-22
# includes-24
# ;-21
# music-25
# .-51
# by-26
# covering-47
# m_1-27
# ,-28
# eels-29
# ,-30
# m_2-31
# ,-32
# proclaimers-34
# the-33
# ,-35
# wade-37
# jason-36
# ,-38
# men-41
# the-39
# baha-40
# ,-42
# and-43
# cale-45
# john-44
# (-46
# cohen-49
# )-50
# leonard-48
# during-52
# june-53
# 2008-54
# institute-59
# ,-55
# the-56
# american-57
# film-58
# gazes-0
# at-1
# .-10
# enormity-3
# the-2
# ,-4
# detail-6
# the-5
# ,-7
# and-8
# craftsmanship-9
# inside-11
# cathedral-13
# the-12
# of-14
# málaga-15
# tower-18
# the-16
# north-17
# rises-19
# meters-21
# and-22
# is-23
# .-37
# 84-20
# cathedral-28
# highest-27
# second-25
# --26
# the-24
# in-29
# behind-32
# m_1-30
# ,-31
# giralda-34
# the-33
# of-35
# m_2-36
# tower-40
# the-38
# south-39
# is-41
# unfinished-42
# .-43
# are-45
# there-44
# disputes-46
# ,-53
# but-54
# nicknamed-64
# on-47
# disappeared-51
# funds-50
# the-49
# where-48
# to-52
# is-57
# because-55
# it-56
# unfinished-58
# cathedral-61
# the-60
# ,-59
# has-62
# been-63
# s-4
# and-0
# then-1
# there-2
# ’-3
# solar-7
# .-33
# the-5
# planta-6
# 20-8
# plant-14
# ps20-10
# (-9
# )-11
# solar-12
# power-13
# ,-15
# is-17
# ,-31
# spain-32
# which-16
# plant-22
# in-29
# a-18
# solar-19
# thermal-20
# energy-21
# in-23
# near-27
# mayor-26
# sanlucar-24
# la-25
# m_1-28
# m_2-30
# is-35
# it-34
# world-37
# the-36
# ’-38
# s-39
# powerful-41
# most-40
# power-43
# solar-42
# tower-44
# .-45
# megawatt-48
# the-46
# 20-47
# produces-55
# mw-50
# )-51
# power-53
# solar-52
# tower-54
# (-49
# electricity-56
# with-57
# mirrors-60
# large-58
# movable-59
# called-61
# heliostats-62
# to-0
# pdt-3
# .-4
# 6:45-1
# p.m.-2
# sandra-5
# 's-6
# daughter-7
# ,-8
# cerna-10
# ,-11
# mother-14
# ,-17
# laura-9
# a-12
# single-13
# and-15
# teacher-16
# murdered-19
# was-18
# on-20
# living-28
# .-46
# monday-21
# ,-22
# august-23
# 2010-26
# 30-24
# ,-25
# while-27
# in-29
# southwest-41
# m_1-30
# ,-31
# city-34
# ,-37
# an-32
# historic-33
# in-35
# m_2-36
# 340-39
# about-38
# miles-40
# of-42
# madrid-43
# ,-44
# spain-45
# slideshow-48
# view-47
# :-49
# mother-50
# of-51
# cerna-54
# murdered-52
# laura-53
# warns-55
# others-56
# multiple-65
# stabbed-64
# old-60
# 49-year-58
# --59
# woman-61
# the-57
# was-62
# brutally-63
# by-0
# dabby-1
# comments-6
# .-37
# at-2
# pm-4
# 1:39-3
# no-5
# :-7
# labels-8
# spans-33
# :-9
# humor-11
# architecture-10
# ,-12
# architecture-14
# crazy-13
# ,-15
# bridge-20
# shaped-17
# toilet-16
# house-18
# alamillo-19
# by-21
# bridge-25
# calatrava-22
# the-23
# alamillo-24
# in-26
# m_1-27
# ,-28
# m_2-29
# (-30
# spain-31
# )-32
# river-36
# the-34
# guadalquivir-35
# construction-38
# of-39
# bridge-41
# the-40
# began-42
# in-43
# and-45
# completed-47
# .-53
# 1989-44
# was-46
# in-48
# by-50
# 1992-49
# calatrava-52
# santiago-51
# art-0
# and-1
# architecture-2
# ,-3
# karachi-4
# ,-5
# pakistan-6
# ,-7
# dabeer-8
# ,-9
# architecture-11
# sustainable-10
# ,-12
# architecture-14
# humorous-13
# ,-15
# architecture-17
# green-16
# ,-18
# music-19
# january-22
# 4-23
# bridge-27
# friday-20
# ,-21
# ,-24
# 2008-25
# alamillo-26
# by-28
# bridge-32
# calatrava-29
# the-30
# alamillo-31
# in-33
# m_1-34
# ,-35
# m_2-36
# (-37
# spain-38
# )-39
# spans-40
# river-43
# .-44
# the-41
# guadalquivir-42
# construction-45
# of-46
# bridge-48
# the-47
# began-49
# in-50
# and-52
# completed-54
# .-60
# 1989-51
# was-53
# in-55
# by-57
# 1992-56
# calatrava-59
# santiago-58
# 100,000-1
# $-0
# stopped-4
# .-9
# when-2
# she-3
# trading-5
# after-6
# months-8
# ten-7
# 91-11
# [-10
# ]-12
# couple-14
# the-13
# began-16
# also-15
# investment-21
# with-30
# at-34
# .-37
# fated-20
# ill-18
# --19
# their-17
# in-22
# venture-29
# development-25
# whitewater-24
# corporation-26
# estate-28
# real-27
# the-23
# m_1-31
# and-32
# m_2-33
# time-36
# this-35
# 90-39
# [-38
# ]-40
# on-41
# february-42
# 27-43
# ,-44
# 1980-45
# gave-48
# ,-46
# rodham-47
# birth-49
# to-50
# .-59
# daughter-52
# a-51
# ,-53
# chelsea-54
# child-58
# ,-55
# her-56
# only-57
# in-60
# november-61
# ,-63
# bill-64
# 1980-62
# lady-1
# first-0
# .-2
# clintons-4
# the-3
# lost-6
# had-5
# investment-9
# ;-15
# 156-17
# and-55
# been-58
# their-7
# late-1970s-8
# in-10
# corporation-14
# development-13
# whitewater-12
# the-11
# [-16
# ]-18
# at-19
# ,-23
# partners-25
# ,-33
# guaranty-36
# time-22
# the-20
# same-21
# their-24
# in-26
# ,-29
# m_1-30
# investment-28
# that-27
# and-31
# m_2-32
# operated-34
# madison-35
# ,-37
# institution-42
# savings-39
# and-40
# loan-41
# a-38
# retained-44
# that-43
# services-47
# ]-54
# the-45
# legal-46
# of-48
# firm-51
# rose-49
# law-50
# 156-53
# [-52
# may-56
# have-57
# improperly-59
# often-1
# most-0
# whitewater-4
# simply-3
# )-5
# was-6
# ,-2
# controversy-10
# .-45
# an-7
# american-8
# politics-9
# began-12
# that-11
# with-13
# investments-17
# estate-16
# real-15
# the-14
# of-18
# in-30
# ,-35
# venture-39
# bill-19
# and-20
# clinton-22
# hillary-21
# and-23
# associates-25
# their-24
# ,-26
# m_1-27
# and-28
# m_2-29
# corporation-34
# development-33
# whitewater-32
# the-31
# a-36
# failed-37
# business-38
# in-40
# 1970s-42
# the-41
# and-43
# 1980s-44
# solution-46
# to-47
# :-52
# ``-53
# definition-57
# legend-51
# today-48
# 's-49
# puzzle-50
# cd-54
# ''-55
# cryptic-56
# ;-58
# ``-59
# dd-60
# ''-61
# nov-0
# 1993-1
# controversy-4
# the-2
# whitewater-3
# was-5
# controversy-9
# .-43
# an-6
# american-7
# political-8
# began-11
# that-10
# with-12
# dealings-16
# estate-15
# real-14
# the-13
# of-17
# and-22
# associates-24
# bill-18
# and-19
# clinton-21
# hillary-20
# their-23
# m_1-25
# in-28
# ,-33
# venture-37
# and-26
# m_2-27
# corporation-32
# development-31
# whitewater-30
# the-29
# a-34
# failed-35
# business-36
# in-38
# 1970s-40
# the-39
# and-41
# 1980s-42
# in-44
# november-45
# ,-47
# hale-49
# 1993-46
# david-48
# ,-50
# source-52
# the-51
# of-53
# criminal-54
# often-1
# most-0
# whitewater-4
# simply-3
# )-5
# was-6
# ,-2
# controversy-10
# .-45
# an-7
# american-8
# politics-9
# began-12
# that-11
# with-13
# investments-17
# estate-16
# real-15
# the-14
# of-18
# in-30
# ,-35
# venture-39
# bill-19
# and-20
# clinton-22
# hillary-21
# and-23
# associates-25
# their-24
# ,-26
# m_1-27
# and-28
# m_2-29
# corporation-34
# development-33
# whitewater-32
# the-31
# a-36
# failed-37
# business-38
# in-40
# 1970s-42
# the-41
# and-43
# 1980s-44
# york-48
# new-47
# times-49
# article-50
# a-46
# published-51
# .-56
# during-52
# u.s-55
# the-53
# 1992-54
# based-4
# music-2
# --3
# segments-5
# serious-0
# ,-1
# ,-6
# including-7
# :-8
# band-12
# the-9
# million-10
# dollar-11
# :-13
# was-15
# this-14
# segment-20
# ,-21
# airing-22
# composed-28
# .-59
# session-19
# jam-17
# --18
# a-16
# from-23
# ,-27
# 1980-24
# through-25
# 1988-26
# of-29
# musicians-35
# star-34
# all-32
# --33
# the-30
# following-31
# :-36
# m_1-37
# ,-38
# m_2-39
# ,-40
# clark-42
# roy-41
# ,-43
# cramer-45
# floyd-44
# ,-46
# mccoy-48
# charlie-47
# ,-49
# davis-51
# danny-50
# ,-52
# burns-54
# jethro-53
# ,-55
# and-56
# gimble-58
# johnny-57
# songwriter-63
# singer-61
# --62
# segment-64
# a-60
# ,-65
# one-67
# where-66
# fuzz-1
# hot-0
# 's-2
# pegg-4
# simon-3
# and-5
# frost-7
# are-12
# .-20
# nick-6
# (-8
# both-9
# of-10
# whom-11
# users-15
# out-16
# )-19
# prolific-13
# twitter-14
# of-17
# interest-18
# co-23
# film-22
# --24
# the-21
# bateman-27
# stars-25
# jason-26
# ,-28
# m_1-29
# ,-35
# ,-30
# m_2-31
# and-32
# weaver-34
# sigourney-33
# features-36
# voice-38
# as-42
# ,-46
# and-47
# directed-49
# the-37
# of-39
# rogen-41
# seth-40
# character-45
# the-43
# title-44
# is-48
# by-50
# mottola-54
# superbad-51
# 's-52
# greg-53
# (-55
# of-57
# instead-56
# pegg-58
# something-0
# better-1
# comes-2
# along-3
# .-4
# 's-7
# and-5
# it-6
# raunchy-9
# without-10
# ,-17
# 's-20
# .-26
# sweetly-8
# getting-11
# deep-13
# too-12
# in-14
# muck-16
# the-15
# though-18
# it-19
# probably-21
# not-22
# for-23
# kids-25
# the-24
# anything-28
# with-29
# in-33
# m_1-30
# and-31
# m_2-32
# it-34
# is-35
# and-27
# worth-36
# .-38
# watching-37
# mention-42
# *-39
# did-40
# i-41
# directed-45
# ?-57
# ''-58
# that-43
# mottola-44
# episodes-48
# a-46
# few-47
# of-49
# development-56
# the-50
# late-51
# ,-52
# lamented-53
# ``-54
# arrested-55
# helps-60
# that-59
# international-2
# goldman-0
# sachs-1
# (-3
# dealer-9
# )-16
# .-17
# a-4
# registered-5
# uk-6
# broker-7
# --8
# ,-10
# subsidiary-12
# a-11
# of-13
# sachs-15
# goldman-14
# until-18
# june-19
# 2009-20
# was-22
# he-21
# replaced-30
# .-39
# --24
# non-23
# executive-25
# chairman-26
# of-27
# bp-28
# being-29
# by-31
# officer-36
# m_1-32
# formely-33
# chief-34
# executive-35
# of-37
# m_2-38
# was-41
# sutherland-40
# director-43
# asked-54
# a-42
# of-44
# bank-47
# the-45
# royal-46
# of-48
# group-50
# scotland-49
# until-51
# he-52
# was-53
# leave-56
# had-61
# to-55
# board-58
# the-57
# it-60
# be-63
# when-59
# to-62
# proponent-4
# currently-0
# the-1
# largest-2
# lte-3
# .-5
# expects-7
# ericsson-6
# enabled-16
# .-27
# %-9
# 80-8
# of-10
# services-13
# broadband-12
# mobile-11
# will-14
# be-15
# by-17
# by-19
# ,-21
# using-22
# cellular-18
# 2012-20
# hspa-23
# and-24
# lte-25
# technologies-26
# ceo-29
# m_1-28
# said-31
# m_2-30
# based-45
# .-48
# bulk-33
# the-32
# of-34
# in-38
# deployments-37
# broadband-36
# mobile-35
# years-42
# the-39
# coming-40
# five-41
# will-43
# be-44
# on-46
# hspa-47
# faces-51
# but-49
# huawei-50
# competition-53
# little-52
# in-54
# market-56
# the-55
# solution-0
# ,-1
# despite-2
# .-6
# lockdown-5
# the-3
# vendor-4
# expects-8
# ericsson-7
# enabled-17
# .-28
# %-10
# 80-9
# of-11
# services-14
# broadband-13
# mobile-12
# will-15
# be-16
# by-18
# by-20
# ,-22
# using-23
# cellular-19
# 2012-21
# hspa-24
# and-25
# lte-26
# technologies-27
# ceo-30
# m_1-29
# said-32
# m_2-31
# based-46
# .-49
# bulk-34
# the-33
# of-35
# in-39
# deployments-38
# broadband-37
# mobile-36
# years-43
# the-40
# coming-41
# five-42
# will-44
# be-45
# on-47
# hspa-48
# according-50
# to-51
# unstrung-52
# forecast-55
# ,-53
# svanberg-54
# billion-57
# 3.5-56
# association-3
# global-0
# mobile-1
# suppliers-2
# .-4
# expects-6
# ericsson-5
# enabled-15
# .-26
# %-8
# 80-7
# of-9
# services-12
# broadband-11
# mobile-10
# will-13
# be-14
# by-16
# by-18
# ,-20
# using-21
# cellular-17
# 2012-19
# hspa-22
# and-23
# lte-24
# technologies-25
# ceo-28
# m_1-27
# said-30
# m_2-29
# based-44
# .-47
# bulk-32
# the-31
# of-33
# in-37
# deployments-36
# broadband-35
# mobile-34
# years-41
# the-38
# coming-39
# five-40
# will-42
# be-43
# on-45
# hspa-46
# according-48
# to-49
# unstrung-50
# forecast-53
# ,-51
# svanberg-52
# billion-55
# 3.5-54
# despises-1
# he-0
# in-2
# .-6
# trial-5
# a-3
# rape-4
# do-12
# if-8
# he-9
# does-10
# n't-11
# it-13
# judge-16
# the-15
# have-18
# but-7
# ,-14
# will-17
# disbarred-20
# .-21
# him-19
# directed-22
# by-23
# .-26
# jewison-25
# norman-24
# written-27
# by-28
# .-32
# m_1-29
# and-30
# m_2-31
# man-34
# this-33
# needs-35
# lawyer-38
# .-41
# the-36
# best-37
# in-39
# town-40
# problem-44
# the-43
# is-45
# but-42
# ...-46
# is-48
# he-47
# lawyer-51
# .-54
# the-49
# best-50
# in-52
# town-53
# contents-55
# 1-56
# kirkland-58
# arthur-57
# 2-59
# happen-2
# could-0
# not-1
# .-3
# arguments-6
# a-4
# priori-5
# for-7
# reason-9
# this-8
# prove-12
# could-10
# never-11
# existence-14
# .-17
# the-13
# of-15
# god-16
# arguments-20
# a-18
# posteriori-19
# criticized-23
# have-21
# been-22
# by-24
# show-36
# .-49
# hume-25
# ,-26
# m_1-27
# ,-28
# m_2-29
# ,-30
# edwards-31
# and-32
# others-34
# many-33
# to-35
# is-40
# argument-39
# this-38
# that-37
# not-41
# proof-43
# a-42
# of-44
# existence-46
# the-45
# of-47
# god-48
# intend-51
# i-50
# use-53
# to-52
# bible-55
# the-54
# been-1
# has-0
# home-3
# m_2-30
# .-40
# the-2
# of-4
# writers-6
# numerous-5
# ,-7
# musicians-8
# including-15
# ,-9
# artists-10
# ,-11
# and-12
# actors-13
# ,-14
# dylan-17
# bob-16
# ,-18
# thomson-20
# ,-29
# virgil-19
# ,-21
# bukowski-23
# charles-22
# ,-24
# m_1-25
# ,-26
# cohen-28
# leonard-27
# ,-31
# pop-33
# iggy-32
# ,-34
# jobriath-35
# ,-36
# and-37
# rivers-39
# larry-38
# chelsea-44
# the-42
# hotel-43
# longer-46
# no-45
# accepts-47
# though-41
# residencies-52
# term-51
# long-49
# --50
# new-48
# building-55
# the-54
# is-56
# ,-53
# still-57
# home-58
# alabama-0
# ,-1
# and-2
# treasoning-9
# in-3
# meantime-5
# the-4
# husband-7
# her-6
# is-8
# her-10
# with-11
# .-18
# star-14
# a-12
# porn-13
# ,-15
# suxxx-17
# candy-16
# believed-21
# this-19
# is-20
# be-23
# and-36
# habits-39
# .-40
# to-22
# reference-25
# m_2-35
# a-24
# to-26
# m_1-27
# ,-28
# wife-30
# the-29
# of-31
# president-34
# former-32
# us-33
# his-37
# womanizing-38
# •-42
# v-41
# auto-50
# g-43
# •-44
# d-45
# •-46
# e-47
# grand-48
# theft-49
# :-51
# city-53
# vice-52
# characters-54
# major-58
# protagonist-55
# tommy-56
# vercetti-57
# sang-1
# and-0
# ``-2
# clothes-6
# ''-7
# ,-8
# mimicking-9
# .-18
# hand-5
# second-3
# --4
# song-11
# the-10
# ``-12
# rose-16
# ''-17
# hand-15
# second-13
# --14
# skit-20
# the-19
# helped-21
# restore-23
# .-26
# to-22
# reputation-25
# her-24
# reagan-27
# and-28
# husband-30
# in-44
# .-46
# her-29
# with-31
# as-34
# predecessor-33
# her-32
# lady-36
# first-35
# ,-37
# m_1-38
# ,-43
# ,-39
# widow-40
# of-41
# m_2-42
# 1985-45
# nancy-47
# and-48
# jackie-49
# compared-52
# were-50
# often-51
# due-53
# ,-57
# in-58
# .-65
# to-54
# glamour-56
# their-55
# contrast-59
# to-60
# ladies-64
# the-61
# intervening-62
# first-63
# reagan-67
# nancy-66
# reflected-68
# on-69
# the-70
# »-1
# lbj-0
# harvey-3
# lee-2
# oswald-4
# monroe-7
# marilyn-6
# »-8
# holden-10
# william-9
# shocker-12
# the-11
# is-13
# not-14
# killing-16
# lbj-15
# jfk-17
# .-18
# shocker-20
# the-19
# was-21
# was-23
# !-26
# she-22
# slut-25
# a-24
# m_1-27
# ,-28
# widow-30
# ,-34
# the-29
# of-31
# m_2-33
# president-32
# believed-35
# johnson-39
# ”-47
# plotted-48
# mail-63
# president-37
# vice-36
# lyndon-38
# and-40
# cabal-43
# a-41
# “-42
# of-44
# tycoons-46
# texas-45
# and-49
# carried-50
# ,-58
# out-51
# assassination-53
# the-52
# of-54
# husband-57
# her-55
# philandering-56
# london-59
# ’-60
# s-61
# daily-62
# designed-1
# he-0
# dress-4
# made-10
# .-25
# the-2
# wedding-3
# for-5
# fabiola-7
# queen-6
# of-8
# belgium-9
# of-11
# satin-14
# ivory-12
# duchess-13
# trimmed-15
# with-16
# at-19
# mink-18
# white-17
# collar-21
# the-20
# and-22
# hips-24
# the-23
# upset-28
# m_1-26
# famously-27
# m_2-29
# for-30
# was-38
# .-53
# buying-31
# creations-35
# balenciaga-32
# 's-33
# expensive-34
# while-36
# he-37
# president-39
# feared-42
# because-40
# he-41
# think-48
# public-46
# the-44
# american-45
# that-43
# might-47
# lavish-52
# purchases-50
# the-49
# too-51
# couture-56
# her-54
# haute-55
# http-2
# video-0
# --1
# :-3
# //www.musicfootnotes.com-4
# /-5
# lana-6
# --7
# video-16
# rey-10
# --9
# anthem-14
# --11
# national-12
# --13
# del-8
# --15
# video-19
# the-17
# music-18
# for-20
# .-45
# song-22
# the-21
# premiered-23
# on-24
# and-29
# depicts-30
# june-25
# 27-26
# ,-27
# 2012-28
# rey-32
# as-33
# as-43
# del-31
# monroe-35
# marilyn-34
# and-36
# m_1-37
# and-38
# rocky-42
# ap-41
# $-40
# a-39
# m_2-44
# rey-47
# del-46
# cited-48
# video-50
# as-51
# the-49
# ``-52
# thing-57
# beautiful-56
# most-55
# definitely-53
# the-54
# done-62
# ''-58
# she-59
# 's-60
# ever-61
# .-63
# as-64
# of-65
# june-66
# 29-67
# ,-68
# 2012-69
# received-73
# ,-70
# it-71
# has-72
# “-3
# :-0
# --1
# )-2
# thing-6
# the-4
# one-5
# want-10
# i-7
# do-8
# not-9
# called-13
# to-11
# be-12
# is-14
# lady-16
# .-17
# first-15
# sounds-19
# it-18
# like-20
# .-24
# horse-23
# a-21
# saddle-22
# kennedy-27
# jacqueline-26
# m_1-29
# onassis-28
# ,-30
# wife-32
# ,-41
# and-42
# probagated-54
# the-31
# of-33
# m_2-34
# ,-35
# president-37
# 35th-36
# of-38
# usa-40
# the-39
# in-43
# move-46
# an-44
# unprecedented-45
# by-47
# lady-51
# an-48
# american-49
# first-50
# ,-52
# she-53
# name-62
# to-63
# friendly-57
# more-56
# neck-61
# jackie-59
# '-60
# her-55
# '-58
# was-0
# single-5
# .-11
# rey-2
# del-1
# 's-3
# fifth-4
# from-6
# july-9
# album-8
# her-7
# 2012-10
# video-14
# the-12
# music-13
# for-15
# and-22
# depicted-23
# and-35
# video-37
# song-17
# the-16
# premiered-18
# june-19
# 27-20
# 2012-21
# rey-25
# as-26
# as-33
# del-24
# m_1-27
# and-28
# rocky-32
# ap-31
# $-30
# a-29
# m_2-34
# the-36
# received-39
# has-38
# views-42
# on-43
# .-45
# m-41
# 5-40
# youtube-44
# faulkner-47
# newton-46
# 's-48
# studio-50
# third-49
# album-51
# write-52
# it-53
# on-54
# skin-56
# your-55
# contained-58
# which-57
# songs-61
# two-59
# nexus-60
# august-1
# 11-0
# 2011-2
# o-5
# 12:05-3
# jackie-4
# :-6
# had-8
# lbj-7
# husband-10
# my-9
# written-12
# killed-11
# by-13
# size-18
# kirkwood-16
# r.-14
# cort-15
# font-17
# decrease-19
# increase-22
# believed-34
# plotted-47
# ,-57
# size-21
# font-20
# m_1-26
# size-24
# font-23
# print-25
# ,-27
# widow-29
# ,-33
# the-28
# of-30
# m_2-32
# president-31
# johnson-38
# ”-46
# president-36
# vice-35
# lyndon-37
# and-39
# cabal-42
# a-40
# “-41
# of-43
# tycoons-45
# texas-44
# and-48
# carried-49
# out-50
# assassination-52
# the-51
# of-53
# husband-56
# her-54
# philandering-55
# london-58
# ’-59
# s-60
# mail-62
# daily-61
# is-1
# ]-0
# author-4
# .-7
# an-2
# american-3
# and-5
# attorney-6
# is-9
# she-8
# member-11
# .-30
# a-10
# of-12
# and-17
# child-21
# family-16
# the-13
# influential-14
# kennedy-15
# the-18
# only-19
# living-20
# of-22
# m_2-29
# m_1-25
# president-24
# u.s.-23
# and-26
# lady-28
# first-27
# at-31
# time-33
# the-32
# of-34
# presidency-38
# father-36
# her-35
# 's-37
# was-40
# she-39
# child-43
# ;-44
# settled-52
# a-41
# young-42
# after-45
# assassination-47
# his-46
# in-48
# 1963-49
# family-51
# her-50
# in-53
# east-56
# the-54
# upper-55
# her-0
# as-1
# senator-5
# york-4
# new-3
# a-2
# :-6
# 1-7
# .-8
# kennedy-10
# caroline-9
# daughter-13
# the-11
# only-12
# and-14
# child-18
# m_2-31
# ,-32
# kennedy-34
# surviving-17
# only-16
# the-15
# of-19
# president-22
# the-20
# 35th-21
# of-23
# m_1-27
# states-26
# united-25
# the-24
# and-28
# icon-30
# fashion-29
# caroline-33
# intention-37
# s-36
# replace-39
# to-38
# clinton-41
# hillary-40
# seems-42
# ’-35
# be-44
# is-55
# to-43
# not-45
# surprise-47
# rest-49
# a-46
# the-48
# of-50
# americans-52
# the-51
# since-53
# she-54
# stranger-57
# to-58
# no-56
# you-0
# .-1
# leave-3
# you-2
# impression-6
# ,-10
# but-11
# annihilating-12
# .-13
# ''-14
# the-4
# same-5
# of-7
# something-8
# beautiful-9
# plath-16
# sylvia-15
# anneyhall-17
# @-18
# rss-20
# aol.com-19
# |-21
# jun-23
# .-24
# archive-22
# 28-25
# ,-26
# 2012-27
# .-38
# at-28
# notes-32
# 170-31
# 9:49pm-29
# with-30
# m_1-33
# &-34
# m_2-35
# ,-36
# 1953-37
# reblogged-40
# thisisthesweetlife-39
# this-41
# from-42
# dreamoffire-44
# liked-50
# liked-55
# palecomplexions-43
# reblogged-45
# this-46
# from-47
# colorsontherecordmachine-49
# anneyhall-48
# chef-52
# this-51
# --53
# d-54
# reblogged-58
# this-56
# mrfrivolous-57
# this-59
# from-60
# jarrodfreeman-62
# cloakxdagger-61
# reblogged-63
# jr.-0
# ,-1
# jr.-3
# ,-8
# john-2
# or-4
# john-7
# john-5
# --6
# was-9
# socialite-12
# .-21
# an-10
# american-11
# ,-13
# publisher-15
# magazine-14
# ,-16
# lawyer-17
# ,-18
# and-19
# pilot-20
# son-24
# the-22
# elder-23
# of-25
# m_2-32
# m_1-28
# president-27
# u.s.-26
# and-29
# lady-31
# first-30
# died-35
# ,-33
# kennedy-34
# in-36
# along-40
# ,-57
# on-58
# .-63
# crash-39
# a-37
# plane-38
# with-41
# wife-43
# his-42
# kennedy-47
# carolyn-44
# bessette-45
# --46
# and-48
# sister-50
# his-49
# --51
# in-52
# bessette-56
# --53
# law-54
# lauren-55
# july-59
# 16-60
# ,-61
# 1999-62
# quote-65
# [-64
# :-66
# wikipedia-67
# ]-68
# destroy-3
# ,-0
# who-1
# would-2
# papers-6
# after-7
# ,-10
# and-11
# mary-12
# .-22
# mary-4
# 's-5
# murder-9
# her-8
# and-13
# wisner-15
# ,-16
# was-18
# frank-14
# who-17
# boss-21
# cord-19
# 's-20
# was-25
# then-23
# there-24
# m_1-29
# .-42
# neophyte-26
# massachusetts-27
# senator-28
# and-30
# wife-32
# become-40
# his-31
# ,-33
# m_2-34
# ,-35
# with-36
# whom-37
# mary-38
# would-39
# close-41
# mary-43
# ,-44
# encouraged-45
# ,-48
# by-46
# cord-47
# devoted-49
# had-54
# and-58
# remained-59
# time-52
# what-50
# spare-51
# she-53
# to-55
# painting-57
# her-56
# aloof-60
# of-61
# the-62
# by-0
# fromm-2
# at-3
# joseph-1
# am-5
# comments-7
# 12:56-4
# 33-6
# :-8
# links-9
# to-10
# labels-13
# post-12
# this-11
# :-14
# magazine-16
# america-15
# ,-17
# syncretism-18
# sunday-19
# 2011-24
# ,-20
# october-21
# ,-23
# 2-22
# misunderstanding-27
# a-25
# jesuit-26
# assassinated-31
# when-28
# m_1-29
# was-30
# nov.-32
# 22-33
# ,-34
# 1963-35
# ,-36
# widow-38
# his-37
# ,-39
# m_2-40
# asked-42
# ,-41
# hannan-45
# deliver-47
# .-66
# archbishop-43
# philip-44
# to-46
# eulogy-49
# because-50
# the-48
# of-51
# relationship-55
# his-52
# close-53
# personal-54
# with-56
# president-58
# the-57
# ,-59
# dated-61
# which-60
# back-62
# to-63
# 1940s-65
# the-64
# father-69
# then-67
# --68
# superman-1
# young-0
# .-2
# poisoned-5
# he-3
# is-4
# by-6
# .-13
# son-9
# his-7
# illegitimate-8
# ,-10
# roslov-12
# captain-11
# eisenhower-16
# president-14
# dwight-15
# delivers-17
# broadcast-22
# .-29
# television-21
# radio-19
# /-20
# a-18
# at-23
# start-25
# the-24
# of-26
# story-28
# the-27
# is-31
# m_1-30
# president-32
# in-33
# .-35
# 1978-34
# divorced-37
# he-36
# wife-40
# and-50
# married-52
# .-56
# his-38
# first-39
# ,-41
# m_2-42
# ,-43
# elected-47
# ,-49
# after-44
# he-45
# was-46
# president-48
# is-51
# to-53
# monroe-55
# marilyn-54
# woman-58
# wonder-57
# mentions-60
# also-59
# assassinated-64
# .-67
# that-61
# nixon-62
# was-63
# in-65
# 1963-66
# british-69
# the-68
# koppel-2
# ,-0
# ted-1
# ,-3
# mclaughlin-5
# ,-52
# john-4
# ,-6
# leibovitz-8
# annie-7
# ,-9
# lennon-11
# john-10
# and-12
# ono-14
# ,-15
# castro-17
# yoko-13
# fidel-16
# ,-18
# einstein-20
# albert-19
# ,-21
# rockwell-23
# ,-28
# warhol-30
# norman-22
# ,-24
# m_1-25
# and-26
# m_2-27
# andy-29
# ,-31
# capote-33
# truman-32
# ,-34
# presley-36
# elvis-35
# ,-37
# zedong-39
# mao-38
# ,-40
# king-42
# larry-41
# ,-43
# bowie-45
# david-44
# ,-46
# jagger-48
# mick-47
# ,-49
# iacocca-51
# lee-50
# is-1
# kennedy-0
# author-4
# .-7
# an-2
# american-3
# and-5
# attorney-6
# is-9
# she-8
# member-11
# .-30
# a-10
# of-12
# and-17
# child-21
# family-16
# the-13
# influential-14
# kennedy-15
# surviving-20
# only-19
# the-18
# of-22
# m_2-29
# m_1-25
# president-24
# u.s.-23
# and-26
# lady-28
# first-27
# at-31
# time-33
# the-32
# of-34
# presidency-38
# father-36
# her-35
# 's-37
# was-40
# she-39
# child-43
# ;-44
# settled-53
# a-41
# young-42
# after-45
# assassination-47
# his-46
# in-48
# 1963-49
# family-52
# her-51
# ,-50
# in-54
# east-57
# the-55
# upper-56
# notes-1
# 16-0
# peninsularian-2
# :-3
# wonder-6
# little-4
# stevie-5
# and-7
# ali-9
# muhammad-8
# (-10
# archives-13
# )-14
# michael-11
# ochs-12
# via-16
# graham-19
# danny-17
# --18
# )-20
# months-22
# 2-21
# ago-23
# notes-25
# 795-24
# m_1-28
# anneyhall-26
# (-15
# :-27
# .-33
# &-29
# m_2-30
# ,-31
# 1953-32
# months-35
# 2-34
# ago-36
# notes-38
# 170-37
# served-40
# saki-39
# in-41
# at-43
# ,-45
# restaurant-49
# in-56
# apple-42
# hangawi-44
# a-46
# vegan-47
# korean-48
# located-50
# at-51
# street-55
# 32nd-54
# east-53
# 12-52
# herzog-2
# werner-1
# 134-5
# ]-0
# ,-3
# [-4
# ]-6
# kubrick-8
# .-49
# stanley-7
# ,-9
# 135-11
# ,-21
# m_1-25
# ,-31
# truffaut-36
# ,-37
# 140-39
# [-10
# ]-12
# lean-14
# lumet-20
# david-13
# ,-15
# 136-17
# [-16
# ]-18
# sidney-19
# 137-23
# [-22
# ]-24
# ,-26
# [-27
# 138-28
# ]-29
# m_2-30
# [-32
# 139-33
# ]-34
# francois-35
# [-38
# ]-40
# lynch-42
# david-41
# 141-44
# and-46
# yimou-48
# [-43
# ]-45
# zhang-47
# 142-51
# [-50
# ]-52
# spielberg-55
# 's-56
# movies-57
# subsequently-53
# ,-54
# legends-0
# aldrich-2
# ,-3
# 130-5
# robert-1
# [-4
# ]-6
# bergman-8
# ingmar-7
# ,-9
# 131-11
# kubrick-20
# .-61
# [-10
# herzog-14
# ,-15
# ]-12
# werner-13
# 132-17
# [-16
# ]-18
# stanley-19
# ,-21
# lean-26
# 133-23
# [-22
# ]-24
# david-25
# ,-27
# 134-29
# ,-33
# 135-35
# ,-43
# truffaut-48
# [-28
# ]-30
# lumet-32
# sidney-31
# [-34
# m_1-37
# m_2-42
# ]-36
# ,-38
# [-39
# 136-40
# ]-41
# [-44
# 137-45
# ]-46
# francois-47
# ,-49
# 138-51
# [-50
# ]-52
# lynch-54
# 139-56
# and-58
# yimou-60
# david-53
# [-55
# ]-57
# zhang-59
# 140-63
# [-62
# ]-64
# spielberg-67
# subsequently-65
# ,-66
# influenced-73
# movies-70
# have-71
# also-72
# directors-75
# including-79
# many-74
# followed-77
# that-76
# ,-78
# wales-1
# wiltshire-0
# festivals-4
# pembrokeshire-2
# literary-3
# &-5
# events-6
# listed-8
# !-9
# get-7
# place-14
# derbyshire-10
# peveril-11
# castle-12
# market-13
# ,-15
# castleton-16
# ,-17
# derbyshire-18
# ,-19
# castle-23
# peveril-22
# 8wq-21
# s33-20
# was-24
# setting-26
# by-31
# .-33
# the-25
# for-27
# novel-29
# the-28
# m_1-30
# m_2-32
# www.english-heritage.org.uk-34
# lea-38
# hall-36
# hardwick-35
# doe-37
# ,-39
# chesterfield-40
# ,-41
# derbyshire-42
# ,-43
# s44-44
# hall-49
# the-46
# stunning-47
# hardwick-48
# ,-50
# maintained-51
# ,-56
# by-52
# trust-55
# the-53
# national-54
# used-58
# was-57
# as-59
# malfoy-60
# are-0
# architects-2
# .-6
# the-1
# of-3
# process-5
# that-4
# in-7
# couple-10
# the-8
# last-9
# of-11
# months-12
# read-14
# i-13
# couple-16
# book-31
# and-39
# enchantress-44
# a-15
# of-17
# mention-20
# books-18
# that-19
# palace-25
# the-21
# term-22
# ``-23
# memory-24
# ''-26
# m_1-28
# 's-29
# history-30
# --27
# m_2-32
# (-33
# favorite-36
# )-37
# ,-38
# a-34
# personal-35
# rushdie-41
# salman-40
# 's-42
# the-43
# of-45
# .-47
# florence-46
# term-53
# what-48
# an-49
# evocative-50
# ,-51
# romantic-52
# thought-56
# ,-54
# i-55
# .-57
# called-59
# also-58
# method-61
# ,-65
# a-66
# ``-60
# of-62
# ''-64
# loci-63
# in-0
# skies-2
# ,-6
# and-7
# in-8
# by-15
# .-22
# the-1
# (-3
# 1959-4
# )-5
# experience-11
# the-9
# mathematical-10
# (-12
# 1981-13
# )-14
# davis-18
# philip-16
# j.-17
# and-19
# hersh-21
# reuben-20
# served-24
# it-23
# as-25
# :-55
# illustration-28
# the-26
# cover-27
# for-29
# ,-36
# account-39
# ,-45
# for-46
# 1983-34
# m_1-30
# 's-31
# m_2-32
# (-33
# )-35
# a-37
# bestselling-38
# of-40
# history-42
# the-41
# of-43
# science-44
# matter-50
# sorabji-48
# richard-47
# 's-49
# ,-51
# space-52
# &-53
# motion-54
# theories-56
# in-57
# and-59
# sequel-61
# stephan-66
# antiquity-58
# their-60
# 1988-63
# ,-65
# (-62
# )-64
# 2-0
# ,-1
# and-2
# meqabyan-4
# 3-3
# (-5
# relation-7
# )-13
# .-14
# no-6
# to-8
# books-10
# the-9
# of-11
# maccabees-12
# churches-17
# some-15
# syriac-16
# accept-18
# letter-20
# as-23
# .-25
# the-19
# of-21
# baruch-22
# scripture-24
# scientists-27
# christian-26
# m_1-30
# by-31
# .-33
# the-28
# bible-29
# m_2-32
# textbook-35
# this-34
# along-37
# with-38
# bible-40
# the-39
# serves-42
# ,-36
# ,-41
# as-43
# .-53
# pastor-48
# the-44
# permanent-45
# ``-46
# impersonal-47
# ''-49
# of-50
# church-52
# the-51
# hammadi-56
# nag-55
# library-57
# gnosticism-54
# and-58
# texts-61
# not-63
# other-59
# gnostic-60
# (-62
# head-1
# the-0
# modelled-3
# .-7
# reputedly-2
# by-4
# astor-6
# lady-5
# astor-8
# 's-9
# conversion-10
# was-11
# gradual-12
# and-13
# influenced-15
# .-21
# was-14
# by-16
# number-18
# a-17
# of-19
# factors-20
# phyllis-24
# her-22
# sister-23
# given-26
# had-25
# her-27
# m_1-28
# by-29
# thought-33
# .-39
# m_2-30
# because-31
# she-32
# find-36
# nancy-34
# might-35
# interesting-38
# it-37
# became-46
# (-40
# phyllis-41
# ,-42
# however-43
# ,-44
# never-45
# scientist-49
# .-50
# )-51
# a-47
# christian-48
# at-52
# astor-55
# first-53
# lady-54
# had-56
# interest-59
# ,-60
# but-61
# after-62
# only-57
# marginal-58
# different-1
# rather-0
# light-2
# on-3
# :-6
# …-7
# .-26
# issue-5
# the-4
# recognized-11
# it-8
# is-9
# now-10
# have-14
# that-12
# streets-13
# functions-18
# social-15
# and-16
# recreational-17
# impaired-22
# which-19
# are-20
# severely-21
# by-23
# traffic-25
# car-24
# study-29
# the-27
# m_1-28
# by-30
# m_2-31
# (-32
# 1981-33
# )-34
# found-35
# had-43
# friends-50
# residents-37
# of-38
# with-40
# streets-39
# traffic-42
# light-41
# that-36
# ,-44
# on-45
# average-46
# ,-47
# three-48
# more-49
# and-51
# acquaintances-55
# on-59
# many-54
# twice-52
# as-53
# as-56
# people-58
# the-57
# was-2
# when-0
# he-1
# 29-3
# 15-6
# ,-4
# she-5
# .-7
# married-8
# until-9
# .-14
# death-11
# her-10
# in-12
# 1981-13
# died-16
# he-15
# afterward-19
# .-20
# days-18
# 13-17
# robinson-22
# chris-21
# and-23
# hudson-25
# m_1-29
# .-35
# kate-24
# ,-26
# years-28
# 13-27
# and-30
# m_2-31
# ,-32
# years-34
# 12-33
# married-36
# from-37
# .-41
# 1945-38
# to-39
# 1946-40
# z-46
# jay-44
# --45
# carter-48
# ``-43
# ``-47
# and-49
# beyonce-50
# knowles-51
# shawn-42
# ,-52
# years-54
# .-55
# 12-53
# macy-58
# william-56
# h.-57
# and-59
# huffman-61
# felicity-60
# hills-1
# beverly-0
# ,-2
# north-4
# .-15
# just-3
# of-5
# and-7
# west-9
# sunset-6
# just-8
# of-10
# hotel-14
# the-11
# beverly-12
# hills-13
# stepfather-17
# my-16
# bought-19
# had-18
# home-21
# from-22
# .-30
# the-20
# inhabitants-25
# its-23
# previous-24
# ,-26
# m_1-27
# and-28
# m_2-29
# being-31
# north-32
# of-33
# sunset-34
# was-35
# symbol-39
# at-40
# .-43
# a-36
# big-37
# status-38
# time-42
# that-41
# lived-46
# if-44
# you-45
# in-47
# north-49
# the-48
# meant-52
# ,-50
# it-51
# had-56
# family-55
# your-54
# that-53
# husband-1
# ideal-0
# by-2
# 15th-7
# kocher-5
# jason-3
# t.-4
# august-6
# ,-8
# film-13
# culture-11
# 2009-9
# --10
# »-12
# and-14
# tv-15
# am-18
# »-16
# i-17
# ,-19
# on-20
# ,-24
# obsessed-25
# .-31
# occasion-23
# a-21
# regular-22
# with-26
# m_1-28
# both-27
# and-29
# m_2-30
# loved-33
# i-32
# both-34
# of-35
# roles-39
# famous-38
# most-37
# their-36
# ,-40
# astin-42
# john-41
# as-43
# addams-45
# gomez-44
# on-46
# as-53
# family-49
# the-47
# addams-48
# and-50
# duke-52
# patty-51
# patty-54
# and-55
# cathy-56
# holmes-0
# ,-1
# years-3
# .-4
# 16-2
# engaged-5
# as-6
# ,-14
# years-16
# .-17
# of-7
# kline-10
# 2006-8
# kevin-9
# and-11
# cates-13
# phoebe-12
# 16-15
# married-18
# in-19
# .-21
# 1989-20
# couple-23
# the-22
# have-24
# children-26
# together-27
# .-28
# two-25
# m_1-29
# and-30
# m_2-31
# ,-32
# years-34
# .-35
# 16-33
# divorced-36
# in-37
# .-39
# 1985-38
# ocasek-41
# ric-40
# and-42
# porizkova-44
# ,-45
# years-47
# .-48
# paulina-43
# 16-46
# married-49
# in-50
# .-52
# 1989-51
# degeneres-54
# ellen-53
# and-55
# derossi-57
# ,-58
# years-60
# .-61
# portia-56
# 15-59
# of-0
# contributers-3
# .-7
# the-1
# great-2
# to-4
# culture-6
# human-5
# established-10
# it-8
# was-9
# in-11
# by-13
# 1804-12
# i-15
# napoleon-14
# and-16
# graves-18
# ,-22
# bizet-24
# ---49
# k-51
# the-17
# of-19
# wilde-21
# oscar-20
# geroges-23
# ,-25
# m_1-26
# and-27
# m_2-28
# ,-29
# modigliani-31
# amedeo-30
# ,-32
# proust-34
# marcel-33
# ,-35
# lyotard-39
# jean-36
# --37
# françois-38
# ,-40
# fourier-42
# joseph-41
# ,-43
# piaf-45
# edith-44
# ,-46
# éluard-48
# paul-47
# --50
# have-53
# i-52
# stop-55
# but-56
# to-54
# with-0
# painter-3
# .-6
# the-1
# american-2
# brooks-5
# romaine-4
# salon-9
# another-7
# literary-8
# of-10
# influence-12
# great-11
# was-13
# held-15
# m_2-32
# .-33
# that-14
# in-16
# by-18
# ,-22
# m_1-26
# saturdays-17
# friends-19
# of-20
# barney-21
# writer-25
# the-23
# american-24
# and-27
# wife-30
# ``-28
# her-29
# ''-31
# toklas-34
# ,-35
# dedicated-41
# writer-38
# a-37
# herself-39
# ,-40
# although-36
# life-43
# to-44
# ,-51
# serving-52
# her-42
# service-46
# the-45
# of-47
# stein-50
# the-48
# manly-49
# her-53
# in-54
# aspects-56
# all-55
# of-57
# life-60
# their-58
# domestic-59
# enough-0
# have-2
# .-11
# to-1
# people-5
# ,-6
# in-7
# satisfied-3
# most-4
# way-10
# its-8
# own-9
# s-14
# ’-13
# career-16
# ,-17
# as-18
# ,-22
# first-15
# novelist-21
# a-19
# young-20
# earned-23
# him-24
# entree-25
# heard-47
# and/or-57
# arts-60
# )-61
# .-62
# into-26
# (-34
# and-35
# through-36
# circle-29
# the-27
# inner-28
# of-30
# m_1-31
# and-32
# m_2-33
# them-37
# ,-38
# about-40
# just-39
# anybody-41
# else-42
# you-43
# ’-44
# ve-45
# ever-46
# of-48
# during-49
# era-51
# that-50
# working-54
# who-52
# was-53
# in-55
# literature-56
# the-58
# visual-59
# he-63
# never-64
# enlarged-0
# ,-1
# at-2
# day-6
# .-7
# flickr-3
# the-4
# other-5
# one-8
# of-9
# commenters-12
# his-10
# regular-11
# pointed-13
# out-14
# be-23
# .-35
# women-18
# the-16
# two-17
# in-19
# photo-21
# the-20
# that-15
# might-22
# none-24
# ,-30
# in-31
# other-25
# than-26
# m_1-27
# and-28
# m_2-29
# years-34
# their-32
# later-33
# goodness-36
# me-37
# !-38
# luminaries-44
# these-42
# two-43
# of-45
# century-48
# the-46
# 20th-47
# scene-51
# paris-49
# ...
# was-39
# separately-40
# in-42
# .-50
# aspendos-43
# ,-44
# perga-45
# and-46
# pamukkale-47
# of-48
# turkey-49
# film-52
# the-51
# released-54
# was-53
# on-55
# november-57
# 6-56
# having-1
# initially-0
# footprint-5
# in-6
# limited-4
# very-3
# a-2
# arena-9
# the-7
# gsm-8
# acquisition-12
# the-11
# of-13
# in-15
# escotel-14
# 2004-16
# gave-17
# ,-10
# idea-18
# presence-24
# m_2-32
# india-23
# truly-20
# pan-21
# --22
# a-19
# covering-25
# (-27
# excluding-28
# ,-31
# maharashtra-26
# m_1-29
# )-30
# ,-33
# gujarat-34
# inclusive-60
# ,-35
# pradesh-37
# andhra-36
# ,-38
# pradesh-40
# madhya-39
# ,-41
# chattisgarh-42
# ,-43
# pradesh-45
# uttar-44
# (-46
# east-47
# )-50
# ,-51
# haryana-52
# and-48
# west-49
# ,-53
# kerala-54
# ,-55
# rajasthan-56
# and-57
# delhi-58
# (-59
# of-61
# on-0
# 5th-2
# the-1
# of-3
# and-7
# didn-8
# january-4
# ,-5
# 2011-6
# ’-9
# come-11
# t-10
# back-12
# until-13
# .-16
# 24th-15
# march-14
# during-17
# months-21
# 3-20
# almost-19
# these-18
# saw-23
# we-22
# rajasthan-24
# .-42
# ,-25
# pradesh-27
# himachal-26
# ,-28
# dehli-29
# ,-30
# m_1-31
# and-32
# m_2-33
# ,-34
# and-35
# bit-39
# also-36
# a-37
# tiny-38
# of-40
# karnataka-41
# was-46
# ever-43
# since-44
# i-45
# 12-47
# and-48
# had-49
# opened-52
# eyes-51
# my-50
# for-53
# goa-55
# india-54
# been-57
# had-56
# my-58
# at-0
# khajuraho-1
# .-5
# ,-2
# or-3
# kolkata-4
# we-6
# both-7
# love-9
# also-8
# india-11
# ,-12
# encourage-16
# south-10
# so-13
# we-14
# strongly-15
# you-17
# fly-19
# .-34
# to-18
# south-20
# enjoy-22
# to-21
# warmth-24
# the-23
# of-25
# m_1-26
# ,-27
# m_2-28
# ,-29
# kerala-30
# or-31
# nadu-33
# tamil-32
# s-41
# but-35
# ,-36
# remember-37
# ,-38
# there-39
# ’-40
# much-44
# see-48
# only-42
# so-43
# that-45
# you-46
# can-47
# and-49
# do-50
# or-55
# in-57
# in-51
# ,-54
# weeks-53
# two-52
# even-56
# a-58
# warsi-0
# ,-1
# kapoor-3
# tusshar-2
# and-4
# talpade-6
# shreyas-5
# features-10
# ;-7
# it-8
# also-9
# actors-12
# .-13
# new-11
# 2-15
# [-14
# ]-16
# film-18
# the-17
# started-19
# shooting-20
# .-31
# on-21
# in-25
# march-23
# 20-22
# 2010-24
# m_1-26
# ,-27
# m_2-28
# and-29
# hyderabad-30
# 2-33
# [-32
# ]-34
# 3-36
# [-35
# ]-37
# golmaal-38
# 3-39
# released-41
# was-40
# on-42
# .-46
# november-44
# 5-43
# 2010-45
# starts-48
# story-47
# with-49
# pranking-55
# madhav-50
# (-51
# warsi-53
# )-54
# arshad-52
# students-56
# ride-0
# to-1
# visit-7
# .-14
# place-4
# a-2
# nearby-3
# nagothane-5
# to-6
# waterfall-13
# less-10
# very-9
# heard-11
# a-8
# vardayini-12
# nagothane-18
# view-15
# larger-16
# map-17
# is-19
# 80kilometers-21
# .-32
# about-20
# from-22
# mumbai-24
# on-25
# navi-23
# highway-30
# m_2-28
# m_1-26
# --27
# national-29
# 17-31
# kilometers-34
# few-33
# ahead-35
# ,-38
# past-39
# of-36
# nagothane-37
# jindal-40
# s-42
# ’-41
# factory-46
# maharashtra-43
# seamless-44
# steel-45
# is-49
# ,-47
# there-48
# kherwadi-53
# village-52
# small-51
# a-50
# on-54
# left-56
# the-55
# of-57
# goa-60
# mumbai-58
# --59
# jha-3
# zara-0
# ''-1
# amardeep-2
# as-4
# as-16
# mother-7
# reshma-5
# 's-6
# biswas-9
# as-10
# jhuma-8
# das-15
# warden-12
# hostel-11
# deep-13
# jyoti-14
# production-19
# and-20
# filming-21
# lawyer-18
# criminal-17
# film-23
# the-22
# shot-25
# was-24
# in-26
# .-30
# m_1-27
# and-28
# m_2-29
# basu-34
# bipasha-33
# offered-36
# earlier-31
# ,-32
# was-35
# part-38
# ,-43
# but-44
# refused-46
# the-37
# of-39
# lady-42
# the-40
# leading-41
# she-45
# .-47
# part-49
# the-48
# went-51
# then-50
# to-52
# .-55
# fernandez-54
# jacqueline-53
# was-57
# basu-56
# across-1
# zones-2
# becomes-5
# while-0
# ,-3
# it-4
# call-10
# .-11
# distance-9
# long-7
# --8
# a-6
# zone-14
# a-12
# cellular-13
# (-15
# or-16
# circle-18
# cellular-17
# )-19
# is-20
# normally-21
# state-24
# ,-25
# with-26
# )-71
# .-72
# the-22
# entire-23
# exceptions-29
# a-27
# few-28
# like-30
# divided-67
# m_1-31
# (-32
# is-34
# )-38
# ,-39
# m_2-40
# (-41
# is-43
# )-50
# ,-51
# jharkhand-52
# (-66
# which-33
# zone-37
# a-35
# different-36
# which-42
# part-45
# a-44
# of-46
# zone-49
# the-47
# maharashtra-48
# (-53
# is-55
# )-62
# or-63
# pradesh-65
# which-54
# part-57
# a-56
# of-58
# zone-61
# the-59
# bihar-60
# uttar-64
# into-68
# zones-70
# multiple-69
# major-1
# canis-0
# (-2
# dog-4
# )-5
# .-6
# the-3
# 's-8
# what-7
# more-9
# black-12
# sirius-11
# ,-13
# animagus-15
# ,-16
# an-14
# morph-18
# ,-10
# could-17
# at-19
# into-21
# .-27
# will-20
# dog-24
# a-22
# black-23
# named-25
# padfoot-26
# example-29
# another-28
# is-30
# m_1-31
# .-55
# ,-32
# star-36
# the-33
# third-34
# brightest-35
# in-37
# constellation-39
# the-38
# m_2-40
# ,-41
# is-43
# which-42
# also-44
# name-46
# the-45
# of-47
# father-50
# sirius-48
# 's-49
# and-51
# uncle-54
# bellatrix-52
# 's-53
# cygnus-56
# ,-57
# andromeda-58
# ,-59
# and-60
# cassiopeia-61
# are-62
# also-63
# constellations-64
# ,-65
# and-66
# regulus-67
# ,-68
# alphard-69
# laws-1
# ancient-0
# of-2
# passed-10
# .-25
# i-4
# theodosius-3
# and-5
# i-7
# justinian-6
# that-8
# were-9
# against-11
# donatists-13
# the-12
# ,-14
# decreed-16
# which-15
# penalty-19
# for-20
# the-17
# death-18
# any-21
# practiced-23
# who-22
# rebaptism-24
# m_1-26
# ,-27
# by-28
# ,-30
# m_2-29
# describes-31
# persecution-33
# between-45
# .-49
# the-32
# and-34
# execution-35
# of-36
# thousands-37
# of-38
# anabaptists-39
# in-40
# parts-42
# various-41
# of-43
# europe-44
# 1525-46
# and-47
# 1660-48
# persecution-51
# continuing-50
# in-52
# europe-53
# was-54
# largely-55
# were-1
# they-0
# group-4
# .-11
# an-2
# independent-3
# out-5
# arose-10
# of-6
# whom-7
# anabaptists-9
# the-8
# keller-13
# ludwig-12
# ,-14
# lindsay-17
# all-36
# thomas-15
# m.-16
# ,-18
# vedder-21
# h.-19
# c.-20
# ,-22
# gràtz-24
# delbert-23
# ,-25
# christian-28
# john-26
# t.-27
# and-29
# m_1-30
# (-31
# author-32
# )-35
# of-33
# m_2-34
# held-37
# ,-38
# in-39
# ,-42
# position-44
# .-52
# degrees-41
# varying-40
# the-43
# were-48
# anabaptists-47
# the-46
# that-45
# of-49
# origin-51
# waldensian-50
# edit-54
# [-53
# ]-55
# spread-57
# in-62
# history-56
# of-58
# anabaptists-61
# the-59
# early-60
# listener-2
# the-1
# ,-3
# series-6
# ,-11
# for-12
# plays-22
# a-4
# tv-5
# about-7
# paramedic-10
# a-8
# telepathic-9
# nbc-13
# ,-14
# international-16
# fox-15
# and-17
# ctv-18
# in-19
# which-20
# he-21
# det-23
# sgt-25
# ,-0
# .-24
# .-26
# becker-27
# ;-28
# m_1-29
# a-64
# ,-30
# adaptation-36
# ;-50
# and-51
# dance-54
# series-35
# mini-33
# --34
# an-31
# nbc-32
# of-37
# times-42
# selling-44
# m_2-38
# 's-39
# york-41
# new-40
# best-43
# novel-45
# of-46
# name-49
# the-47
# same-48
# one-52
# last-53
# directed-55
# by-56
# and-59
# starring-60
# lehun-58
# richard-57
# dhavernas-62
# caroline-61
# ,-63
# is-1
# name-0
# “-2
# reference-4
# !-12
# a-3
# to-5
# term-8
# the-6
# nautical-7
# ,-9
# ahoy-11
# ships-10
# words-15
# the-14
# ahoy-18
# !-19
# “-16
# chips-17
# feature-22
# ”-20
# also-21
# prominently-23
# in-24
# .-36
# story-26
# a-25
# appearing-27
# ,-33
# by-34
# in-28
# chapter-29
# 15-30
# of-31
# m_1-32
# m_2-35
# 1-38
# [-37
# ]-39
# .-40
# relays-42
# dickens-41
# tale-45
# a-43
# childhood-44
# of-46
# shipwright-48
# a-47
# named-49
# taunted-53
# chips-50
# who-51
# is-52
# by-54
# rat-58
# a-55
# diabolical-56
# talking-57
# predicts-60
# who-59
# sinking-62
# the-61
# seat-0
# in-1
# at-23
# .-29
# centuries-8
# 11th-3
# ,-4
# 12th-5
# and-6
# 13th-7
# the-2
# in-9
# duchy-12
# the-10
# former-11
# of-13
# swabia-14
# ,-15
# incorporated-17
# ,-22
# which-16
# aargau-21
# day-20
# present-18
# --19
# time-25
# the-24
# of-26
# m_1-28
# the-27
# from-30
# germany-32
# southwestern-31
# alsace-35
# (-33
# mainly-34
# ,-36
# m_2-37
# )-42
# ,-38
# aargau-39
# and-40
# thurgau-41
# family-44
# the-43
# extended-45
# influence-47
# to-50
# ,-59
# austria-63
# its-46
# and-48
# holdings-49
# reaches-53
# the-51
# southeastern-52
# of-54
# empire-58
# the-55
# holy-56
# roman-57
# today-61
# 's-62
# roughly-60
# comprised-1
# is-0
# of-2
# .-9
# tunes-5
# various-3
# show-4
# and-6
# hits-8
# pop-7
# favorites-14
# my-12
# two-13
# on-15
# album-17
# the-16
# are-18
# infact-10
# ,-11
# covers-19
# .-20
# s-25
# so-22
# what-23
# ’-24
# new-26
# ?-27
# is-29
# ”-28
# from-30
# .-35
# m_1-31
# &-32
# pisano-34
# john-33
# trumpet-38
# magic-37
# is-40
# ”-39
# tune-43
# .-44
# a-41
# m_2-42
# alpert-46
# herb-45
# &-47
# brass-50
# --51
# the-48
# tijuana-49
# track-56
# my-54
# love-55
# listing-57
# what-52
# now-53
# :-58
# side-59
# one-60
# :-61
# what-62
# now-63
# love-65
# my-64
# memories-67
# freckles-66
# of-68
# madrid-69
# vajpayee-4
# minister-0
# --1
# atal-2
# behari-3
# ,-5
# also-6
# poet-10
# .-26
# acclaimed-9
# critically-8
# a-7
# --11
# in-12
# ,-15
# disha-17
# albums-14
# two-13
# nayi-16
# (-18
# 1999-19
# )-20
# and-21
# samvedna-22
# (-23
# 2002-24
# )-25
# india-27
# 's-28
# minister-31
# current-29
# prime-30
# m_1-32
# and-33
# wife-35
# m_2-36
# his-34
# known-38
# are-37
# be-40
# .-44
# to-39
# admirers-43
# his-41
# avid-42
# on-45
# may-46
# ,-50
# in-51
# 10-47
# ,-48
# 2007-49
# session-55
# a-52
# milestone-53
# joint-54
# held-56
# in-57
# hall-61
# the-58
# historic-59
# central-60
# of-62
# parliament-65
# india-63
# 's-64
# minister-0
# in-1
# ,-3
# but-4
# going-7
# 1970-2
# really-5
# got-6
# only-8
# in-9
# .-12
# mid-1980s-11
# the-10
# until-15
# 2009-17
# early-16
# denied-20
# however-13
# ,-14
# india-18
# officially-19
# existence-22
# .-27
# the-21
# of-23
# project-26
# such-24
# a-25
# minister-29
# prime-28
# m_1-30
# crack-36
# wife-33
# m_2-34
# will-35
# coconut-39
# the-37
# auspicious-38
# marking-40
# launch-42
# the-41
# of-43
# india-44
# s-46
# ’-45
# submarine-53
# powered-50
# nuclear-48
# --49
# missile-52
# ballistic-51
# first-47
# at-54
# centre-57
# the-55
# shipbuilding-56
# ,-58
# wikipedia-61
# visakhapatnam-59
# --60
# ,-62
# encyclopedia-65
# the-63
# free-64
# @-66
# @-67
# ameparam-68
# @-69
# @-70
# file-73
# /wiki-71
# /-72
# :-74
# arealview.jpg-77
# .-78
# vizag-75
# --76
# jpg-79
# ''-80
# school-2
# higher-0
# secondary-1
# on-3
# wednesday-4
# resembled-5
# fortress-7
# .-8
# a-6
# nowhere-9
# in-10
# sight-11
# was-12
# student-14
# .-17
# any-13
# or-15
# teacher-16
# all-19
# after-18
# 's-22
# ,-20
# it-21
# in-23
# .-57
# booth-29
# turned-27
# school-25
# --26
# this-24
# --28
# cast-41
# minister-32
# prime-31
# m_1-33
# and-34
# wife-36
# ,-37
# m_2-38
# ,-39
# his-35
# where-30
# will-40
# votes-43
# on-44
# goes-48
# their-42
# thursday-45
# as-46
# assam-47
# to-49
# phase-52
# the-50
# second-51
# of-53
# elections-56
# sabha-55
# lok-54
# image-58
# via-59
# wikipedia-60
# is-62
# this-61
# first-64
# the-63
# rafael-0
# of-1
# ,-3
# as-6
# launcher-11
# .-26
# israel-2
# as-4
# well-5
# a-7
# single-8
# universal-9
# vertical-10
# capable-12
# of-13
# launching-14
# missiles-20
# role-18
# multi-16
# --17
# supersonic-15
# cruise-19
# like-21
# brahmos-23
# the-22
# and-24
# sagarika-25
# minister-28
# prime-27
# crack-35
# wife-32
# m_2-33
# will-34
# coconut-38
# ;-50
# --51
# )-53
# marking-54
# the-36
# auspicious-37
# (-39
# no-40
# bottles-44
# ,-41
# no-42
# champagne-43
# here-45
# in-46
# navy-49
# the-47
# indian-48
# )-52
# launch-56
# the-55
# of-57
# india-58
# s-60
# ’-59
# missile-66
# powered-64
# nuclear-62
# --63
# first-61
# ballistic-65
# ----------------------------------------------------------------------
# NodeNotFound                         Traceback (most recent call last)
# <ipython-input-191-2417aaa3d7af> in <module>()
# ----> 1 evaluateCV(clf, le, train_data, train_labels_featurized)
#
# <ipython-input-190-f63d41b939d5> in evaluateCV(classifier, label_encoder, X, y, verbose)
#      45             X_train, X_test = [X[i] for i in train_index], [X[i] for i in test_index]
#      46             y_train, y_test = [y[i] for i in train_index], [y[i] for i in test_index]
# ---> 47             clf.fit(X_train, y_train)
#      48             pred_labels = classifier.predict(X_test)
#      49             stats = precision_recall_fscore_support(y_test, pred_labels, beta=0.5)
#
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     246             This estimator
#     247         """
# --> 248         Xt, fit_params = self._fit(X, y, **fit_params)
#     249         if self._final_estimator is not None:
#     250             self._final_estimator.fit(Xt, y, **fit_params)
#
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params)
#     211                 Xt, fitted_transformer = fit_transform_one_cached(
#     212                     cloned_transformer, None, Xt, y,
# --> 213                     **fit_params_steps[name])
#     214                 # Replace the transformer of the step with the fitted
#     215                 # transformer. This is necessary when loading the transformer
#
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     360
#     361     def __call__(self, *args, **kwargs):
# --> 362         return self.func(*args, **kwargs)
#     363
#     364     def call_and_shelve(self, *args, **kwargs):
#
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, weight, X, y, **fit_params)
#     579                        **fit_params):
#     580     if hasattr(transformer, 'fit_transform'):
# --> 581         res = transformer.fit_transform(X, y, **fit_params)
#     582     else:
#     583         res = transformer.fit(X, y, **fit_params).transform(X)
#
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in fit_transform(self, X, y, **fit_params)
#     737             delayed(_fit_transform_one)(trans, weight, X, y,
#     738                                         **fit_params)
# --> 739             for name, trans, weight in self._iter())
#     740
#     741         if not result:
#
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, weight, X, y, **fit_params)
#     579                        **fit_params):
#     580     if hasattr(transformer, 'fit_transform'):
# --> 581         res = transformer.fit_transform(X, y, **fit_params)
#     582     else:
#     583         res = transformer.fit(X, y, **fit_params).transform(X)
#
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     518         else:
#     519             # fit method of arity 2 (supervised transformation)
# --> 520             return self.fit(X, y, **fit_params).transform(X)
#     521
#     522
#
# <ipython-input-188-3e5697ee6086> in transform(self, X)
#       8
#       9     def transform(self, X):
# ---> 10         return FindDepPath(X, verbose=False)
#
# <ipython-input-180-753544f5e29a> in FindDepPath(data, verbose)
#      23
#      24             try:
# ---> 25                 instance_context.append(nx.shortest_path_length(graph, source=s, target=t))
#      26             except nx.NetworkXNoPath:
#      27                 instance_context.append(0)
#
# /Applications/anaconda3/lib/python3.7/site-packages/networkx/algorithms/shortest_paths/generic.py in shortest_path_length(G, source, target, weight)
#     242     else:
#     243         if source not in G:
# --> 244             raise nx.NodeNotFound("Source {} not in G".format(source))
#     245
#     246         if target is None:
#
# NodeNotFound: Source Snippet(left='RAFAEL of Israel , as well as a single universal vertical launcher capable of launching supersonic multi-role cruise missiles like the BrahMos and Sagarika . Prime Minister', mention_1='Manmohan Singh', middle='’ s wife', mention_2='Gursharan Kaur', right='will crack the auspicious coconut ( no , no Champagne bottles here in the Indian Navy ; - ) ) marking the launch of India ’ s first nuclear-powered ballistic missile', direction='fwd') not in G

# %%
# A check for the average F1 score

f_scorer = make_scorer(fbeta_score, beta=0.5, average='macro')

def evaluateCV_check(classifier, X, y, verbose=True):
    kfold = StratifiedKFold(n_splits = 5, shuffle=True, random_state=0) 
    scores = cross_val_score(classifier, X, y, cv=kfold, scoring = f_scorer)
    print("\nCross-validation scores (StratifiedKFold): ", scores)
    print("Mean cv score (StratifiedKFold): ", scores.mean())

# %%
evaluateCV_check(clf, train_data, train_labels_featurized)
# Out:
# Cross-validation scores (StratifiedKFold):  [0.78319178 0.77791582 0.78375181 0.78223485 0.78230726]
# Mean cv score (StratifiedKFold):  0.7818803012927733

# %%
##################################################################################################
# 4. TEST PREDICTIONS and ANALYSIS
##################################################################################################

# Fit final model on the full train data
clf.fit(train_data, train_labels_featurized)

# Predict on test set
test_data, test_labels = load_data('../data/test-covered.json.txt', verbose=False)
print(len(test_labels))
# test_data_featurized = SelectContext(test_data, verbose=False)
test_label_predicted = clf.predict(test_data)
print(len(test_label_predicted))
# Deprecation warning explained: https://stackoverflow.com/questions/49545947/sklearn-deprecationwarning-truth-value-of-an-array
test_label_predicted_decoded = le.inverse_transform(test_label_predicted)
print(len(test_label_predicted_decoded))
print(test_label_predicted_decoded[:2])
f = open("outputs/test_labels.txt", 'w', encoding="utf-8")
for label in test_label_predicted_decoded:
    f.write(label+'\n')
# Out:
# 1840
# 1840
# 1840
# ['capital' 'NO_REL']
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# Feature analisys - print N most informative
# !! Make changes in this function when you change the pipleine!!
def printNMostInformative(classifier,label_encoder,N):
    """Prints features with the highest coefficient values, per class"""
    feature_names = classifier.named_steps['countvectorizer'].get_feature_names()

    coef = classifier.named_steps['logisticregression'].coef_    
    print(coef.shape)
    for rel in label_encoder.classes_:
        rel_id = label_encoder.transform([rel])[0]
        coef_rel = coef[rel_id]
        coefs_with_fns = sorted(zip(coef_rel, feature_names))
        top_features = coefs_with_fns[-N:]
        print("\nClass {} best: ".format(rel))
        for feat in top_features:
            print(feat)        
        
print("Top features used to predict: ")
# show the top features
printNMostInformative(clf,le,2)
