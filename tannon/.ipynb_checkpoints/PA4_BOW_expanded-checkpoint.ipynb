# %% [markdown]
# ### this script sets a baseline for realation extraction using frequency-based BOW model
#
# #### add additional features

# %%
import gzip
import numpy as np
import random
import os
import json

from collections import Counter, defaultdict, namedtuple
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_fscore_support, fbeta_score, make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score, StratifiedKFold, KFold
from sklearn.preprocessing import FunctionTransformer,LabelEncoder
import numpy as np

##### additional imports
import spacy
nlp = spacy.load('en')

# %%
##################################################################################################
# 1. LOAD DATA
##################################################################################################

PairExample = namedtuple('PairExample',
    'entity_1, entity_2, snippet')
Snippet = namedtuple('Snippet',
    'left, mention_1, middle, mention_2, right, direction')
def load_data(file, verbose=True):
    f = open(file,'r', encoding='utf-8')
    data = []
    labels = []
    for i,line in enumerate(f):
        instance = json.loads(line)
        if i==0:
            if verbose:
                print('json example:')
                print(instance)
        #'relation, entity_1, entity_2, snippet' fileds for each example
        #'left, mention_1, middle, mention_2, right, direction' for each snippet
        instance_tuple = PairExample(instance['entity_1'],instance['entity_2'],[])
        for snippet in instance['snippet']:
            try:
                snippet_tuple = Snippet(snippet['left'],snippet['mention_1'],snippet['middle'],
                                   snippet['mention_2'],snippet['right'],
                                    snippet['direction'])
                instance_tuple.snippet.append(snippet_tuple)
            except:
                print(instance)
        if i==0:
            if verbose:
                print('\nexample transformed as a named tuple:')
                print(instance_tuple)
        data.append(instance_tuple)
        labels.append(instance['relation'])
    return data,labels
    
train_data, train_labels = load_data('../data/train.json.txt')
# Out:
# json example:
# {'relation': 'has_spouse', 'entity_1': 'Judy_Garland', 'entity_2': 'David_Rose', 'snippet': [{'left': 'thirty and his life and career were riding high . In 1941 , shortly after the death of his father , Mercer began an intense affair with nineteen-year-old', 'mention_1': 'Judy Garland', 'middle': 'while she was engaged to composer', 'mention_2': 'David Rose', 'right': '. Garland married Rose to temporarily stop the affair , but the effect on Mercer lingered , adding to the emotional depth of his lyrics . Their affair', 'direction': 'fwd'}]}
#
# example transformed as a named tuple:
# PairExample(entity_1='Judy_Garland', entity_2='David_Rose', snippet=[Snippet(left='thirty and his life and career were riding high . In 1941 , shortly after the death of his father , Mercer began an intense affair with nineteen-year-old', mention_1='Judy Garland', middle='while she was engaged to composer', mention_2='David Rose', right='. Garland married Rose to temporarily stop the affair , but the effect on Mercer lingered , adding to the emotional depth of his lyrics . Their affair', direction='fwd')])

# %%
# Statistics over relations
def print_stats(labels):
    labels_counts = Counter(labels)
    print('{:20s} {:>10s} {:>10s}'.format('', '', 'rel_examples'))
    print('{:20s} {:>10s} {:>10s}'.format('relation', 'examples', '/all_examples'))
    print('{:20s} {:>10s} {:>10s}'.format('--------', '--------', '-------'))
    for k,v in labels_counts.items():
        print('{:20s} {:10d} {:10.2f}'.format(k, v, v /len(labels)))
    print('{:20s} {:>10s} {:>10s}'.format('--------', '--------', '-------'))
    print('{:20s} {:10d} {:10.2f}'.format('Total', len(labels), len(labels) /len(labels)))

print('Train set statistics:')
print_stats(train_labels)
# Out:
# Train set statistics:
#                                 rel_examples
# relation               examples /all_examples
# --------               --------    -------
# has_spouse                 3019       0.31
# author                     2653       0.27
# NO_REL                     2300       0.24
# capital                     510       0.05
# worked_at                  1178       0.12
# --------               --------    -------
# Total                      9660       1.00

# %%
# check that each entity pair is assigned only one relation
pair_dict={}
rel_dict={}
for example, label in zip(train_data,train_labels):
    if (example.entity_1,example.entity_2) not in pair_dict.keys():
        pair_dict[(example.entity_1,example.entity_2)] = [label]
        
    else:
        pair_dict[(example.entity_1,example.entity_2)].append(label)
        print(example.entity_1,example.entity_2,label)
    if label not in rel_dict.keys():
        rel_dict[label] = [example]
    else:
        rel_dict[label].append(example)
print("Done building dictionary")  
    
# example for each relation
for rel in rel_dict.keys():
    ex = rel_dict[rel][0]
    print(rel,ex.entity_1,ex.entity_2)
# Out:
# Done building dictionary
# has_spouse Judy_Garland David_Rose
# author Charlie_and_the_Chocolate_Factory Roald_Dahl
# NO_REL Sichuan Tibet
# capital Andalusia Seville
# worked_at Carl-Henric_Svanberg Ericsson

# %%
# how to reconstruct full context

# ex = train_data[0]
# print(ex)
# print("\n full context:")
# s = ex.snippet[0]
# print(' '.join((s.left, s.mention_1, s.middle, s.mention_2, s.right)))

# %%
def lemmatize(doc):
    lemmas = []
    doc = nlp(doc)
    for w in doc:
        if w.lemma_ == "-PRON-":
            lemmas.append(w.orth_)
        else:
            lemmas.append(w.lemma_)
    lemmas = " ".join(lemmas)
    return lemmas

# %%
def rebuild_text(ex):
    rebuilt_ex = []
    for s in ex.snippet:
        text = ' '.join((s.left, s.mention_1, s.middle, s.mention_2, s.right))
        rebuilt_ex.append(text)
    return rebuilt_ex

# %%
def build_text_from_snippet(s):
    text = ' '.join((s.left, s.mention_1, s.middle, s.mention_2, s.right))
    return text

# %%
def rebuild_corpus(data):
    corpus = []
    for ex in data:
        corpus.append(rebuild_text(ex)) 
    return corpus

# %%
mini_corpus = rebuild_corpus(train_data[:100])

for ex in mini_corpus:
    doc = nlp(ex[0])
    print([sent.string for sent in doc.sents])
#     key_sent = sent.string for sent in doc.sents if sent.string 
#     sentences = [sent.string.strip() for sent in doc.sents]
# Out:
# ['thirty and his life and career were riding high . ', 'In 1941 , shortly after the death of his father , Mercer began an intense affair with nineteen-year-old Judy Garland while she was engaged to composer David Rose . ', 'Garland married Rose to temporarily stop the affair , but the effect on Mercer lingered , adding to the emotional depth of his lyrics . ', 'Their affair']
# ['Latest activity 4 Other Sweet-Treat Wikia Summary of a Sweet Adventure Edit Charlie and the Chocolate Factory is a 2005 film adaptation of the 1964 book of the same name by Roald Dahl . ', 'Directed by Tim Burton , the film stars Freddie Highmore as Charlie Bucket and Johnny Depp as Willy Wonka . ', 'The storyline concerns a']
# ['various places claim the title , such as parts of southern Kham in northwestern Yunnan province , including the tourist destinations of Lijiang and Zhongdian . ', 'Places like Sichuan and Tibet also claim the real Shangri-La was in its territory . ', 'In 2001 , Tibet Autonomous Region put forward a proposal that the three regions optimise all Shangri-la']
# ['full rounds , Zoe believes she would have aimed it at Daniel . ', 'She begs Lacy to help her escape soon , before she does something rash . ', 'Notes ', 'The Ghost in the Machine is a non-fiction work by Arthur Koestler . ', "Among its themes are man 's tendency towards self-destruction , and that the more primitive parts of the brain ( the `` ghost in the machine '' ) can override"]
# ['swell . ', '2005/02/15 : Rabbit Redux , John Updike : ', 'I liked it better than the first book in this series . ', 'Definitely some good stuff here . ', '2005/01/21 : ', 'God Knows , Joseph Heller : ', 'Interesting and worth reading . ', 'Do/did most middle-class Americans really live like this ? ', '2005/10/22 : ', 'Zuckerman Bound , Philip Roth : ', 'More good stuff . ', '2005/10/18 : Lila']
# ['government . ', "Not only are Glenn Beck and Sean Hannity preaching a political gospel with religious zeal , but millions of Americans are also devoted followers of Rush Limbaugh , Bill O'Reilly , Michael Savage , Neal Boortz , Ann Coulter , Laura Ingraham , Mark Levin and a host of other conservative radio talk show hosts across the country . ", 'In a poll']
# ['American business magnate , philanthropist , author , and is chairman of Microsoft , the software company . ', 'Gates was born in Seattle , Washington , to William H. Gates , Sr . and Mary Maxwell Gates , of English , German , and Scotch-Irish descent . ', 'His family was upper middle class ; his father was a prominent lawyer , his mother served on']
# ['to fourteen . ', "Evidently there 's only so much the cinema-going sensibility can stand . ", "I read a review which suggested that this book represents the flipside to Lady Chatterley 's Lover , and I think there 's a lot of truth in that : ", "Lawrence 's book uses some ripe language and bluntly carnal descriptions of the sexual act to tell a story that is , at its heart , pretty conventional"]
# ['for one hundred and eighty-days in Susa to show off the vast wealth of his kingdom and the beauty and wonder of his majesty . ', 'The King Ahasuerus ordered his queen , Vashti to come before him and his guests wearing her crown to show off how beautiful she was . ', "But when the king 's command was delivered , Queen"]
# ['and themes but a simple enough plot and humor to appeal to children . ', 'It made notable use of popular music ; the soundtrack includes music by Smash Mouth , Eels , Joan Jett , The Proclaimers , Jason Wade , The Baha Men , and John Cale ( covering Leonard Cohen ) . ', 'During June 2008 , the American Film Institute']
# ['gazes at the enormity , the detail , and craftsmanship . ', 'Inside the Cathedral of Málaga ', 'The north tower rises 84 meters and is the second-highest cathedral in Andalusia , behind the Giralda of Seville . ', 'The south tower is unfinished . ', 'There are disputes on where the funds disappeared to , but because it is unfinished , the Cathedral has been nicknamed']
# ['$ 100,000 when she stopped trading after ten months . ', '[ 91 ] The couple also began their ill-fated investment in the Whitewater Development Corporation real estate venture with Jim and Susan McDougal at this time . ', '[ 90 ] On February 27 , 1980 , Rodham gave birth to a daughter , Chelsea , her only child . ', 'In November 1980 , Bill']
# ['serious , music-based segments , including : The Million Dollar Band : ', 'This was a jam-session segment , airing from 1980 through 1988 , composed of the following all-star musicians : Chet Atkins , Boots Randolph , Roy Clark , Floyd Cramer , Charlie McCoy , Danny Davis , Jethro Burns , and Johnny Gimble . ', 'A singer-songwriter segment , where one']
# ["Hot Fuzz 's Simon Pegg and Nick Frost ( both of whom are prolific Twitter users out of interest ) . ", "The film co-stars Jason Bateman , Kristen Wiig , Bill Hader and Sigourney Weaver , features the voice of Seth Rogen as the title character , and is directed by Superbad 's Greg Mottola ( instead of Pegg"]
# ['Goldman Sachs International ( a registered UK broker-dealer , a subsidiary of Goldman Sachs ) . ', 'Until June 2009 he was non-executive chairman of BP being replaced by Carl-Henric Svanberg formely chief executive officer of Ericsson . ', 'Sutherland was a director of the Royal Bank of Scotland Group until he was asked to leave the board when it had to be']
# ['he despises in a rape trial . ', "But if he does n't do it , the judge will have him disbarred . ", 'Directed by Norman Jewison . ', 'Written by Valerie Curtin and Barry Levinson . ', 'This man needs the best lawyer in town . ', 'But the problem is ... ', 'he is the best lawyer in town . ', 'Contents 1 ', 'Arthur Kirkland 2']
# ['could not happen . ', 'A priori arguments for this reason could never prove the existence of God . ', 'A posteriori arguments have been criticized by Hume , Kant , Mill , Edwards and many others to show that this argument is not a proof of the existence of God . ', 'I intend to use the Bible']
# ['a Hurricane replica . ', "Of the parks along Windsor 's waterfront , the largest is the five-kilometre ( three mile ) stretch overlooking the Detroit skyline . ", 'It stretches from the Ambassador Bridge to the Hiram Walker Distillery . ', 'The western portion of the park contains the Odette Sculpture Park which features over 30 large-scale contemporary sculptures for public viewing , along with the']
# ['has been the home of numerous writers , musicians , artists , and actors , including Bob Dylan , Virgil Thomson , Charles Bukowski , Janis Joplin , Leonard Cohen , Patti Smith , Iggy Pop , Jobriath , and Larry Rivers . ', 'Though the Hotel Chelsea no longer accepts new long-term residencies , the building is still home']
# ['body-mapped subject . ', 'A bedroom that comes to life with the story of Peter Pan . ', "A touchscreen coffee table containing an interactive original copy of Lewis Carroll 's Alice 's Adventures Under Ground . ", 'A kitchen featuring a countertop voice-activated cookbook , an internet-connected bulletin board , and Siemens appliances , including the Liftmatic Oven . ', 'Rock Band and video games in']
# ['Alabama , and in the meantime her husband is treasoning her with a porn star , Candy Suxxx . ', 'This is believed to be a reference to Jacqueline Kennedy , the wife of former US President John F. Kennedy and his womanizing habits . ', 'v • g • d • e Grand Theft Auto : ', 'Vice City characters Protagonist Tommy Vercetti Major']
# ['] Werner Herzog , [ 134 ] Stanley Kubrick , [ 135 ] David Lean , [ 136 ] Sidney Lumet , [ 137 ] Roman Polanski , [ 138 ] Martin Scorsese , [ 139 ] Francois Truffaut , [ 140 ] David Lynch [ 141 ] and Zhang Yimou . ', '[ 142 ] ', "Subsequently , Spielberg 's movies"]
# ['Wiltshire Wales Pembrokeshire Literary Festivals & Events Get Listed ! ', 'Derbyshire Peveril Castle Market Place , Castleton , Derbyshire , S33 8WQ Peveril Castle was the setting for the novel Peveril of the Peak by Sir Walter Scott . ', 'www.english-heritage.org.uk Hardwick Hall Doe Lea , Chesterfield , Derbyshire , S44 ', '5QJ ', 'The stunning Hardwick Hall , maintained by the National Trust , was used as Malfoy']
# ['are the architects of that process . ', "In the last couple of months I read a couple of books that mention the term `` memory palace '' - ", "Daniel J. Boorstin 's history book ", "The Discoverers ( a personal favorite ) , and Salman Rushdie 's The Enchantress of Florence . ", 'What an evocative , romantic term , I thought . ', "Also called `` method of loci '' , a"]
# ['he held the detainees . ', 'Even the Attorney General ', '’ s ', 'Office requested the support of the Mexican army , so the military group stationed in the street Henry Dunant and Miguel de Cervantes was mobilized to guard the place . ', 'He noted that along with ‘ ', 'The thousand loves ’ , three other men were arrested during the operation that led the']
# ['2 , and 3 Meqabyan ( no relation to the Books of Maccabees ) . ', 'Some Syriac churches accept the Letter of Baruch as scripture . ', 'Christian Scientists The Bible Science and Health with Key to the Scriptures by Mary Baker Eddy . ', "This textbook , along with the Bible , serves as the permanent `` impersonal pastor '' of the church . ", 'Gnosticism Nag Hammadi library and other Gnostic texts ( not']
# ['rather different light on the issue : …it is now recognized that streets have social and recreational functions which are severely impaired by car traffic . ', 'The Livable Streets study by Donald Appleyard ( 1981 ) found that residents of streets with light traffic had , on average , three more friends and twice as many acquaintances as the people on']
# ['when he was 29 , she 15 . ', 'Married until her death in 1981 . ', 'He died 13 days afterward . ', 'Chris Robinson and Kate Hudson , 13 years Artie Shaw and Ava Gardner , 12 years . ', 'Married from 1945 to 1946 . ', 'Shawn `` Jay-Z `` Carter and Beyonce Knowles , 12 years . ', 'William H. Macy and Felicity Huffman']
# ['Ideal Husband by Jason T. Kocher August 15th , 2009 - Culture » Film and TV ', '» I am , on a regular occasion , obsessed with both John Astin and Patty Duke . ', 'I loved both of their most famous roles , John Astin as Gomez Addams on The Addams Family and Patty Duke as Patty and Cathy']
# ['of the great contributers to human culture . ', 'It was established in 1804 by Napoleon I and the graves of Oscar Wilde , Geroges Bizet , Gertrude Stein and Alice B. Toklas , Amedeo Modigliani , Marcel Proust , Jean-François Lyotard , Joseph Fourier , Edith Piaf , Paul Éluard -- - K ', 'i have to stop but']
# ['particularly appropriate as a show of support given its history . ', 'It was invented by Raffaele Esposito , a Neapolitan pizzaiolo , to commemorate a visit of King Umberto I and Queen Margherita of Savoy . ', 'The pizza was designed as an edible symbol , with the white of the mozzarella , the red of the tomato sauce , and the green of']
# ["that `` Lacedemonia [ meaning Sparta ] , [ was ] the noblest and best city governed that ever was '' . ", 'He commended it as a model for England . ', 'The Swiss-French philosopher Jean-Jacques Rousseau contrasted Sparta favourably with Athens in his Discourse on the Arts and Sciences , arguing that its austere constitution was preferable to the more cultured nature of Athenian life . ', 'Sparta was also used as a model of social']
# ['whom are also descendants of Hussaini Brahmins and mourn the death of Imam Hussain . ', 'There is also a significant migrant population of Bhumihars in Mauritius , Suriname , Trinidad and Tobago , Guyana and others . ', 'Bhumihars are commonly called Babhans which is the Pali word for Brahmins and is used to refer to Brahmins in Buddhist']
# ['he is a ghost ? ', "For more info about this book , visit the author 's official site at http : //www.jessicaverday.com/ or her blog at http : //jessicaverday.blogspot.com/ . ", 'Based on The Legend of Sleepy Hollow by Washington Irving . ', 'More YA books : Beautiful Creatures , Beautiful Darkness ( Caster Chronicles ) ', 'Nevermore ( Nevermore ) ', 'Evermore , Blue Moon ', '( The Immortals ) Fallen , Torment , Passion']
# ["for surveillance by Mondas ' Central Committee . ", "The creatures occasionally go wild , chewing on power sources , and must be rounded up by a `` mat-catcher . '' ", 'In the Past Doctor Adventures novel Illegal Alien by Mike Tucker and Robert Perry , set in the 1940s , the Cybermen create cybermats by cyber-converting local animals like cats or birds , possibly because of lack of']
# ['legendary Monterey Jazz Festival 12 times , spanning from 1959 thru 1993 , sharing the stage with jazz greats such as Sarah Vaughan , Dianne Reeves , Thelonious Monk , Oscar Peterson , Miles Davis , Cal Tjader , Carmen McRae , Herbie Hancock , Nat Adderley , and Dizzy Gillespie . ', 'During the 1980s Williams appeared']
# ['on 07.08.2010 12:00 p.m . ', 'The next production of the PCPA Theaterfest will be the mega-hit , harbinger of a new , uniquely American sensibility in musical theater , West Side Story , with a book by Arthur Laurents , music by Leonard Bernstein , lyrics by Stephen Sondheim and — in 1957 — choreography by Jerome Robbins . ', 'The PCPA production is directed']
# ['determine at-large ( non-conference winning ) teams to complete the field of 68 teams , and , to seed the field by ranking all teams from first through sixty-eighth . ', "ESPN 's Joe Lunardi is the inventor of the term `` bracketology '' , starting first as the owner and editor of the Blue Ribbon College Basketball Yearbook and ending up as"]
# ['BlueTales » ', 'JetBlue » ', 'Celebrity Jetters ', 'JetBlue Blog JetBlue June 24 , 2010 ', 'Celebrity Jetters Airport Operations Crewmember Renee had the pleasure of meeting NBA star , Grant Hill , and his wife Tamia , a six-time Grammy Award-nominated Canadian-American R & B/Hip Hop recording artist , and record producer . ', 'Grant is an NBA Player who early in his career played for']
# ['Nolan was born in Blackpool , Lancashire , England . ', 'Friday , March 12 , 1965 - Chechen Torch singer and actress Liza Umarova was born in Almaty , Kazakh Soviet Socialist Republic , Soviet Union . ', "From Edna Whitcomb Harrison ( '65 ) of VA - 03/11/10 - `` birthday information '' : Carol , Please add these to your birthday lists :"]
# ['enroll at Princeton but never received their graduate catalog as women there were not allowed in the graduate astronomy program until 1975 . ', 'She applied to Cornell University , where she studied physics under Philip Morrison , Richard Feynman , and Hans Bethe . ', 'There she earned a M.A . in 1951 . ', 'Then in 1954 at Georgetown University she earned a Ph.D .']
# ["the Qur'an ( 74:30 ) . ", "The epilogue of J. K. Rowling 's Harry Potter and the Deathly Hallows is titled `` Nineteen Years Later . '' ", "Jodi Picoult 's first New York Times Best Seller was titled Nineteen Minutes . ", 'In television Edit `` Hey Nineteen `` was the 88th episode of Wings , named after the Steely Dan song. ', '`` Deus Ex Machina']
# ['It With You ( 1938 ) was one of the films that brought Stewart widespread attention In 1938 , Stewart had a brief , tumultuous romance with Hollywood queen Norma Shearer , whose husband , Irving Thalberg , head of production at MGM , had died two years earlier . ', 'Stewart began a successful partnership with director Frank Capra in 1938 , ', 'when he']
# ['attack on the employees there , ” said Jim Pugh of Rebuild the Dream . ', '“ ', 'We ’ re trying to let them know what ’ s happening. ', '” ', 'The ad that targets Freddie Mac employees features a small picture of the face of CEO Charles Haldeman , and the message , “ Freddie Mac did what ? ? ? ? ', 'Freddie Mac is evicting a former Marine who ’ s been trying to pay his mortgage . ', 'Tell CEO Haldeman']
# ['a discussion with Deepa Iyer , Executive Director of South Asian Americans Leading Together ( SAALT ) , co-sponsored a talk with celebrated Indian actress and social activist Shabana Azmi and scriptwriter Javed Akhtar , helped coordinate minority student recruiting , and hosted various movie nights and group potlucks . ', 'In its second year , SALSA held a panel on diversity in']
# ["auctions guide newsletters visualserver Arriving soon , Terry Richardson 's Bright Shiny Morning : Wives , Wheels , Weapons , released by JMc & GHB Editions . ", "Companion to the 2008 James Frey novel Bright Shiny Morning , Richardson 's artist book reprints several chapters from Frey 's complex novel alongside Richardson 's responsive photo-essays . ", 'Frey , best known as the author publicly slammed for fictionalizing']
# ['so many of America ’ s avant-garde artists in the mid-20th century including besides some of these poets , notable alumni include Fielding Dawson , Michael Rumaker , Robert Rauschenberg , Dorothea Rockburne , Susan Weil , John Chamberlain , Ray Johnson , Kenneth Noland , Oli Sivhonen , Joel Oppenheimer , Jonathan Williams , Ruth Asawa , Robert De Niro ,']
# ["much-overlooked kind of children 's literature is work written by children and young teens , such as The Young Visiters by Daisy Ashford ( aged nine ) or the juvenilia of Jane Austen , written to amuse brothers and sisters . ", 'Anne Frank wrote a novel and many short stories in addition to her diary . ', 'Barbara Newhall Follett wrote']
# ['meet weekly during the school year to solve and discuss puzzles . ', 'Each spring it organizes a campuswide crossword tournament . ', 'Other schools with crossword clubs include Harvard , Yale , Princeton and Texas Christian . ', 'Brown ', '’ ', 's club , though , has the most members with published puzzles . ', 'This New York Times crossword seemed fairly easy for']
# ['actually , I changed my topic like five thousand times , ', 'my mind wasn ', '’ ', 't really on it . ', 'In the end I decided to write about this composer Luciano Berio . ', 'He worked with Cathy Berberian doing strange vocal pieces . ', 'I ’ m writing about the relationship of language and speech in relation to music and songs , and also glossolalia and Tourette ', '’ s Syndrome .']
# ["Kimmel 's gay farm featuring Rosie the Rhinoceros ", 'TWITTER REPLACING PUBLICISTS , AMERICAN IDOL RECAP AND GARDENING Rosie talked about how much she respects the fact that Jim Carrey and Jenny McCarthy decided to tell the public that their relationship ended on twitter recently . ', 'She thought there was something great about it and sees twitter as an']
# ['not on meeting people . ', 'Pownce is centered around sharing messages , files , events , and links with already established friends . ', 'It was created and currently maintained by Digg founder Kevin Rose , with Leah Culver , Daniel Burka , and Shawn Allen . ', 'Since the launch on June 27 , 2007 new members can only join by']
# ['campaign , titled “ Catwalk the World : Fashion for Food. ', '” , began in Nigeria in April 2006 and recently staged an event in Ghana which brought celebrities like Damon Dash , his wife , designer Rachel Roy , and Ghanaian-born , London -based designer Ozwald Boateng . ', "The campaign 's goal is to raise money towards halving the number of hungry people in the"]
# ['state . ', 'History of LINUX® When UNIX was young ', '( UNIX Version 6 ) , ', 'the source code was widely available , under AT & T license , and frequently studied . ', 'John Lions , of the University of New South Wales in Australia , even wrote a little booklet describing its operation , line by line ( Lions , 1996 ) . ', 'This booklet was used ( with permission of AT & T ) as a']
# ['and Walter Matthau . ', "It is Presley 's fourth movie ( the third and last filmed in black & white ) , and adapted from the 1952 novel by Harold Robbins , A Stone for Danny Fisher . ", 'This ', 'Poster is an Reproduction Poster of Elvis Presley at The International Hotel Banner ', 'Poster back in 1969 . ', 'I invite you to view the other']
# ['to local families and businesses . ', "Dixie Lee 's latest demo `` Soulmates '' , speaks about legendary country music couples `` Keith & Lorrie - Johnny & June - George & Tammy - Loretta & Doo , '' who despite their challenges in life , `` gave the world their songs '' . ", "Lee 's Traditional Country vocal style blended with a strong"]
# ['extra-curricular fucking… because I would love him and at the end of the day , he would love me . ', 'We would be some urban version of Larry and Althea Flynt . ', 'I was ready for that . ', 'And in the meantime , until we exchange vows… ', 'I would have some fun', '… ', 'A couple of days later , I ’ m']
# ['Mihan Productions . ', 'Over his career as an animator , Hoover worked on such shows as Fat Albert and the Cosby Kids , The Archie Show , Tarzan , Flash Gordon , He-Man and the Masters of the Universe , ', 'She-Ra : Princess of Power , The Super Friends , The Smurfs , Men in Black : The Series']
# ['Films , Books , Film Reviews , Movies Film Review : ', 'The Shawshank Redemption *', '*Remember , spoilers abound ! ', '*', '* A few years ago , I read a great novella by Stephen King , called Rita Hayworth and the Shawshank Redemption . ', 'I knew a movie had been made about it , and I knew that it was a really big deal , but I guess that all']
# ['90s Show : Film , Moment by Moment 1978 Friday , May 6 , 2011 Film , Moment by Moment 1978 Moment by Moment ', 'is a 1978 film starring John Travolta and Lily Tomlin . ', 'The film was written and directed by Jane Wagner . ', 'Plot John Travolta played his first romantic lead in this drama about an ill-fated May-September romance . ', 'Trisha ( Lily Tomlin ) is a wealthy']
# ['Assistant Secretary of Defense for Education ( 1972-1974 ) . ', '[ 53 ] Walter Harrington Ryle , III ', '– Epsilon Advisor – President of Northeast Missouri State Teachers College ( 1937-1967 ) . ', '[ 54 ', '] Walter Dill Scott – National Honorary – President of Northwestern University ( 1920 - 1939 ) . ', '[ 55 ] Charles A. Sevrinson – Alpha Lambda Acting President of North Dakota State University ( 1946 ) ; Dean of Men of North Dakota State']
# ['was re-hired but died before she could resume filming . ', 'Doris Day and James Garner were eventually cast in the roles originated by Irene Dunne and Cary Grant in My Favorite Wife . ', "Chuck Connors played the Randolph Scott role , replacing Tom Tryon , who 'd been cast in the Monroe version . ", "Following Monroe 's death in August 1962 , t he new version was released by"]
# [', was a Brigadier General in the 2 nd Infantry Regiment raised from Watertown , MA . ', 'A check on Google revealed a Wikipedia page about Charles Russell Lowell and Josephine Shaw Lowell . ', 'They apparently had a daughter , Carlotta Lowell . ', 'Josephine Lowell ( 1843-1905 ) became well known in New York City society circles . ', 'She died 12 October 1905 in']
# ['our suppliers in the USA needs to have their new motorhomes moved from the factory where they are built , in Indiana , to their bases in San Francisco , Denver , Las Vegas and Los Angeles . ', 'They offer rentals of the motorhomes at incredibly cheap rates , and you simply need to deliver them at']
# ['Aw , hot favorite after the huge success of The Little Nyonya , to the coveted title of Babe of the Year in the annual Flame Awards organised by The New Paper . ', "In an informal survey conducted by MediaCorp 's Branding and Promotion Vice-President Paul Chan , Rui En and Elvin Ng were voted as the Best On-Screen Couple in 2009 . ", 'Rui En and Elvin']
# [', and then watched a traditional Beijing opera performance . ', 'On April 29 , Lien gave a speech and answered questions from students and faculty in Peking University . ', 'He mentioned that both Hu Shih and former Taiwan University president Fu Sinian had graduated from Peking University , then worked at Taiwan University and spread liberalism there . ', '`` Therefore , in terms of']
# ['from reaching the embassy gates , and no injuries were reported . ', '[ 70 ] ', '[ 71 ] Iraq Reuters reported that hundreds protested against the film in Baghdad ‘ s Sadr City and in Basra . ', 'A smaller crowd protested in Najaf . ', 'Protesters burned American flags , chanted “ Death to America ” and called on the Iraqi government to expel the']
# ['September 8 , 1926 . ', 'While guests were waiting for Garbo to show up for a proposed double wedding ceremony - Garbo and Gilbert with the director King Vidor and his fiancee , actress Eleanor Boardman - Mayer allegedly made a crude remark about Garbo to the distraught Gilbert that caused him to fly into a rage and he physically attacked']
# ['in the couple is less than 18 , or in heterosexual relationships , the woman is more than 5 years older than the man . ', '40 or More J. Howard Marshall and Anna Nicole Smith , 63 years . ', 'She was 26 and he was 89 . ', 'They married on June 27 , 1994 and the marriage lasted over a year . ', 'The']
# ['for Standish and monuments have been built in his memory . ', 'One of the best known depictions of Standish in popular culture was the 1858 book , The Courtship of Miles Standish by Henry Wadsworth Longfellow . ', 'Highly fictionalized , the story presents Standish as a timid romantic . ', 'It was extremely popular in the 19th century and played a significant role in']
# ['after his graduation from IIT Kharagpur . ', 'Kejriwal quit his job with Tata Steel in 1992 [ citation needed ] and spent some time working with Mother Teresa ‘ s Missionaries of Charity in Kolkata , the Ramakrishna Mission in the North-East India and Nehru Yuva Kendra . ', '[ 9 ] ', '[ 10 ] Kejriwal joined the Indian Revenue Service in 1995 . ', '[ 10 ]']
# ['Arago ( 1824 ) ', '[ French ] and implemented first by Walter Baily [ American ] . ', 'Nuclear Reactor : ', 'Quote : The first artificial nuclear reactor , Chicago Pile-1 , was constructed at the University of Chicago by a team led by Enrico Fermi in 1942 . ', 'I see , so Italy gets the credit because Fermi was Italian ? ', "I think you 're more proving MY point than yours . ", 'Microprocessor : ', 'Quote : ', 'The']
# ["March 2001 , christened by Reagan 's wife Nancy the same day , and commissioned on 12 July 2003 , with Captain J. W. Goodwin in command . ", "Vice President Dick Cheney and Lynne Cheney were both present at the ceremony , as well as Nancy Reagan , who gave the ship 's crew the traditional first order as an active unit of"]
# ['Feist . ', 'It was a reasonably good year for music , but you mostly can ’ t tell that at all from this bloated out of touch spectacle . ', 'ey Louis Prima ! ', 'Wow Keely Smith looking good ! ', 'Is Kid Rock going to put out a jazz-rap album ? ', 'Because he should not . ', 'Although if you put saxophones on a record it']
# ["of 1759 , a decisive victory of British and Prussian forces over France in the Seven Years ' War . ", 'The town is about 75 km away from Hanover , from where the House of Hanover comes—the dynasty which ruled the United Kingdom from 1714 until 1901 . ', 'Minden saw service during the War of 1812 in the Chesapeake Bay . ', 'Some']
# ["won praise playing Christine Mannon ( `` defiantly cool , camp and skittish '' , Evening Standard ; `` glows with mature sexual allure '' , Daily Telegraph ) in a revival of Eugene O'Neill 's Mourning Becomes Electra directed by Howard Davies . ", '`` This production was one of the best experiences of my professional life , The play was four and a half hours']
# ['in the Holy Land Posted by Taufiq Rahim | 4:52 AM We had the chance at the Dubai School of Government last night to host Adam Shapiro and Huwaida Arraf , co-founders of the non-violent resistance movement in the Occupied Territories , the International Solidarity Movement ( ISM ) ; Arraf also chairs the Free Gaza organization that was responsible']
# ['and possibly the first wife of Italian fascist dictator Benito Mussolini . ', 'Early life Ida Dalser was born in Sopramonte , a village near Trento , the capital of the ethnically Italian Trentino region , at that time within the borders of the Tyrol region Austro-Hungarian Empire . ', 'The daughter of the village mayor , she was sent to Paris']
# ['project of the United States Federal Bureau of Investigation . ', '[ 3 ] ', 'In January 1970 , Cox was invited to speak to several dozen guests of composer Leonard Bernstein and his wife Felicia at their penthouse apartment in the wealthy Upper East Side neighborhood of Manhattan . ', 'The gathering was an effort to raise funds for the defense']
# ['Johansen , the son of a Norwegian-American , is an American rock , protopunk , blues and pop singer , as well as a songwriter and actor . ', 'He was a member of the protopunk band The New York Dolls and also achieved commercial success under the pseudonym Buster Poindexter . ', 'Richard Matheson , the son of Norwegian immigrants , is']
# ["The interviews feature proponents of a wide spectrum of approaches , from relatively 'straight ' documentaries ( Fernando Birri , Helena Solberg-Ladd ) , through mixed documentary-fiction modes ( Nelson Pereira dos Santos ) , to tropical allegory ( Glauber Rocha ) , and absurdist reflexivity ( Raul Ruiz ) . ", "The third section supplements the comments by filmmakers with details of work 'behind the scenes , ' i.e. , the"]
# ['22,000 years in the future , an atomic weapon with an adjustable radiation yield called a Wikipedia : stone burner is used in an assassination attempt . ', "[ 1 ] In Wikipedia : Kurt Vonnegut 's book Wikipedia : Deadeye Dick ( 1982 ) , an American town , Midland City , Ohio , is depopulated because a neutron bomb detonates on the freeway . ", 'All structures are intact , the townspeople are buried']
# ['16th 2011 ', 'Posted in : ', 'Lifestyle no comments Do you like this story ? ', 'Miranda Lambert and Blake Shelton got married on Saturday ( countrychorus.wordpress.com ) Happy news for Miranda Lambert and Blake Shelton opted for a wedding ceremony that was held at the Don Strange Ranch in Boerne , Texas , north of San Antonio . ', 'The event took place on']
# ['dreams ', 'After early successes in space , much of the public saw intensive space exploration as inevitable . ', "Those aspirations are remembered in science fiction such as Arthur C. Clarke 's A Fall of Moondust and also 2001 : ", "A Space Odyssey , Roald Dahl 's Charlie and the Great Glass Elevator , Joanna Russ 's 1968 novel Picnic on Paradise , and"]
# ['Harken Energy Corporation , of which he was a director . ', 'The sale raised the issue of whether it constituted illegal insider trading . ', "In House of Bush , House of Saud , Craig Unger asserts that at the time of Bush 's sale , Harken Energy `` was expected to run out of money in just three days '' ( ", 'p. 123 ) . ', 'In a']
# ['including Wiktionary ( a wiki dictionary ) , Wikibooks ( textbooks ) , and others , and owns all of their domain names . ', 'Previously , the site was hosted on the servers of Bomis , Inc. , a company mostly owned by Jimmy Wales . ', 'With the announcement of the Wikimedia Foundation on June 20 , 2003 , the ownership of all domain names was transferred to the Foundation . ', 'The site']
# ['and the study of myth . ', "He describes his writing and speaking style as `` mind- jazz on ancient texts '' . ", 'He is an astute reader of science , social science , history , and literature . ', 'He is the founder of the Lindisfarne Association . ', 'Tags : Politics , culture , economics , William Irwin Thompson ,']
# ['Soviet Union . ', "The affair was terminated by the government 's Cabinet Secretary , Sir Norman Brook , who spoke to Profumo on the advice of Sir Roger Hollis , the head of MI5 . ", 'On 9 August 1961 , Profumo wrote to Keeler advising her he could no longer see her . ', 'However , when Johnny Edgecombe was arrested for shooting']
# ['of various cartoon specials on CBS -- including Peanuts -- throughout the 1960s and 1970s . ', "The title of this 'toon is based on the book , `` The Best Christmas Pageant Ever '' , by Barbara Robinson . ", 'The plot has nothing in common except for the holiday theme , of course . ', 'The Peter Frampton album Homestar finds at the concession stand is']
# [', a Mesopotamian merchant and missionary , brought a mission to India in 345 AD . ', '[ 31 ] ', 'He brought 400 Christians from Baghdad , Nineveh , and Jerusalem to Kodungallur . ', 'He and his companion Bishop Joseph of Edessa sought refuge under King Cheraman Perumal from persecution of Christians by the Persian king Shapur II']
# ['system that providers , patients , and family can trust in communicating private information that should not be in the public domain . ', 'Jonathon is interviewed here by Robert Scoble of Rackspace . ', 'Care-Zone has both a desktop and a mobile app availble in iOS , or iPhone . ', 'The website uses https// a secured internet protocol . ', 'Care-zone allows']
# ['The ALBERT Inn @ ', 'Woodthorpe ', 'The Pub Sign A 23 year old Prince Albert , Consort to Queen Victoria . ', 'Painted in 1842 by Franz Xaver Winterhalter . ', 'The original is part of the Royal Collection . ', 'The Prince died in 1861 at']
# ['Army base : More than 30 people are injured in a car bomb explosion at the UK Army headquarters in Rheindahlen , West Germany . ', '1989 ', '– Stanley Pons and Martin Fleischmann announce cold fusion at the University of Utah . ', '1989 ', '– ', 'A 1,000-foot diameter Near-Earth asteroid misses the Earth by 400,000 miles . ', '1990 – Katelyn DePutter was born . ', 'Poker champion . ', '1990 –']
# ['on 20 Mar 2009 02:16 pm THE CONFUSING MERITS OF POORLY NAMED ', 'INSTITUTIONS ', 'A libertarian-leaning friend sends over this column by Uni Chicago Economists and Hoover Institute Fellows Gary Becker ( Nobel Laureate ! ) and Kevin Murphy , advocating a “ do no harm ” approach to the current crisis . ', 'Some smart dudes , about as articulate as it comes']
# ['is as beautiful and diverse as the landscape . ', "In northern India , Hindu 's flock to pilgramage centers such as Char Dham , Haridwar , Mathura , Allahabad and Varanasi . ", 'Buddhists travel in the footsteps of Siddhartha , and the Buddha working towards enlightenment by visiting the Mahabodhi Temple . ', "In Amritsar Sikh 's sojourn at"]
# ['Brooklyn by Garth Ennis , Jimmy Palmiotti and Mihailio Vukelic – ', 'it ', '’ s okay . ', 'The best comic book that I ’ ve read recently was the truly tearful Pride Of Baghdad by Brian K. Vaughan and Niko Henrichon . ', 'I borrowed a copy from my local public library . ', 'It was so good I may have to buy a copy or']
# ['of a tailor-to-the-stars in a comic city isn ’ t uncommon by any means ; the most famous one is probably Paul Giambi . ', '“ Batman in Nighttown ” , by Karen Haber and Robert Silverberg ', '– ', 'I ’ ve referred to this story before , with a costumed Bruce Wayne stalking an erstaz Batman through Gotham ', '’ s seedy nightclub district . ', 'It ', '’ s a quick read ,']
# ['son of King Robert III of Scotland and Annabella Drummond . ', 'King Robert III of Scotland , son of King Robert II of Scotland and Elizabeth Mure . ', 'King Robert II of Scotland , son of Marjorie Bruce and Walter Stewart , 6th High Steward of Scotland . ', 'Walter Stewart , 6th High Steward of Scotland , son of James']
# ["him `` a very nice letter of appreciation on State Department stationery '' . ", "The lyrics from another track , `` The Hula Hula Boys `` , were excerpted in Hunter S. Thompson 's 1983 book , The Curse of Lono . ", 'The Envoy was the first Zevon album to feature his son Jordan Zevon . ', 'After the disappointing reception for The Envoy , Zevon was']
# [', with a precursor in the League of the Rhine ) . ', "Napoleon was its `` protector . '' ", 'On 6 August , following an ultimatum by Napoleon , Francis II gave up his title of Emperor and declared the Holy Roman Empire dissolved . ', "In the years that followed , 23 more German states joined the Confederation ; Francis 's Habsburg dynasty would rule the remainder of the empire as Austria ."]

# %%
def extract_key_sents(data):
    key_sents = []
    for ex in data:
        m1 = ex.snippet[0].mention_1
        m2 = ex.snippet[0].mention_2
        text = build_text_from_snippet(ex.snippet[0])
        doc = nlp(text)
        for sent in doc.sents:
#             print(sent)
            if m1 in sent.string and m2 in sent.string:
                key_sents.append(sent)
                continue
                
    return key_sents

# %%
key_sents = extract_key_sents(train_data[:100])
print(type(key_sents[0]))
for sent in key_sents:
    for chunk in sent.noun_chunks:
        print(chunk.label_, chunk.text, chunk.root.text, chunk.root.dep_,
          chunk.root.head.text)
    for token in sent: 
        print(token.text, token.dep_, token.head.text, token.head.pos_,
              [child for child in token.children])
# Out:
# <class 'spacy.tokens.span.Span'>
# NP the death death pobj after
# NP his father father pobj of
# NP Mercer Mercer nsubj began
# NP an intense affair affair dobj began
# NP nineteen-year-old Judy Garland Garland pobj with
# NP she she nsubjpass engaged
# NP David Rose Rose dobj composer
# In prep began VERB [1941]
# 1941 pobj In ADP []
# , punct began VERB []
# shortly advmod after ADP []
# after prep began VERB [shortly, death]
# the det death NOUN []
# death pobj after ADP [the, of]
# of prep death NOUN [father]
# his poss father NOUN []
# father pobj of ADP [his]
# , punct began VERB []
# Mercer nsubj began VERB []
# began ROOT began VERB [In, ,, after, ,, Mercer, affair, engaged, .]
# an det affair NOUN []
# intense amod affair NOUN []
# affair dobj began VERB [an, intense, with]
# with prep affair NOUN [Garland]
# nineteen nummod year NOUN []
# - punct year NOUN []
# year npadvmod old ADJ [nineteen, -]
# - punct old ADJ []
# old amod Garland PROPN [year, -]
# Judy compound Garland PROPN []
# Garland pobj with ADP [old, Judy]
# while mark engaged VERB []
# she nsubjpass engaged VERB []
# was auxpass engaged VERB []
# engaged advcl began VERB [while, she, was, composer]
# to aux composer NOUN []
# composer xcomp engaged VERB [to, Rose]
# David compound Rose PROPN []
# Rose dobj composer NOUN [David]
# . punct began VERB []
# NP Latest activity activity nsubj is
# NP 4 Other Sweet-Treat Wikia Summary Summary appos activity
# NP a Sweet Adventure Edit Charlie Charlie pobj of
# NP the Chocolate Factory Factory conj Summary
# NP a 2005 film adaptation adaptation attr is
# NP the 1964 book book pobj of
# NP the same name name pobj of
# NP Roald Dahl Dahl pobj by
# Latest amod activity NOUN []
# activity nsubj is VERB [Latest, Summary]
# 4 nummod Summary PROPN []
# Other compound Summary PROPN []
# Sweet compound Wikia PROPN []
# - punct Wikia PROPN []
# Treat compound Wikia PROPN []
# Wikia compound Summary PROPN [Sweet, -, Treat]
# Summary appos activity NOUN [4, Other, Wikia, of, and, Factory]
# of prep Summary PROPN [Charlie]
# a det Charlie PROPN []
# Sweet compound Adventure PROPN []
# Adventure compound Charlie PROPN [Sweet]
# Edit compound Charlie PROPN []
# Charlie pobj of ADP [a, Adventure, Edit]
# and cc Summary PROPN []
# the det Factory PROPN []
# Chocolate compound Factory PROPN []
# Factory conj Summary PROPN [the, Chocolate]
# is ROOT is VERB [activity, adaptation, .]
# a det adaptation NOUN []
# 2005 nummod adaptation NOUN []
# film compound adaptation NOUN []
# adaptation attr is VERB [a, 2005, film, of]
# of prep adaptation NOUN [book]
# the det book NOUN []
# 1964 nummod book NOUN []
# book pobj of ADP [the, 1964, of, by]
# of prep book NOUN [name]
# the det name NOUN []
# same amod name NOUN []
# name pobj of ADP [the, same]
# by prep book NOUN [Dahl]
# Roald compound Dahl PROPN []
# Dahl pobj by ADP [Roald]
# . punct is VERB []
# NP Places Places nsubj claim
# NP Sichuan Sichuan pobj like
# NP Tibet Tibet conj Sichuan
# NP the real Shangri-La La nsubj was
# NP its territory territory pobj in
# Places nsubj claim VERB [like]
# like prep Places NOUN [Sichuan]
# Sichuan pobj like ADP [and, Tibet]
# and cc Sichuan PROPN []
# Tibet conj Sichuan PROPN []
# also advmod claim VERB []
# claim ROOT claim VERB [Places, also, was, .]
# the det La PROPN []
# real amod La PROPN []
# Shangri compound La PROPN []
# - punct La PROPN []
# La nsubj was VERB [the, real, Shangri, -]
# was ccomp claim VERB [La, in]
# in prep was VERB [territory]
# its poss territory NOUN []
# territory pobj in ADP [its]
# . punct claim VERB []
# NP The Ghost Ghost nsubj is
# NP the Machine Machine pobj in
# NP a non-fiction work work attr is
# NP Arthur Koestler Koestler pobj by
# The det Ghost PROPN []
# Ghost nsubj is VERB [The, in]
# in prep Ghost PROPN [Machine]
# the det Machine NOUN []
# Machine pobj in ADP [the]
# is ROOT is VERB [Ghost, work, .]
# a det work NOUN []
# non nmod - PUNCT []
# - punct fiction NOUN [non]
# fiction compound work NOUN [-]
# work attr is VERB [a, fiction, by]
# by prep work NOUN [Koestler]
# Arthur compound Koestler PROPN []
# Koestler pobj by ADP [Arthur]
# . punct is VERB []
# NP God Knows Knows ROOT Knows
# God compound Knows PROPN []
# Knows ROOT Knows PROPN [God, ,, Heller]
# , punct Knows PROPN []
# Joseph compound Heller PROPN []
# Heller npadvmod Knows PROPN [Joseph, :]
# : punct Heller PROPN []
# NP Glenn Beck Beck nsubj are
# NP Sean Hannity Hannity conj Beck
# NP a political gospel gospel dobj preaching
# NP religious zeal zeal pobj with
# NP millions millions nsubj are
# NP Americans Americans pobj of
# NP devoted followers followers attr are
# NP Rush Limbaugh Limbaugh pobj of
# NP other conservative radio talk show hosts hosts pobj of
# NP the country country pobj across
# Not preconj are VERB [only]
# only advmod Not ADV []
# are aux preaching VERB [Not, Beck]
# Glenn compound Beck PROPN []
# Beck nsubj are VERB [Glenn, and, Hannity]
# and cc Beck PROPN []
# Sean compound Hannity PROPN []
# Hannity conj Beck PROPN [Sean]
# preaching ROOT preaching VERB [are, gospel, ,, but, are]
# a det gospel NOUN []
# political amod gospel NOUN []
# gospel dobj preaching VERB [a, political, with]
# with prep gospel NOUN [zeal]
# religious amod zeal NOUN []
# zeal pobj with ADP [religious]
# , punct preaching VERB []
# but cc preaching VERB []
# millions nsubj are VERB [of]
# of prep millions NOUN [Americans]
# Americans pobj of ADP []
# are conj preaching VERB [millions, also, followers, ,, O'Reilly, .]
# also advmod are VERB []
# devoted amod followers NOUN []
# followers attr are VERB [devoted, of]
# of prep followers NOUN [Limbaugh]
# Rush compound Limbaugh PROPN []
# Limbaugh pobj of ADP [Rush]
# , punct are VERB []
# Bill compound O'Reilly PROPN []
# O'Reilly npadvmod are VERB [Bill, ,, Savage]
# , punct O'Reilly PROPN []
# Michael compound Savage PROPN []
# Savage conj O'Reilly PROPN [Michael, ,, Boortz]
# , punct Savage PROPN []
# Neal compound Boortz PROPN []
# Boortz conj Savage PROPN [Neal, ,, Coulter]
# , punct Boortz PROPN []
# Ann compound Coulter PROPN []
# Coulter conj Boortz PROPN [Ann, ,, Ingraham]
# , punct Coulter PROPN []
# Laura compound Ingraham PROPN []
# Ingraham conj Coulter PROPN [Laura, ,, Levin]
# , punct Ingraham PROPN []
# Mark compound Levin PROPN []
# Levin conj Ingraham PROPN [Mark, and, host]
# and cc Levin PROPN []
# a det host NOUN []
# host conj Levin PROPN [a, of]
# of prep host NOUN [hosts]
# other amod hosts NOUN []
# conservative amod hosts NOUN []
# radio compound show NOUN []
# talk compound show NOUN []
# show compound hosts NOUN [radio, talk]
# hosts pobj of ADP [other, conservative, show, across]
# across prep hosts NOUN [country]
# the det country NOUN []
# country pobj across ADP [the]
# . punct are VERB []
# NP Gates Gates nsubjpass born
# NP Seattle Seattle pobj in
# NP Washington Washington appos Seattle
# NP William H. Gates Gates pobj to
# NP Sr Sr appos Gates
# NP Mary Maxwell Gates Gates conj Sr
# NP English English pobj of
# NP descent descent pobj of
# Gates nsubjpass born VERB []
# was auxpass born VERB []
# born ROOT born VERB [Gates, was, in, ,, to, .]
# in prep born VERB [Seattle]
# Seattle pobj in ADP [,, Washington]
# , punct Seattle PROPN []
# Washington appos Seattle PROPN []
# , punct born VERB []
# to prep born VERB [Gates]
# William compound Gates PROPN []
# H. compound Gates PROPN []
# Gates pobj to ADP [William, H., ,, Sr, ,, of]
# , punct Gates PROPN []
# Sr appos Gates PROPN [., and, Gates]
# . punct Sr PROPN []
# and cc Sr PROPN []
# Mary compound Gates PROPN []
# Maxwell compound Gates PROPN []
# Gates conj Sr PROPN [Mary, Maxwell]
# , punct Gates PROPN []
# of prep Gates PROPN [English, descent]
# English pobj of ADP [,, German]
# , punct English PROPN []
# German conj English PROPN [,, and, Irish]
# , punct German ADJ []
# and cc German ADJ []
# Scotch compound Irish ADJ []
# - punct Irish ADJ []
# Irish conj German ADJ [Scotch, -]
# descent pobj of ADP []
# . punct born VERB []
# NP The King Ahasuerus Ahasuerus nsubj ordered
# NP his queen queen dobj ordered
# NP Vashti Vashti nsubj come
# NP him him pobj before
# NP his guests guests conj him
# NP her crown crown dobj wearing
# NP she she nsubj was
# The det Ahasuerus PROPN []
# King compound Ahasuerus PROPN []
# Ahasuerus nsubj ordered VERB [The, King]
# ordered ROOT ordered VERB [Ahasuerus, queen, come, .]
# his poss queen NOUN []
# queen dobj ordered VERB [his, ,]
# , punct queen NOUN []
# Vashti nsubj come VERB []
# to aux come VERB []
# come ccomp ordered VERB [Vashti, to, before, wearing]
# before prep come VERB [him]
# him pobj before ADP [and, guests]
# and cc him PRON []
# his poss guests NOUN []
# guests conj him PRON [his]
# wearing advcl come VERB [crown, show]
# her poss crown NOUN []
# crown dobj wearing VERB [her]
# to aux show VERB []
# show advcl wearing VERB [to, off, was]
# off prt show VERB []
# how advmod beautiful ADJ []
# beautiful acomp was VERB [how]
# she nsubj was VERB []
# was ccomp show VERB [beautiful, she]
# . punct ordered VERB []
# NP It It nsubj made
# NP notable use use dobj made
# NP popular music music pobj of
# NP the soundtrack soundtrack nsubj includes
# NP music music dobj includes
# NP Smash Mouth Mouth pobj by
# NP Eels Eels conj Mouth
# NP Joan Jett Jett conj Eels
# NP The Proclaimers Proclaimers conj Jett
# NP Jason Wade Wade conj Proclaimers
# NP The Baha Men Men conj Wade
# NP John Cale Cale conj Men
# NP Leonard Cohen Cohen dobj covering
# It nsubj made VERB []
# made ccomp includes VERB [It, use]
# notable amod use NOUN []
# use dobj made VERB [notable, of]
# of prep use NOUN [music]
# popular amod music NOUN []
# music pobj of ADP [popular]
# ; punct includes VERB []
# the det soundtrack NOUN []
# soundtrack nsubj includes VERB [the]
# includes ROOT includes VERB [made, ;, soundtrack, music, .]
# music dobj includes VERB [by, covering]
# by prep music NOUN [Mouth]
# Smash compound Mouth PROPN []
# Mouth pobj by ADP [Smash, ,, Eels]
# , punct Mouth PROPN []
# Eels conj Mouth PROPN [,, Jett]
# , punct Eels PROPN []
# Joan compound Jett PROPN []
# Jett conj Eels PROPN [Joan, ,, Proclaimers]
# , punct Jett PROPN []
# The det Proclaimers PROPN []
# Proclaimers conj Jett PROPN [The, ,, Wade]
# , punct Proclaimers PROPN []
# Jason compound Wade PROPN []
# Wade conj Proclaimers PROPN [Jason, ,, Men]
# , punct Wade PROPN []
# The det Men PROPN []
# Baha compound Men PROPN []
# Men conj Wade PROPN [The, Baha, ,, and, Cale]
# , punct Men PROPN []
# and cc Men PROPN []
# John compound Cale PROPN []
# Cale conj Men PROPN [John]
# ( punct covering VERB []
# covering acl music NOUN [(, Cohen, )]
# Leonard compound Cohen PROPN []
# Cohen dobj covering VERB [Leonard]
# ) punct covering VERB []
# . punct includes VERB []
# NP The north tower tower nsubj rises
# NP the second-highest cathedral cathedral attr is
# NP Andalusia Andalusia pobj in
# NP the Giralda Giralda pobj behind
# NP Seville Seville pobj of
# The det tower NOUN []
# north compound tower NOUN []
# tower nsubj rises VERB [The, north]
# rises ROOT rises VERB [tower, meters, and, is, .]
# 84 nummod meters NOUN []
# meters npadvmod rises VERB [84]
# and cc rises VERB []
# is conj rises VERB [cathedral]
# the det cathedral NOUN []
# second advmod highest ADJ []
# - punct highest ADJ []
# highest amod cathedral NOUN [second, -]
# cathedral attr is VERB [the, highest, in, ,, behind]
# in prep cathedral NOUN [Andalusia]
# Andalusia pobj in ADP []
# , punct cathedral NOUN []
# behind prep cathedral NOUN [Giralda]
# the det Giralda PROPN []
# Giralda pobj behind ADP [the, of]
# of prep Giralda PROPN [Seville]
# Seville pobj of ADP []
# . punct rises VERB []
# NP The couple couple nsubj began
# NP their ill-fated investment investment dobj began
# NP the Whitewater Development Corporation real estate venture venture pobj in
# NP Jim Jim pobj with
# NP Susan McDougal McDougal conj Jim
# NP this time time pobj at
# [ punct 91 NUM []
# 91 meta began VERB [[, ]]
# ] punct 91 NUM []
# The det couple NOUN []
# couple nsubj began VERB [The]
# also advmod began VERB []
# began ROOT began VERB [91, couple, also, investment, at, .]
# their poss investment NOUN []
# ill advmod fated VERB []
# - punct fated VERB []
# fated amod investment NOUN [ill, -]
# investment dobj began VERB [their, fated, in]
# in prep investment NOUN [venture]
# the det venture NOUN []
# Whitewater compound Development PROPN []
# Development nmod Corporation PROPN [Whitewater]
# Corporation nmod venture NOUN [Development]
# real amod estate NOUN []
# estate compound venture NOUN [real]
# venture pobj in ADP [the, Corporation, estate, with]
# with prep venture NOUN [Jim]
# Jim pobj with ADP [and, McDougal]
# and cc Jim PROPN []
# Susan compound McDougal PROPN []
# McDougal conj Jim PROPN [Susan]
# at prep began VERB [time]
# this det time NOUN []
# time pobj at ADP [this]
# . punct began VERB []
# NP a jam-session segment segment attr was
# NP the following all-star musicians musicians pobj of
# NP Chet Atkins Atkins appos musicians
# NP Boots Randolph Randolph conj Atkins
# NP Roy Clark Clark conj Randolph
# NP Floyd Cramer Cramer conj Clark
# NP Charlie McCoy McCoy conj Cramer
# NP Danny Davis Davis conj McCoy
# NP Jethro Burns Burns conj Davis
# NP Johnny Gimble Gimble conj Burns
# This nsubj was VERB []
# was ROOT was VERB [This, segment, ,, airing, composed, .]
# a det segment NOUN []
# jam compound session NOUN []
# - punct session NOUN []
# session compound segment NOUN [jam, -]
# segment attr was VERB [a, session]
# , punct was VERB []
# airing advcl was VERB [from, ,]
# from prep airing VERB [1980, through]
# 1980 pobj from ADP []
# through prep from ADP [1988]
# 1988 pobj through ADP []
# , punct airing VERB []
# composed advcl was VERB [of]
# of prep composed VERB [musicians]
# the det musicians NOUN []
# following amod musicians NOUN []
# all det star NOUN []
# - punct star NOUN []
# star compound musicians NOUN [all, -]
# musicians pobj of ADP [the, following, star, :, Atkins]
# : punct musicians NOUN []
# Chet compound Atkins PROPN []
# Atkins appos musicians NOUN [Chet, ,, Randolph]
# , punct Atkins PROPN []
# Boots compound Randolph PROPN []
# Randolph conj Atkins PROPN [Boots, ,, Clark]
# , punct Randolph PROPN []
# Roy compound Clark PROPN []
# Clark conj Randolph PROPN [Roy, ,, Cramer]
# , punct Clark PROPN []
# Floyd compound Cramer PROPN []
# Cramer conj Clark PROPN [Floyd, ,, McCoy]
# , punct Cramer PROPN []
# Charlie compound McCoy PROPN []
# McCoy conj Cramer PROPN [Charlie, ,, Davis]
# , punct McCoy PROPN []
# Danny compound Davis PROPN []
# Davis conj McCoy PROPN [Danny, ,, Burns]
# , punct Davis PROPN []
# Jethro compound Burns PROPN []
# Burns conj Davis PROPN [Jethro, ,, and, Gimble]
# , punct Burns PROPN []
# and cc Burns PROPN []
# Johnny compound Gimble PROPN []
# Gimble conj Burns PROPN [Johnny]
# . punct was VERB []
# NP film film nsubj co
# NP Kristen Wiig Wiig appos Bateman
# NP Bill Hader Hader conj Wiig
# NP Sigourney Weaver Weaver conj Hader
# NP the voice voice dobj features
# NP Seth Rogen Rogen pobj of
# NP the title character character pobj as
# NP Superbad 's Greg Mottola Mottola pobj by
# NP Pegg Pegg pobj of
# The det - PUNCT []
# film nsubj co NOUN []
# co nmod - PUNCT [film]
# - punct Bateman PROPN [The, co]
# stars compound Bateman PROPN []
# Jason compound Bateman PROPN []
# Bateman nsubj features VERB [-, stars, Jason, ,, Wiig]
# , punct Bateman PROPN []
# Kristen compound Wiig PROPN []
# Wiig appos Bateman PROPN [Kristen, ,, Hader]
# , punct Wiig PROPN []
# Bill compound Hader PROPN []
# Hader conj Wiig PROPN [Bill, and, Weaver]
# and cc Hader PROPN []
# Sigourney compound Weaver PROPN []
# Weaver conj Hader PROPN [Sigourney]
# , punct features VERB []
# features ROOT features VERB [Bateman, ,, voice, as, ,, and, directed]
# the det voice NOUN []
# voice dobj features VERB [the, of]
# of prep voice NOUN [Rogen]
# Seth compound Rogen PROPN []
# Rogen pobj of ADP [Seth]
# as prep features VERB [character]
# the det character NOUN []
# title compound character NOUN []
# character pobj as ADP [the, title]
# , punct features VERB []
# and cc features VERB []
# is auxpass directed VERB []
# directed conj features VERB [is, by]
# by agent directed VERB [Mottola]
# Superbad poss Mottola PROPN ['s]
# 's case Superbad PROPN []
# Greg compound Mottola PROPN []
# Mottola pobj by ADP [Superbad, Greg, (, of]
# ( punct Mottola PROPN []
# instead advmod of ADP []
# of cc Mottola PROPN [instead, Pegg]
# Pegg pobj of ADP []
# NP June June pobj Until
# NP he he nsubj was
# NP non-executive chairman chairman nsubjpass replaced
# NP BP BP pobj of
# NP Carl-Henric Svanberg formely chief executive officer officer pobj by
# NP Ericsson Ericsson pobj of
# Until prep was VERB [June]
# June pobj Until ADP [2009]
# 2009 nummod June PROPN []
# he nsubj was VERB []
# was ROOT was VERB [Until, he, replaced, .]
# non nmod - PUNCT []
# - punct executive NOUN [non]
# executive amod chairman NOUN [-]
# chairman nsubjpass replaced VERB [executive, of]
# of prep chairman NOUN [BP]
# BP pobj of ADP []
# being auxpass replaced VERB []
# replaced ccomp was VERB [chairman, being, by]
# by agent replaced VERB [officer]
# Carl compound Svanberg PROPN []
# - punct Svanberg PROPN []
# Henric compound Svanberg PROPN []
# Svanberg nmod officer NOUN [Carl, -, Henric]
# formely advmod chief ADJ []
# chief amod officer NOUN [formely]
# executive amod officer NOUN []
# officer pobj by ADP [Svanberg, chief, executive, of]
# of prep officer NOUN [Ericsson]
# Ericsson pobj of ADP []
# . punct was VERB []
# NP Valerie Curtin Curtin pobj by
# NP Barry Levinson Levinson conj Curtin
# Written ROOT Written VERB [by, .]
# by agent Written VERB [Curtin]
# Valerie compound Curtin PROPN []
# Curtin pobj by ADP [Valerie, and, Levinson]
# and cc Curtin PROPN []
# Barry compound Levinson PROPN []
# Levinson conj Curtin PROPN [Barry]
# . punct Written VERB []
# NP A posteriori arguments arguments nsubjpass criticized
# NP Hume Hume pobj by
# NP Kant Kant conj Hume
# NP Mill Mill conj Kant
# NP Edwards Edwards conj Mill
# NP many others others conj Edwards
# NP this argument argument nsubj is
# NP a proof proof attr is
# NP the existence existence pobj of
# NP God God pobj of
# A det arguments NOUN []
# posteriori amod arguments NOUN []
# arguments nsubjpass criticized VERB [A, posteriori]
# have aux criticized VERB []
# been auxpass criticized VERB []
# criticized ROOT criticized VERB [arguments, have, been, by, show, .]
# by agent criticized VERB [Hume]
# Hume pobj by ADP [,, Kant]
# , punct Hume PROPN []
# Kant conj Hume PROPN [,, Mill]
# , punct Kant PROPN []
# Mill conj Kant PROPN [,, Edwards]
# , punct Mill PROPN []
# Edwards conj Mill PROPN [and, others]
# and cc Edwards PROPN []
# many amod others NOUN []
# others conj Edwards PROPN [many]
# to aux show VERB []
# show advcl criticized VERB [to, is]
# that mark is VERB []
# this det argument NOUN []
# argument nsubj is VERB [this]
# is ccomp show VERB [that, argument, not, proof]
# not neg is VERB []
# a det proof NOUN []
# proof attr is VERB [a, of]
# of prep proof NOUN [existence]
# the det existence NOUN []
# existence pobj of ADP [the, of]
# of prep existence NOUN [God]
# God pobj of ADP []
# . punct criticized VERB []
# NP It It nsubj stretches
# NP the Ambassador Bridge Bridge pobj from
# NP the Hiram Walker Distillery Distillery pobj to
# It nsubj stretches VERB []
# stretches ROOT stretches VERB [It, from, to, .]
# from prep stretches VERB [Bridge]
# the det Bridge PROPN []
# Ambassador compound Bridge PROPN []
# Bridge pobj from ADP [the, Ambassador]
# to prep stretches VERB [Distillery]
# the det Distillery PROPN []
# Hiram compound Distillery PROPN []
# Walker compound Distillery PROPN []
# Distillery pobj to ADP [the, Hiram, Walker]
# . punct stretches VERB []
# NP the home home attr been
# NP numerous writers writers pobj of
# NP musicians musicians conj writers
# NP artists artists conj musicians
# NP actors actors conj artists
# NP Bob Dylan Dylan pobj including
# NP Virgil Thomson Thomson conj Dylan
# NP Charles Bukowski Bukowski conj Thomson
# NP Janis Joplin Joplin conj Bukowski
# NP Leonard Cohen Cohen conj Joplin
# NP Patti Smith Smith conj Cohen
# NP Iggy Pop Pop conj Smith
# NP Jobriath Jobriath conj Pop
# NP Larry Rivers Rivers conj Jobriath
# has aux been VERB []
# been ROOT been VERB [has, home, .]
# the det home NOUN []
# home attr been VERB [the, of]
# of prep home NOUN [writers]
# numerous amod writers NOUN []
# writers pobj of ADP [numerous, ,, musicians, including]
# , punct writers NOUN []
# musicians conj writers NOUN [,, artists]
# , punct musicians NOUN []
# artists conj musicians NOUN [,, and, actors]
# , punct artists NOUN []
# and cc artists NOUN []
# actors conj artists NOUN [,]
# , punct actors NOUN []
# including prep writers NOUN [Dylan]
# Bob compound Dylan PROPN []
# Dylan pobj including VERB [Bob, ,, Thomson]
# , punct Dylan PROPN []
# Virgil compound Thomson PROPN []
# Thomson conj Dylan PROPN [Virgil, ,, Bukowski]
# , punct Thomson PROPN []
# Charles compound Bukowski PROPN []
# Bukowski conj Thomson PROPN [Charles, ,, Joplin]
# , punct Bukowski PROPN []
# Janis compound Joplin PROPN []
# Joplin conj Bukowski PROPN [Janis, ,, Cohen]
# , punct Joplin PROPN []
# Leonard compound Cohen PROPN []
# Cohen conj Joplin PROPN [Leonard, ,, Smith]
# , punct Cohen PROPN []
# Patti compound Smith PROPN []
# Smith conj Cohen PROPN [Patti, ,, Pop]
# , punct Smith PROPN []
# Iggy compound Pop PROPN []
# Pop conj Smith PROPN [Iggy, ,, Jobriath]
# , punct Pop PROPN []
# Jobriath conj Pop PROPN [,, and, Rivers]
# , punct Jobriath PROPN []
# and cc Jobriath PROPN []
# Larry compound Rivers PROPN []
# Rivers conj Jobriath PROPN [Larry]
# . punct been VERB []
# NP A touchscreen coffee table table ROOT table
# NP an interactive original copy copy dobj containing
# NP Lewis Carroll 's Alice 's Adventures Adventures pobj of
# NP Ground Ground pobj Under
# A det table NOUN []
# touchscreen compound table NOUN []
# coffee compound table NOUN []
# table ROOT table NOUN [A, touchscreen, coffee, containing, .]
# containing acl table NOUN [copy]
# an det copy NOUN []
# interactive amod copy NOUN []
# original amod copy NOUN []
# copy dobj containing VERB [an, interactive, original, of]
# of prep copy NOUN [Adventures]
# Lewis compound Carroll PROPN []
# Carroll poss Adventures PROPN [Lewis, 's]
# 's case Carroll PROPN []
# Alice poss Adventures PROPN ['s]
# 's case Alice PROPN []
# Adventures pobj of ADP [Carroll, Alice, Under]
# Under prep Adventures PROPN [Ground]
# Ground pobj Under ADP []
# . punct table NOUN []
# NP a reference reference attr be
# NP Jacqueline Kennedy Kennedy pobj to
# NP the wife wife appos Kennedy
# NP former US President John F. Kennedy Kennedy pobj of
# NP his womanizing habits habits conj Kennedy
# This nsubjpass believed VERB []
# is auxpass believed VERB []
# believed ROOT believed VERB [This, is, be, .]
# to aux be VERB []
# be xcomp believed VERB [to, reference]
# a det reference NOUN []
# reference attr be VERB [a, to]
# to prep reference NOUN [Kennedy]
# Jacqueline compound Kennedy PROPN []
# Kennedy pobj to ADP [Jacqueline, ,, wife]
# , punct Kennedy PROPN []
# the det wife NOUN []
# wife appos Kennedy PROPN [the, of]
# of prep wife NOUN [Kennedy]
# former amod President PROPN []
# US compound President PROPN []
# President compound Kennedy PROPN [former, US]
# John compound Kennedy PROPN []
# F. compound Kennedy PROPN []
# Kennedy pobj of ADP [President, John, F., and, habits]
# and cc Kennedy PROPN []
# his poss habits NOUN []
# womanizing compound habits NOUN []
# habits conj Kennedy PROPN [his, womanizing]
# . punct believed VERB []
# NP Stanley Kubrick Kubrick nsubj 134
# NP David Lean Lean appos 135
# NP [ 137 ] Roman Polanski Polanski appos Kubrick
# NP 138 ] Martin Scorsese Scorsese appos Polanski
# NP [ 139 ] Francois Truffaut Truffaut appos Scorsese
# NP David Lynch Lynch appos 140
# NP Zhang Yimou Yimou conj Lynch
# ] punct 134 NUM []
# Werner compound Herzog PROPN []
# Herzog dep 134 NUM [Werner]
# , punct 134 NUM []
# [ punct 134 NUM []
# 134 ROOT 134 NUM [], Herzog, ,, [, ], Kubrick, .]
# ] punct 134 NUM []
# Stanley compound Kubrick PROPN []
# Kubrick nsubj 134 NUM [Stanley, ,, 135, ,, Polanski]
# , punct Kubrick PROPN []
# [ punct 135 NUM []
# 135 appos Kubrick PROPN [[, ], Lean, Lumet]
# ] punct 135 NUM []
# David compound Lean PROPN []
# Lean appos 135 NUM [David, ,, 136]
# , punct Lean PROPN []
# [ punct 136 NUM []
# 136 appos Lean PROPN [[, ]]
# ] punct 136 NUM []
# Sidney compound Lumet PROPN []
# Lumet npadvmod 135 NUM [Sidney]
# , punct Kubrick PROPN []
# [ punct Polanski PROPN []
# 137 nummod Polanski PROPN []
# ] punct Polanski PROPN []
# Roman compound Polanski PROPN []
# Polanski appos Kubrick PROPN [[, 137, ], Roman, ,, [, Scorsese]
# , punct Polanski PROPN []
# [ punct Polanski PROPN []
# 138 nummod Scorsese PROPN []
# ] punct Scorsese PROPN []
# Martin compound Scorsese PROPN []
# Scorsese appos Polanski PROPN [138, ], Martin, ,, Truffaut]
# , punct Scorsese PROPN []
# [ punct Truffaut PROPN []
# 139 nummod Truffaut PROPN []
# ] punct Truffaut PROPN []
# Francois compound Truffaut PROPN []
# Truffaut appos Scorsese PROPN [[, 139, ], Francois, ,, 140]
# , punct Truffaut PROPN []
# [ punct 140 NUM []
# 140 appos Truffaut PROPN [[, ], Lynch]
# ] punct 140 NUM []
# David compound Lynch PROPN []
# Lynch appos 140 NUM [David, 141, and, Yimou]
# [ punct 141 NUM []
# 141 appos Lynch PROPN [[, ]]
# ] punct 141 NUM []
# and cc Lynch PROPN []
# Zhang compound Yimou PROPN []
# Yimou conj Lynch PROPN [Zhang]
# . punct 134 NUM []
# NP Derbyshire Peveril Castle Market Place Place nsubj was
# NP Castleton Castleton conj Place
# NP Derbyshire Derbyshire conj Castleton
# NP S33 8WQ Peveril Castle Castle conj Derbyshire
# NP the setting setting attr was
# NP the novel Peveril Peveril pobj for
# NP the Peak Peak pobj of
# NP Sir Walter Scott Scott pobj by
# Derbyshire compound Place PROPN []
# Peveril compound Place PROPN []
# Castle compound Place PROPN []
# Market compound Place PROPN []
# Place nsubj was VERB [Derbyshire, Peveril, Castle, Market, ,, Castleton]
# , punct Place PROPN []
# Castleton conj Place PROPN [,, Derbyshire]
# , punct Castleton PROPN []
# Derbyshire conj Castleton PROPN [,, Castle]
# , punct Derbyshire PROPN []
# S33 nmod Castle PROPN []
# 8WQ compound Peveril PROPN []
# Peveril compound Castle PROPN [8WQ]
# Castle conj Derbyshire PROPN [S33, Peveril]
# was ROOT was VERB [Place, setting, .]
# the det setting NOUN []
# setting attr was VERB [the, for, by]
# for prep setting NOUN [Peveril]
# the det Peveril PROPN []
# novel amod Peveril PROPN []
# Peveril pobj for ADP [the, novel, of]
# of prep Peveril PROPN [Peak]
# the det Peak PROPN []
# Peak pobj of ADP [the]
# by prep setting NOUN [Scott]
# Sir compound Scott PROPN []
# Walter compound Scott PROPN []
# Scott pobj by ADP [Sir, Walter]
# . punct was VERB []
# NP Office Office nsubj requested
# NP the support support dobj requested
# NP the Mexican army army pobj of
# NP the military group group nsubjpass mobilized
# NP the street Henry Dunant Dunant pobj in
# NP Miguel de Cervantes Cervantes conj Dunant
# NP the place place dobj guard
# Office nsubj requested VERB []
# requested ROOT requested VERB [Office, support, ,, so, mobilized]
# the det support NOUN []
# support dobj requested VERB [the, of]
# of prep support NOUN [army]
# the det army NOUN []
# Mexican amod army NOUN []
# army pobj of ADP [the, Mexican]
# , punct requested VERB []
# so cc requested VERB []
# the det group NOUN []
# military amod group NOUN []
# group nsubjpass mobilized VERB [the, military, stationed]
# stationed acl group NOUN [in]
# in prep stationed VERB [Dunant]
# the det Dunant PROPN []
# street compound Dunant PROPN []
# Henry compound Dunant PROPN []
# Dunant pobj in ADP [the, street, Henry, and, Cervantes]
# and cc Dunant PROPN []
# Miguel compound Cervantes PROPN []
# de compound Cervantes PROPN []
# Cervantes conj Dunant PROPN [Miguel, de]
# was auxpass mobilized VERB []
# mobilized conj requested VERB [group, was, guard, .]
# to aux guard VERB []
# guard xcomp mobilized VERB [to, place]
# the det place NOUN []
# place dobj guard VERB [the]
# . punct mobilized VERB []
# NP Christian Scientists Scientists ROOT Scientists
# NP The Bible Science Science appos Scientists
# NP Health Health conj Science
# NP Key Key pobj with
# NP the Scriptures Scriptures pobj to
# NP Mary Baker Eddy Eddy pobj by
# Christian amod Scientists PROPN []
# Scientists ROOT Scientists PROPN [Christian, Science, with, by, .]
# The det Science PROPN []
# Bible compound Science PROPN []
# Science appos Scientists PROPN [The, Bible, and, Health]
# and cc Science PROPN []
# Health conj Science PROPN []
# with prep Scientists PROPN [Key]
# Key pobj with ADP [to]
# to prep Key PROPN [Scriptures]
# the det Scriptures NOUN []
# Scriptures pobj to ADP [the]
# by prep Scientists PROPN [Eddy]
# Mary compound Eddy PROPN []
# Baker compound Eddy PROPN []
# Eddy pobj by ADP [Mary, Baker]
# . punct Scientists PROPN []
# NP The Livable Streets study study nsubj found
# NP Donald Appleyard Appleyard pobj by
# NP residents residents nsubj had
# NP streets streets pobj of
# NP light traffic traffic pobj with
# NP the people people pobj as
# The det study NOUN []
# Livable compound Streets PROPN []
# Streets compound study NOUN [Livable]
# study nsubj found VERB [The, Streets, by]
# by prep study NOUN [Appleyard]
# Donald compound Appleyard PROPN []
# Appleyard pobj by ADP [Donald, (, 1981, )]
# ( punct Appleyard PROPN []
# 1981 appos Appleyard PROPN []
# ) punct Appleyard PROPN []
# found ROOT found VERB [study, had, friends]
# that mark had VERB []
# residents nsubj had VERB [of, with]
# of prep residents NOUN [streets]
# streets pobj of ADP []
# with prep residents NOUN [traffic]
# light amod traffic NOUN []
# traffic pobj with ADP [light]
# had ccomp found VERB [that, residents, ,, on]
# , punct had VERB []
# on prep had VERB [average, ,]
# average amod on ADP []
# , punct on ADP []
# three nummod friends NOUN [more]
# more amod three NUM []
# friends advcl found VERB [three, and, acquaintances, on]
# and cc friends NOUN []
# twice advmod many ADJ []
# as advmod many ADJ []
# many amod acquaintances NOUN [twice, as]
# acquaintances conj friends NOUN [many, as]
# as prep acquaintances NOUN [people]
# the det people NOUN []
# people pobj as ADP [the]
# on prep friends NOUN []
# NP Chris Robinson Robinson ROOT Robinson
# NP Kate Hudson Hudson conj Robinson
# NP 13 years Artie Shaw Shaw conj Hudson
# NP Ava Gardner Gardner conj Shaw
# NP 12 years years appos Hudson
# Chris compound Robinson PROPN []
# Robinson ROOT Robinson PROPN [Chris, and, Hudson]
# and cc Robinson PROPN []
# Kate compound Hudson PROPN []
# Hudson conj Robinson PROPN [Kate, ,, Shaw, ,, years, .]
# , punct Hudson PROPN []
# 13 nummod years NOUN []
# years compound Shaw PROPN [13]
# Artie compound Shaw PROPN []
# Shaw conj Hudson PROPN [years, Artie, and, Gardner]
# and cc Shaw PROPN []
# Ava compound Gardner PROPN []
# Gardner conj Shaw PROPN [Ava]
# , punct Hudson PROPN []
# 12 nummod years NOUN []
# years appos Hudson PROPN [12]
# . punct Hudson PROPN []
# NP I I nsubj am
# NP a regular occasion occasion pobj on
# NP both John Astin Astin pobj with
# NP Patty Duke Duke conj Astin
# » punct am VERB []
# I nsubj am VERB []
# am ROOT am VERB [», I, ,, on, ,, obsessed, .]
# , punct am VERB []
# on prep am VERB [occasion]
# a det occasion NOUN []
# regular amod occasion NOUN []
# occasion pobj on ADP [a, regular]
# , punct am VERB []
# obsessed acomp am VERB [with]
# with prep obsessed VERB [Astin]
# both preconj Astin PROPN []
# John compound Astin PROPN []
# Astin pobj with ADP [both, John, and, Duke]
# and cc Astin PROPN []
# Patty compound Duke PROPN []
# Duke conj Astin PROPN [Patty]
# . punct am VERB []
# NP I I nsubj loved
# NP their most famous roles roles pobj of
# NP John Astin Astin appos roles
# NP Gomez Addams Addams pobj as
# NP The Addams Family Family pobj on
# NP Patty Duke Duke conj Family
# NP Patty Patty pobj as
# NP Cathy Cathy conj Patty
# I nsubj loved VERB []
# loved ROOT loved VERB [I, both]
# both dobj loved VERB [of]
# of prep both DET [roles]
# their poss roles NOUN []
# most advmod famous ADJ []
# famous amod roles NOUN [most]
# roles pobj of ADP [their, famous, ,, Astin]
# , punct roles NOUN []
# John compound Astin PROPN []
# Astin appos roles NOUN [John, as]
# as prep Astin PROPN [Addams]
# Gomez compound Addams PROPN []
# Addams pobj as ADP [Gomez, on, as]
# on prep Addams PROPN [Family]
# The det Family PROPN []
# Addams compound Family PROPN []
# Family pobj on ADP [The, Addams, and, Duke]
# and cc Family PROPN []
# Patty compound Duke PROPN []
# Duke conj Family PROPN [Patty]
# as prep Addams PROPN [Patty]
# Patty pobj as ADP [and, Cathy]
# and cc Patty PROPN []
# Cathy conj Patty PROPN []
# NP It It nsubjpass established
# NP Napoleon I I pobj by
# NP the graves graves conj I
# NP Oscar Wilde Wilde pobj of
# NP Geroges Bizet Bizet conj I
# NP Gertrude Stein Stein conj Bizet
# NP Alice B. Toklas Toklas conj Stein
# NP Amedeo Modigliani Modigliani conj Toklas
# NP Marcel Proust Proust conj Modigliani
# NP Jean-François Lyotard Lyotard conj Proust
# NP Joseph Fourier Fourier conj Lyotard
# NP Edith Piaf Piaf conj Fourier
# NP Paul Éluard Éluard conj Piaf
# NP - K K appos I
# It nsubjpass established VERB []
# was auxpass established VERB []
# established ROOT established VERB [It, was, in, by]
# in prep established VERB [1804]
# 1804 pobj in ADP []
# by agent established VERB [I]
# Napoleon compound I PROPN []
# I pobj by ADP [Napoleon, and, graves, ,, Bizet, --, K]
# and cc I PROPN []
# the det graves NOUN []
# graves conj I PROPN [the, of]
# of prep graves NOUN [Wilde]
# Oscar compound Wilde PROPN []
# Wilde pobj of ADP [Oscar]
# , punct I PROPN []
# Geroges compound Bizet PROPN []
# Bizet conj I PROPN [Geroges, ,, Stein]
# , punct Bizet PROPN []
# Gertrude compound Stein PROPN []
# Stein conj Bizet PROPN [Gertrude, and, Toklas]
# and cc Stein PROPN []
# Alice compound Toklas PROPN []
# B. compound Toklas PROPN []
# Toklas conj Stein PROPN [Alice, B., ,, Modigliani]
# , punct Toklas PROPN []
# Amedeo compound Modigliani PROPN []
# Modigliani conj Toklas PROPN [Amedeo, ,, Proust]
# , punct Modigliani PROPN []
# Marcel compound Proust PROPN []
# Proust conj Modigliani PROPN [Marcel, ,, Lyotard]
# , punct Proust PROPN []
# Jean compound Lyotard PROPN []
# - punct Lyotard PROPN []
# François compound Lyotard PROPN []
# Lyotard conj Proust PROPN [Jean, -, François, ,, Fourier]
# , punct Lyotard PROPN []
# Joseph compound Fourier PROPN []
# Fourier conj Lyotard PROPN [Joseph, ,, Piaf]
# , punct Fourier PROPN []
# Edith compound Piaf PROPN []
# Piaf conj Fourier PROPN [Edith, ,, Éluard]
# , punct Piaf PROPN []
# Paul compound Éluard PROPN []
# Éluard conj Piaf PROPN [Paul]
# -- punct I PROPN []
# - punct K PROPN []
# K appos I PROPN [-]
# NP It It nsubjpass invented
# NP Raffaele Esposito Esposito pobj by
# NP a Neapolitan pizzaiolo pizzaiolo appos Esposito
# NP a visit visit dobj commemorate
# NP King Umberto I I pobj of
# NP Queen Margherita Margherita conj I
# NP Savoy Savoy pobj of
# It nsubjpass invented VERB []
# was auxpass invented VERB []
# invented ROOT invented VERB [It, was, by, ,, commemorate, .]
# by agent invented VERB [Esposito]
# Raffaele compound Esposito PROPN []
# Esposito pobj by ADP [Raffaele, ,, pizzaiolo]
# , punct Esposito PROPN []
# a det pizzaiolo NOUN []
# Neapolitan compound pizzaiolo NOUN []
# pizzaiolo appos Esposito PROPN [a, Neapolitan]
# , punct invented VERB []
# to aux commemorate VERB []
# commemorate xcomp invented VERB [to, visit]
# a det visit NOUN []
# visit dobj commemorate VERB [a, of]
# of prep visit NOUN [I]
# King compound Umberto PROPN []
# Umberto compound I PROPN [King]
# I pobj of ADP [Umberto, and, Margherita]
# and cc I PROPN []
# Queen compound Margherita PROPN []
# Margherita conj I PROPN [Queen, of]
# of prep Margherita PROPN [Savoy]
# Savoy pobj of ADP []
# . punct invented VERB []
# NP The Swiss-French philosopher Jean-Jacques Rousseau Rousseau nsubj contrasted
# NP Sparta Sparta dobj contrasted
# NP Athens Athens pobj with
# NP his Discourse Discourse pobj in
# NP the Arts Arts pobj on
# NP Sciences Sciences conj Arts
# NP its austere constitution constitution nsubj was
# NP the more cultured nature nature pobj to
# NP Athenian life life pobj of
# The det philosopher NOUN []
# Swiss compound French ADJ []
# - punct French ADJ []
# French compound philosopher NOUN [Swiss, -]
# philosopher compound Rousseau PROPN [The, French]
# Jean compound Rousseau PROPN []
# - punct Rousseau PROPN []
# Jacques compound Rousseau PROPN []
# Rousseau nsubj contrasted VERB [philosopher, Jean, -, Jacques]
# contrasted ROOT contrasted VERB [Rousseau, Sparta, favourably, with, in, on, ,, arguing, .]
# Sparta dobj contrasted VERB []
# favourably advmod contrasted VERB []
# with prep contrasted VERB [Athens]
# Athens pobj with ADP []
# in prep contrasted VERB [Discourse]
# his poss Discourse PROPN []
# Discourse pobj in ADP [his]
# on prep contrasted VERB [Arts]
# the det Arts PROPN []
# Arts pobj on ADP [the, and, Sciences]
# and cc Arts PROPN []
# Sciences conj Arts PROPN []
# , punct contrasted VERB []
# arguing advcl contrasted VERB [was]
# that mark was VERB []
# its poss constitution NOUN []
# austere amod constitution NOUN []
# constitution nsubj was VERB [its, austere]
# was ccomp arguing VERB [that, constitution, preferable]
# preferable acomp was VERB [to]
# to prep preferable ADJ [nature]
# the det nature NOUN []
# more advmod cultured ADJ []
# cultured amod nature NOUN [more]
# nature pobj to ADP [the, cultured, of]
# of prep nature NOUN [life]
# Athenian amod life NOUN []
# life pobj of ADP [Athenian]
# . punct contrasted VERB []
# NP a significant migrant population population attr is
# NP Bhumihars Bhumihars pobj of
# NP Mauritius Mauritius pobj in
# NP Suriname Suriname conj Mauritius
# NP Trinidad Trinidad conj Suriname
# NP Tobago Tobago conj Trinidad
# NP Guyana Guyana conj Tobago
# NP others others conj Guyana
# There expl is VERB []
# is ROOT is VERB [There, also, population, .]
# also advmod is VERB []
# a det population NOUN []
# significant amod population NOUN []
# migrant amod population NOUN []
# population attr is VERB [a, significant, migrant, of]
# of prep population NOUN [Bhumihars]
# Bhumihars pobj of ADP [in]
# in prep Bhumihars PROPN [Mauritius]
# Mauritius pobj in ADP [,, Suriname]
# , punct Mauritius PROPN []
# Suriname conj Mauritius PROPN [,, Trinidad]
# , punct Suriname PROPN []
# Trinidad conj Suriname PROPN [and, Tobago]
# and cc Trinidad PROPN []
# Tobago conj Trinidad PROPN [,, Guyana]
# , punct Tobago PROPN []
# Guyana conj Tobago PROPN [and, others]
# and cc Guyana PROPN []
# others conj Guyana PROPN []
# . punct is VERB []
# NP The Legend Legend pobj on
# NP Sleepy Hollow Hollow pobj of
# NP Washington Irving Irving pobj by
# Based ROOT Based VERB [on, .]
# on prep Based VERB [Legend]
# The det Legend PROPN []
# Legend pobj on ADP [The, of, by]
# of prep Legend PROPN [Hollow]
# Sleepy compound Hollow PROPN []
# Hollow pobj of ADP [Sleepy]
# by prep Legend PROPN [Irving]
# Washington compound Irving PROPN []
# Irving pobj by ADP [Washington]
# . punct Based VERB []
# NP the Past Past pobj In
# NP Illegal Alien Alien dobj novel
# NP Mike Tucker Tucker pobj by
# NP Robert Perry Perry conj Tucker
# NP the 1940s 1940s pobj in
# NP the Cybermen Cybermen nsubj create
# NP cybermats cybermats dobj create
# NP cyber-converting local animals animals pobj by
# NP cats cats pobj like
# NP birds birds conj cats
# NP lack lack pobj because
# In prep novel NOUN [Past]
# the det Past PROPN []
# Past pobj In ADP [the]
# Doctor compound Adventures PROPN []
# Adventures compound novel NOUN [Doctor]
# novel ROOT novel NOUN [In, Adventures, Alien, by, ,, set, create]
# Illegal compound Alien PROPN []
# Alien dobj novel NOUN [Illegal]
# by prep novel NOUN [Tucker]
# Mike compound Tucker PROPN []
# Tucker pobj by ADP [Mike, and, Perry]
# and cc Tucker PROPN []
# Robert compound Perry PROPN []
# Perry conj Tucker PROPN [Robert]
# , punct novel NOUN []
# set acl novel NOUN [in]
# in prep set VERB [1940s]
# the det 1940s NOUN []
# 1940s pobj in ADP [the]
# , punct create VERB []
# the det Cybermen PROPN []
# Cybermen nsubj create VERB [the]
# create conj novel NOUN [,, Cybermen, cybermats, by, ,, because]
# cybermats dobj create VERB []
# by prep create VERB [animals]
# cyber npadvmod converting VERB []
# - punct converting VERB []
# converting amod animals NOUN [cyber, -]
# local amod animals NOUN []
# animals pobj by ADP [converting, local, like]
# like prep animals NOUN [cats]
# cats pobj like ADP [or, birds]
# or cc cats NOUN []
# birds conj cats NOUN []
# , punct create VERB []
# possibly advmod because ADP []
# because prep create VERB [possibly, of, lack]
# of pcomp because ADP []
# lack pobj because ADP [of]
# of prep lack NOUN []
# NP legendary Monterey Jazz Festival Festival ROOT Festival
# NP the stage stage dobj sharing
# NP jazz greats greats pobj with
# NP Sarah Vaughan Vaughan pobj as
# NP Dianne Reeves Reeves conj Vaughan
# NP Thelonious Monk Monk conj Reeves
# NP Oscar Peterson Peterson conj Monk
# NP Miles Davis Davis conj Peterson
# NP Cal Tjader Tjader conj Davis
# NP Carmen McRae McRae conj Tjader
# NP Herbie Hancock Hancock conj McRae
# NP Nat Adderley Adderley conj Hancock
# NP Dizzy Gillespie Gillespie conj Adderley
# legendary amod Festival PROPN []
# Monterey compound Festival PROPN []
# Jazz compound Festival PROPN []
# Festival ROOT Festival PROPN [legendary, Monterey, Jazz, times, ,, spanning, .]
# 12 nummod times NOUN []
# times npadvmod Festival PROPN [12]
# , punct Festival PROPN []
# spanning advcl Festival PROPN [from, ,, sharing]
# from prep spanning VERB [1959, thru]
# 1959 pobj from ADP []
# thru prep from ADP [1993]
# 1993 pobj thru ADP []
# , punct spanning VERB []
# sharing conj spanning VERB [stage, with]
# the det stage NOUN []
# stage dobj sharing VERB [the]
# with prep sharing VERB [greats]
# jazz compound greats NOUN []
# greats pobj with ADP [jazz, as]
# such amod as ADP []
# as prep greats NOUN [such, Vaughan]
# Sarah compound Vaughan PROPN []
# Vaughan pobj as ADP [Sarah, ,, Reeves]
# , punct Vaughan PROPN []
# Dianne compound Reeves PROPN []
# Reeves conj Vaughan PROPN [Dianne, ,, Monk]
# , punct Reeves PROPN []
# Thelonious compound Monk PROPN []
# Monk conj Reeves PROPN [Thelonious, ,, Peterson]
# , punct Monk PROPN []
# Oscar compound Peterson PROPN []
# Peterson conj Monk PROPN [Oscar, ,, Davis]
# , punct Peterson PROPN []
# Miles compound Davis PROPN []
# Davis conj Peterson PROPN [Miles, ,, Tjader]
# , punct Davis PROPN []
# Cal compound Tjader PROPN []
# Tjader conj Davis PROPN [Cal, ,, McRae]
# , punct Tjader PROPN []
# Carmen compound McRae PROPN []
# McRae conj Tjader PROPN [Carmen, ,, Hancock]
# , punct McRae PROPN []
# Herbie compound Hancock PROPN []
# Hancock conj McRae PROPN [Herbie, ,, Adderley]
# , punct Hancock PROPN []
# Nat compound Adderley PROPN []
# Adderley conj Hancock PROPN [Nat, ,, and, Gillespie]
# , punct Adderley PROPN []
# and cc Adderley PROPN []
# Dizzy compound Gillespie PROPN []
# Gillespie conj Adderley PROPN [Dizzy]
# . punct Festival PROPN []
# NP The next production production nsubj be
# NP the PCPA Theaterfest Theaterfest pobj of
# NP the mega-hit , harbinger harbinger attr be
# NP a new , uniquely American sensibility sensibility pobj of
# NP musical theater theater pobj in
# NP West Side Story Story appos harbinger
# NP a book book pobj with
# NP Arthur Laurents Laurents pobj by
# NP music music appos Laurents
# NP Leonard Bernstein Bernstein pobj by
# NP lyrics lyrics appos Bernstein
# NP Stephen Sondheim Sondheim pobj by
# NP choreography choreography appos book
# NP Jerome Robbins Robbins pobj by
# The det production NOUN []
# next amod production NOUN []
# production nsubj be VERB [The, next, of]
# of prep production NOUN [Theaterfest]
# the det Theaterfest PROPN []
# PCPA compound Theaterfest PROPN []
# Theaterfest pobj of ADP [the, PCPA]
# will aux be VERB []
# be ROOT be VERB [production, will, harbinger, with, .]
# the det harbinger NOUN []
# mega advmod hit NOUN []
# - punct hit NOUN []
# hit amod harbinger NOUN [mega, -]
# , punct harbinger NOUN []
# harbinger attr be VERB [the, hit, ,, of, ,, Story, ,]
# of prep harbinger NOUN [sensibility]
# a det sensibility NOUN []
# new amod sensibility NOUN []
# , punct sensibility NOUN []
# uniquely advmod American ADJ []
# American amod sensibility NOUN [uniquely]
# sensibility pobj of ADP [a, new, ,, American, in]
# in prep sensibility NOUN [theater]
# musical amod theater NOUN []
# theater pobj in ADP [musical]
# , punct harbinger NOUN []
# West compound Side PROPN []
# Side compound Story PROPN [West]
# Story appos harbinger NOUN [Side]
# , punct harbinger NOUN []
# with prep be VERB [book]
# a det book NOUN []
# book pobj with ADP [a, by, —, choreography]
# by prep book NOUN [Laurents]
# Arthur compound Laurents PROPN []
# Laurents pobj by ADP [Arthur, ,, music]
# , punct Laurents PROPN []
# music appos Laurents PROPN [by]
# by prep music NOUN [Bernstein]
# Leonard compound Bernstein PROPN []
# Bernstein pobj by ADP [Leonard, ,, lyrics]
# , punct Bernstein PROPN []
# lyrics appos Bernstein PROPN [by, and, —, in]
# by prep lyrics NOUN [Sondheim]
# Stephen compound Sondheim PROPN []
# Sondheim pobj by ADP [Stephen]
# and cc lyrics NOUN []
# — conj lyrics NOUN []
# in prep lyrics NOUN [1957]
# 1957 pobj in ADP []
# — punct book NOUN []
# choreography appos book NOUN [by]
# by prep choreography NOUN [Robbins]
# Jerome compound Robbins PROPN []
# Robbins pobj by ADP [Jerome]
# . punct be VERB []
# NP ESPN 's Joe Lunardi Lunardi nsubj is
# NP the inventor inventor attr is
# NP the term term pobj of
# NP `` bracketology bracketology appos term
# NP the owner owner pobj as
# NP editor editor conj owner
# NP the Blue Ribbon College Basketball Yearbook Yearbook pobj of
# ESPN poss Lunardi PROPN ['s]
# 's case ESPN PROPN []
# Joe compound Lunardi PROPN []
# Lunardi nsubj is VERB [ESPN, Joe]
# is ROOT is VERB [Lunardi, inventor, ,, starting]
# the det inventor NOUN []
# inventor attr is VERB [the, of]
# of prep inventor NOUN [term]
# the det term NOUN []
# term pobj of ADP [the, bracketology]
# `` punct bracketology NOUN []
# bracketology appos term NOUN [``, '']
# '' punct bracketology NOUN []
# , punct is VERB []
# starting advcl is VERB [first, and, ending]
# first advmod starting VERB [as]
# as prep first ADV [owner]
# the det owner NOUN []
# owner pobj as ADP [the, and, editor, of]
# and cc owner NOUN []
# editor conj owner NOUN []
# of prep owner NOUN [Yearbook]
# the det Yearbook PROPN []
# Blue compound Yearbook PROPN []
# Ribbon compound Yearbook PROPN []
# College compound Yearbook PROPN []
# Basketball compound Yearbook PROPN []
# Yearbook pobj of ADP [the, Blue, Ribbon, College, Basketball]
# and cc starting VERB []
# ending conj starting VERB [up, as]
# up prt ending VERB []
# as prep ending VERB []
# NP Celebrity Jetters Airport Operations Crewmember Renee Renee nsubj had
# NP the pleasure pleasure dobj had
# NP meeting NBA star star pobj of
# NP Grant Hill Hill appos pleasure
# NP his wife wife conj Hill
# NP Tamia Tamia appos wife
# NP a six-time Grammy Award-nominated Canadian-American R & B/Hip Hop recording artist artist conj Tamia
# NP record producer producer conj artist
# Celebrity compound Jetters PROPN []
# Jetters compound Airport PROPN [Celebrity]
# Airport compound Operations PROPN [Jetters]
# Operations compound Renee PROPN [Airport]
# Crewmember compound Renee PROPN []
# Renee nsubj had VERB [Operations, Crewmember]
# had ROOT had VERB [Renee, pleasure, .]
# the det pleasure NOUN []
# pleasure dobj had VERB [the, of, ,, Hill]
# of prep pleasure NOUN [star]
# meeting compound star NOUN []
# NBA compound star NOUN []
# star pobj of ADP [meeting, NBA]
# , punct pleasure NOUN []
# Grant compound Hill PROPN []
# Hill appos pleasure NOUN [Grant, ,, and, wife]
# , punct Hill PROPN []
# and cc Hill PROPN []
# his poss wife NOUN []
# wife conj Hill PROPN [his, Tamia]
# Tamia appos wife NOUN [,, artist]
# , punct Tamia PROPN []
# a det artist NOUN []
# six nummod time NOUN []
# - punct time NOUN []
# time nmod artist NOUN [six, -]
# Grammy compound Award PROPN []
# Award npadvmod nominated VERB [Grammy]
# - punct nominated VERB []
# nominated amod artist NOUN [Award, -]
# Canadian amod American ADJ []
# - punct American ADJ []
# American amod artist NOUN [Canadian, -]
# R nmod Hip PROPN [&, B]
# & cc R NOUN []
# B conj R NOUN []
# / punct Hip PROPN []
# Hip compound Hop PROPN [R, /]
# Hop compound artist NOUN [Hip]
# recording amod artist NOUN []
# artist conj Tamia PROPN [a, time, nominated, American, Hop, recording, ,, and, producer]
# , punct artist NOUN []
# and cc artist NOUN []
# record compound producer NOUN []
# producer conj artist NOUN [record]
# . punct had VERB []
# NP March March appos Friday
# NP - Chechen Torch singer singer nsubjpass born
# NP actress Liza Umarova Umarova conj singer
# NP Almaty Almaty pobj in
# NP Soviet Union Union appos Republic
# Friday npadvmod born VERB [,, March]
# , punct Friday PROPN []
# March appos Friday PROPN [12, ,, 1965]
# 12 nummod March PROPN []
# , punct March PROPN []
# 1965 nummod March PROPN []
# - punct Chechen PROPN []
# Chechen compound singer NOUN [-]
# Torch compound singer NOUN []
# singer nsubjpass born VERB [Chechen, Torch, and, Umarova]
# and cc singer NOUN []
# actress compound Umarova PROPN []
# Liza compound Umarova PROPN []
# Umarova conj singer NOUN [actress, Liza]
# was auxpass born VERB []
# born ROOT born VERB [Friday, singer, was, in, ,, Republic, .]
# in prep born VERB [Almaty]
# Almaty pobj in ADP []
# , punct born VERB []
# Kazakh compound Republic PROPN []
# Soviet compound Republic PROPN []
# Socialist compound Republic PROPN []
# Republic npadvmod born VERB [Kazakh, Soviet, Socialist, ,, Union]
# , punct Republic PROPN []
# Soviet compound Union PROPN []
# Union appos Republic PROPN [Soviet]
# . punct born VERB []
# NP She She nsubj applied
# NP Cornell University University pobj to
# NP she she nsubj studied
# NP physics physics dobj studied
# NP Philip Morrison Morrison pobj under
# NP Richard Feynman Feynman conj Morrison
# NP Hans Bethe Bethe conj Feynman
# She nsubj applied VERB []
# applied ROOT applied VERB [She, to, .]
# to prep applied VERB [University]
# Cornell compound University PROPN []
# University pobj to ADP [Cornell, ,, studied]
# , punct University PROPN []
# where advmod studied VERB []
# she nsubj studied VERB []
# studied relcl University PROPN [where, she, physics, under]
# ...
# ( punct countrychorus.wordpress.com X []
# countrychorus.wordpress.com appos Saturday PROPN [(, )]
# ) punct countrychorus.wordpress.com X []
# Happy amod news NOUN []
# news dobj married VERB [Happy, for, opted]
# for prep news NOUN [Lambert]
# Miranda compound Lambert PROPN []
# Lambert pobj for ADP [Miranda, and, Shelton]
# and cc Lambert PROPN []
# Blake compound Shelton PROPN []
# Shelton conj Lambert PROPN [Blake]
# opted acl news NOUN [for]
# for prep opted VERB [ceremony]
# a det ceremony NOUN []
# wedding compound ceremony NOUN []
# ceremony pobj for ADP [a, wedding, held]
# that nsubjpass held VERB []
# was auxpass held VERB []
# held relcl ceremony NOUN [that, was, at]
# at prep held VERB [Ranch]
# the det Ranch PROPN []
# Don compound Strange PROPN []
# Strange compound Ranch PROPN [Don]
# Ranch pobj at ADP [the, Strange, in, north]
# in prep Ranch PROPN [Boerne]
# Boerne pobj in ADP [,, Texas, ,]
# , punct Boerne PROPN []
# Texas appos Boerne PROPN []
# , punct Boerne PROPN []
# north npadvmod Ranch PROPN [of]
# of prep north NOUN [Antonio]
# San compound Antonio PROPN []
# Antonio pobj of ADP [San]
# . punct married VERB []
# NP Those aspirations aspirations nsubjpass remembered
# NP science fiction fiction pobj in
# NP Arthur C. Clarke 's A Fall Fall pobj as
# NP Moondust Moondust pobj of
# Those det aspirations NOUN []
# aspirations nsubjpass remembered VERB [Those]
# are auxpass remembered VERB []
# remembered ROOT remembered VERB [aspirations, are, in]
# in prep remembered VERB [fiction]
# science compound fiction NOUN []
# fiction pobj in ADP [science, as]
# such amod as ADP []
# as prep fiction NOUN [such, Fall]
# Arthur compound Clarke PROPN []
# C. compound Clarke PROPN []
# Clarke poss Fall NOUN [Arthur, C., 's]
# 's case Clarke PROPN []
# A det Fall NOUN []
# Fall pobj as ADP [Clarke, A, of, and, 2001]
# of prep Fall NOUN [Moondust]
# Moondust pobj of ADP []
# and cc Fall NOUN []
# also advmod 2001 NUM []
# 2001 conj Fall NOUN [also, :]
# : punct 2001 NUM []
# NP House House pobj In
# NP Bush Bush pobj of
# NP House House conj House
# NP Saud Saud pobj of
# NP Craig Unger Unger nsubj asserts
# NP the time time pobj at
# NP Bush 's sale sale pobj of
# NP Harken Energy Energy nsubjpass expected
# NP money money pobj of
# NP just three days days pobj in
# In prep asserts VERB [House]
# House pobj In ADP [of, House]
# of prep House PROPN [Bush]
# Bush pobj of ADP [,]
# , punct Bush PROPN []
# House conj House PROPN [of]
# of prep House PROPN [Saud]
# Saud pobj of ADP []
# , punct asserts VERB []
# Craig compound Unger PROPN []
# Unger nsubj asserts VERB [Craig]
# asserts ROOT asserts VERB [In, ,, Unger, expected]
# that mark expected VERB []
# at prep expected VERB [time]
# the det time NOUN []
# time pobj at ADP [the, of]
# of prep time NOUN [sale]
# Bush poss sale NOUN ['s]
# 's case Bush PROPN []
# sale pobj of ADP [Bush]
# , punct expected VERB []
# Harken compound Energy PROPN []
# Energy nsubjpass expected VERB [Harken]
# `` punct expected VERB []
# was auxpass expected VERB []
# expected ccomp asserts VERB [that, at, ,, Energy, ``, was, run, '', (]
# to aux run VERB []
# run xcomp expected VERB [to, out, in]
# out prep run VERB [of]
# of prep out ADP [money]
# money pobj of ADP []
# in prep run VERB [days]
# just advmod three NUM []
# three nummod days NOUN [just]
# days pobj in ADP [three]
# '' punct expected VERB []
# ( punct expected VERB []
# NP the site site nsubjpass hosted
# NP the servers servers pobj on
# NP Bomis , Inc. Inc. pobj of
# NP a company company appos Inc.
# NP Jimmy Wales Wales pobj by
# Previously advmod hosted VERB []
# , punct hosted VERB []
# the det site NOUN []
# site nsubjpass hosted VERB [the]
# was auxpass hosted VERB []
# hosted ROOT hosted VERB [Previously, ,, site, was, on, .]
# on prep hosted VERB [servers]
# the det servers NOUN []
# servers pobj on ADP [the, of]
# of prep servers NOUN [Inc.]
# Bomis nmod Inc. PROPN []
# , punct Inc. PROPN []
# Inc. pobj of ADP [Bomis, ,, ,, company]
# , punct Inc. PROPN []
# a det company NOUN []
# company appos Inc. PROPN [a, owned]
# mostly advmod owned VERB []
# owned acl company NOUN [mostly, by]
# by agent owned VERB [Wales]
# Jimmy compound Wales PROPN []
# Wales pobj by ADP [Jimmy]
# . punct hosted VERB []
# NP He He nsubj is
# NP an astute reader reader attr is
# NP science science pobj of
# NP social science science conj science
# NP history history conj science
# NP literature literature conj history
# He nsubj is VERB []
# is ROOT is VERB [He, reader, .]
# an det reader NOUN []
# astute amod reader NOUN []
# reader attr is VERB [an, astute, of]
# of prep reader NOUN [science]
# science pobj of ADP [,, science]
# , punct science NOUN []
# social amod science NOUN []
# science conj science NOUN [social, ,, history]
# , punct science NOUN []
# history conj science NOUN [,, and, literature]
# , punct history NOUN []
# and cc history NOUN []
# literature conj history NOUN []
# . punct is VERB []
# NP The affair affair nsubjpass terminated
# NP the government 's Cabinet Secretary Secretary pobj by
# NP Sir Norman Brook Brook appos Secretary
# NP who who nsubj spoke
# NP Profumo Profumo pobj to
# NP the advice advice pobj on
# NP Sir Roger Hollis Hollis pobj of
# NP the head head appos Hollis
# NP MI5 MI5 pobj of
# The det affair NOUN []
# affair nsubjpass terminated VERB [The]
# was auxpass terminated VERB []
# terminated ROOT terminated VERB [affair, was, by, .]
# by agent terminated VERB [Secretary]
# the det government NOUN []
# government poss Secretary PROPN [the, 's]
# 's case government NOUN []
# Cabinet compound Secretary PROPN []
# Secretary pobj by ADP [government, Cabinet, ,, Brook, ,, spoke]
# , punct Secretary PROPN []
# Sir compound Brook PROPN []
# Norman compound Brook PROPN []
# Brook appos Secretary PROPN [Sir, Norman]
# , punct Secretary PROPN []
# who nsubj spoke VERB []
# spoke relcl Secretary PROPN [who, to, on]
# to prep spoke VERB [Profumo]
# Profumo pobj to ADP []
# on prep spoke VERB [advice]
# the det advice NOUN []
# advice pobj on ADP [the, of]
# of prep advice NOUN [Hollis]
# Sir compound Hollis PROPN []
# Roger compound Hollis PROPN []
# Hollis pobj of ADP [Sir, Roger, ,, head]
# , punct Hollis PROPN []
# the det head NOUN []
# head appos Hollis PROPN [the, of]
# of prep head NOUN [MI5]
# MI5 pobj of ADP []
# . punct terminated VERB []
# NP The title title nsubjpass based
# NP this 'toon toon pobj of
# NP the book book pobj on
# NP The Best Christmas Pageant Pageant appos based
# NP Barbara Robinson Robinson pobj by
# The det title NOUN []
# title nsubjpass based VERB [The, of]
# of prep title NOUN [toon]
# this det toon NOUN []
# ' punct toon NOUN []
# toon pobj of ADP [this, ']
# is auxpass based VERB []
# based ROOT based VERB [title, is, on, ,, ``, Pageant, .]
# on prep based VERB [book]
# the det book NOUN []
# book pobj on ADP [the]
# , punct based VERB []
# `` punct based VERB []
# The det Pageant PROPN []
# Best amod Pageant PROPN []
# Christmas compound Pageant PROPN []
# Pageant appos based VERB [The, Best, Christmas, Ever, '', ,, by]
# Ever advmod Pageant PROPN []
# '' punct Pageant PROPN []
# , punct Pageant PROPN []
# by prep Pageant PROPN [Robinson]
# Barbara compound Robinson PROPN []
# Robinson pobj by ADP [Barbara]
# . punct based VERB []
# NP He He nsubj brought
# NP 400 Christians Christians dobj brought
# NP Baghdad Baghdad pobj from
# NP Nineveh Nineveh conj Baghdad
# NP Jerusalem Jerusalem conj Nineveh
# NP Kodungallur Kodungallur pobj to
# He nsubj brought VERB []
# brought ROOT brought VERB [He, Christians, from, to, .]
# 400 nummod Christians PROPN []
# Christians dobj brought VERB [400]
# from prep brought VERB [Baghdad]
# Baghdad pobj from ADP [,, Nineveh]
# , punct Baghdad PROPN []
# Nineveh conj Baghdad PROPN [,, and, Jerusalem]
# , punct Nineveh PROPN []
# and cc Nineveh PROPN []
# Jerusalem conj Nineveh PROPN []
# to prep brought VERB [Kodungallur]
# Kodungallur pobj to ADP []
# . punct brought VERB []
# NP Jonathon Jonathon nsubjpass interviewed
# NP Robert Scoble Scoble pobj by
# NP Rackspace Rackspace pobj of
# Jonathon nsubjpass interviewed VERB []
# is auxpass interviewed VERB []
# interviewed ROOT interviewed VERB [Jonathon, is, here, by, .]
# here advmod interviewed VERB []
# by agent interviewed VERB [Scoble]
# Robert compound Scoble PROPN []
# Scoble pobj by ADP [Robert, of]
# of prep Scoble PROPN [Rackspace]
# Rackspace pobj of ADP []
# . punct interviewed VERB []
# NP 23 year old Prince Albert Albert appos A
# NP Consort Consort appos Albert
# NP Queen Victoria Victoria pobj to
# The det A DET []
# Pub compound Sign PROPN []
# Sign compound A DET [Pub]
# A ROOT A DET [The, Sign, Albert, .]
# 23 nummod year NOUN []
# year npadvmod old ADJ [23]
# old amod Albert PROPN [year]
# Prince compound Albert PROPN []
# Albert appos A DET [old, Prince, ,, Consort]
# , punct Albert PROPN []
# Consort appos Albert PROPN [to]
# to prep Consort PROPN [Victoria]
# Queen compound Victoria PROPN []
# Victoria pobj to ADP [Queen]
# . punct A DET []
# NP – Stanley Pons Pons nsubj announce
# NP Martin Fleischmann Fleischmann conj Pons
# NP cold fusion fusion dobj announce
# NP the University University pobj at
# NP Utah Utah pobj of
# – punct Pons PROPN []
# Stanley compound Pons PROPN []
# Pons nsubj announce VERB [–, Stanley, and, Fleischmann]
# and cc Pons PROPN []
# Martin compound Fleischmann PROPN []
# Fleischmann conj Pons PROPN [Martin]
# announce ROOT announce VERB [Pons, fusion, at, .]
# cold amod fusion NOUN []
# fusion dobj announce VERB [cold]
# at prep announce VERB [University]
# the det University PROPN []
# University pobj at ADP [the, of]
# of prep University PROPN [Utah]
# Utah pobj of ADP []
# . punct announce VERB []
# NP A libertarian-leaning friend friend nsubj sends
# NP this column column pobj over
# NP Uni Chicago Economists Economists pobj by
# NP Hoover Institute Fellows Gary Becker Becker conj Economists
# NP ( Nobel Laureate Laureate appos Becker
# NP Kevin Murphy Murphy conj sends
# NP do no harm ” approach approach dobj advocating
# NP the current crisis crisis pobj to
# A det friend NOUN []
# libertarian npadvmod leaning VERB []
# - punct leaning VERB []
# leaning amod friend NOUN [libertarian, -]
# friend nsubj sends VERB [A, leaning]
# sends ROOT sends VERB [friend, over, by, !, ), and, Murphy, ,, advocating, .]
# over prep sends VERB [column]
# this det column NOUN []
# column pobj over ADP [this]
# by prep sends VERB [Economists]
# Uni compound Economists PROPN []
# Chicago compound Economists PROPN []
# Economists pobj by ADP [Uni, Chicago, and, Becker]
# and cc Economists PROPN []
# Hoover compound Institute PROPN []
# Institute compound Becker PROPN [Hoover]
# Fellows compound Becker PROPN []
# Gary compound Becker PROPN []
# Becker conj Economists PROPN [Institute, Fellows, Gary, Laureate]
# ( punct Laureate PROPN []
# Nobel compound Laureate PROPN []
# Laureate appos Becker PROPN [(, Nobel]
# ! punct sends VERB []
# ) punct sends VERB []
# and cc sends VERB []
# Kevin compound Murphy PROPN []
# Murphy conj sends VERB [Kevin]
# , punct sends VERB []
# advocating advcl sends VERB [“, approach]
# a det “ PUNCT []
# “ dobj advocating VERB [a]
# do nmod harm NOUN []
# no det harm NOUN []
# harm nmod approach NOUN [do, no, ”]
# ” punct harm NOUN []
# approach dobj advocating VERB [harm, to]
# to prep approach NOUN [crisis]
# the det crisis NOUN []
# current amod crisis NOUN []
# crisis pobj to ADP [the, current]
# . punct sends VERB []
# NP northern India India pobj In
# NP Hindu 's flock flock pobj In
# NP pilgramage centers centers pobj to
# NP Char Dham Dham pobj as
# NP Haridwar Haridwar conj Dham
# NP Mathura Mathura conj Haridwar
# NP Allahabad Allahabad conj Mathura
# NP Varanasi Varanasi conj Allahabad
# In ROOT In ADP [India, ,, flock]
# northern amod India PROPN []
# India pobj In ADP [northern]
# , punct In ADP []
# Hindu poss flock NOUN ['s]
# 's case Hindu PROPN []
# flock pobj In ADP [Hindu, to, .]
# to prep flock NOUN [centers]
# pilgramage compound centers NOUN []
# centers pobj to ADP [pilgramage, as]
# such amod as ADP []
# as prep centers NOUN [such, Dham]
# Char compound Dham PROPN []
# Dham pobj as ADP [Char, ,, Haridwar]
# , punct Dham PROPN []
# Haridwar conj Dham PROPN [,, Mathura]
# , punct Haridwar PROPN []
# Mathura conj Haridwar PROPN [,, Allahabad]
# , punct Mathura PROPN []
# Allahabad conj Mathura PROPN [and, Varanasi]
# and cc Allahabad PROPN []
# Varanasi conj Allahabad PROPN []
# . punct flock NOUN []
# NP The best comic book book nsubj was
# NP I I nsubj read
# NP the truly tearful Pride Pride attr was
# NP Baghdad Baghdad pobj Of
# NP Brian K. Vaughan Vaughan pobj by
# NP Niko Henrichon Henrichon conj Vaughan
# The det book NOUN []
# best amod book NOUN []
# comic amod book NOUN []
# book nsubj was VERB [The, best, comic, read]
# that dobj read VERB []
# I nsubj read VERB [’]
# ’ appos I PRON []
# ve aux read VERB []
# read relcl book NOUN [that, I, ve, recently]
# recently advmod read VERB []
# was ROOT was VERB [book, Pride, .]
# the det Pride PROPN []
# truly advmod tearful ADJ []
# tearful amod Pride PROPN [truly]
# Pride attr was VERB [the, tearful, Of, by]
# Of prep Pride PROPN [Baghdad]
# Baghdad pobj Of ADP []
# by prep Pride PROPN [Vaughan]
# Brian compound Vaughan PROPN []
# K. compound Vaughan PROPN []
# Vaughan pobj by ADP [Brian, K., and, Henrichon]
# and cc Vaughan PROPN []
# Niko compound Henrichon PROPN []
# Henrichon conj Vaughan PROPN [Niko]
# . punct was VERB []
# NP “ Batman Batman ROOT Batman
# NP Nighttown Nighttown pobj in
# NP Karen Haber Haber pobj by
# NP Robert Silverberg Silverberg conj Haber
# “ compound Batman PROPN []
# Batman ROOT Batman PROPN [“, in, ”, ,, by]
# in prep Batman PROPN [Nighttown]
# Nighttown pobj in ADP []
# ” advmod Batman PROPN []
# , punct Batman PROPN []
# by prep Batman PROPN [Haber]
# Karen compound Haber PROPN []
# Haber pobj by ADP [Karen, and, Silverberg]
# and cc Haber PROPN []
# Robert compound Silverberg PROPN []
# Silverberg conj Haber PROPN [Robert]
# NP King Robert III III ROOT III
# NP Scotland Scotland pobj of
# NP son son appos III
# NP King Robert II II pobj of
# NP Scotland Scotland pobj of
# NP Elizabeth Mure Mure conj II
# King compound III PROPN []
# Robert compound III PROPN []
# III ROOT III PROPN [King, Robert, of, ,, son, .]
# of prep III PROPN [Scotland]
# Scotland pobj of ADP []
# , punct III PROPN []
# son appos III PROPN [of]
# of prep son NOUN [II]
# King compound II PROPN []
# Robert compound II PROPN []
# II pobj of ADP [King, Robert, of, and, Mure]
# of prep II PROPN [Scotland]
# Scotland pobj of ADP []
# and cc II PROPN []
# Elizabeth compound Mure PROPN []
# Mure conj II PROPN [Elizabeth]
# . punct III PROPN []
# NP The lyrics lyrics ROOT lyrics
# NP another track track pobj from
# NP The Hula Hula Boys Boys nsubjpass excerpted
# NP Hunter S. Thompson 's 1983 book book pobj in
# NP The Curse Curse appos book
# NP Lono Lono pobj of
# The det lyrics NOUN []
# lyrics ROOT lyrics NOUN [The, from, ,, ``, excerpted, .]
# from prep lyrics NOUN [track]
# another det track NOUN []
# track pobj from ADP [another]
# , punct lyrics NOUN []
# `` punct lyrics NOUN []
# The det Boys PROPN []
# Hula compound Hula PROPN []
# Hula compound Boys PROPN [Hula]
# Boys nsubjpass excerpted VERB [The, Hula]
# `` punct excerpted VERB []
# , punct excerpted VERB []
# were auxpass excerpted VERB []
# excerpted acl lyrics NOUN [Boys, ``, ,, were, in]
# in prep excerpted VERB [book]
# Hunter compound Thompson PROPN []
# S. compound Thompson PROPN []
# Thompson poss book NOUN [Hunter, S., 's]
# 's case Thompson PROPN []
# 1983 nummod book NOUN []
# book pobj in ADP [Thompson, 1983, ,, Curse]
# , punct book NOUN []
# The det Curse NOUN []
# Curse appos book NOUN [The, of]
# of prep Curse NOUN [Lono]
# Lono pobj of ADP []
# . punct lyrics NOUN []
# NP 6 August August pobj On
# NP an ultimatum ultimatum pobj following
# NP Napoleon Napoleon pobj by
# NP Francis II II nsubj gave
# NP his title title dobj gave
# NP Emperor Emperor pobj of
# NP the Holy Roman Empire Empire nsubj dissolved
# On prep gave VERB [August]
# 6 nummod August PROPN []
# August pobj On ADP [6]
# , punct gave VERB []
# following prep gave VERB [ultimatum]
# an det ultimatum NOUN []
# ultimatum pobj following VERB [an, by]
# by prep ultimatum NOUN [Napoleon]
# Napoleon pobj by ADP []
# , punct gave VERB []
# Francis compound II PROPN []
# II nsubj gave VERB [Francis]
# gave ROOT gave VERB [On, ,, following, ,, II, up, title, and, declared, .]
# up prt gave VERB []
# his poss title NOUN []
# title dobj gave VERB [his, of]
# of prep title NOUN [Emperor]
# Emperor pobj of ADP []
# and cc gave VERB []
# declared conj gave VERB [dissolved]
# the det Empire PROPN []
# Holy compound Empire PROPN []
# Roman compound Empire PROPN []
# Empire nsubj dissolved VERB [the, Holy, Roman]
# dissolved ccomp declared VERB [Empire]
# . punct gave VERB []

# %% [raw]
# # def id_named_entities(data):
#
# #     for ex in data[1:2]:
# #         print(ex)
# #         text = rebuild_text(ex.snippet[0])
# #         pro_text = nlp(text)
# #         for m in pro_text.ents:
# #             print(m)
#
#
# #         m1 = nlp(ex.snippet[2].mention_1)
# #         m2 = nlp(ex.snippet[2].mention_2)
# #         print(m1)
# #         print(m1.ents)
# #         for m in m1.ents:
# #             print(m.label_)
#
# #         for m in mentions:
# #         print(m.ents.label_)
#
# #         for s in ex:
# #             text = rebuild_text(s)
# #             print(text)
# #         text = rebuild_text(ex)
# #         text = nlp(text)
# #         print(text.ents)
#
# # id_named_entities(train_data)

# %%
def tag_tokens(doc):
    tagged_ex = []
    
    for w in doc:
        if w.orth_ == "MENTION_1" or w.orth_ == "MENTION_2":
            tagged_ex.append(w.orth_)
        else:
            tagged_ex.append(w.pos_)
            
    tagged_ex = " ".join(tagged_ex)
    
    return tagged_ex

# %%
def lemmatize(doc):
    lemmas = []
    
    for w in doc:
        if w.lemma_ == "-PRON-" or w.orth_ == "MENTION_1" or w.orth_ == "MENTION_2":
            lemmas.append(w.orth_)
        else:
            lemmas.append(w.lemma_)
    
    lemmas = " ".join(lemmas)
    
    return lemmas

# %%
##################################################################################################
# 2.1 NLP PROCESS CORPUS
##################################################################################################

def nlp(data, verbose=True):
    context_data = []
    for instance in data:
        instance_context = []
        for s in instance.snippet:
            context = nlp(s.left, "MENTION_1", s.middle, "MENTION_2", s.right)
            instance_context.append(context)
        context_data.append(instance_context)
    
    if verbose:
        print(len(data))
        print(len(context_data))
        print(data[0])
        print(context_data[0])
    
    return context_data

# %%
##################################################################################################
# 2. EXTRACT FEATURES and BUILD CLASSIFIER
##################################################################################################

# Turn data into numerical features

def SelectContext(data, use_lemmas=False, use_tags=False, verbose=True):
    only_context_data = []
    for instance in data:
        instance_context = []
        for s in instance.snippet:
            if use_lemmas:  
                context = lemmatize(s.left + " MENTION_1 " + s.middle + " MENTION_2 " + s.right)
                instance_context.append(context)
#             if use_tags:
#                 context = tag_tokens(s.left + " MENTION_1 " + s.middle + " MENTION_2 " + s.right)
#                 context = ' '.join((tag_tokens(s.left), "m1", tag_tokens(s.middle), "m2", tag_tokens(s.right)))
#                 instance_context.append(context)

            else:
                context = ' '.join((s.left, "MENTION_1", s.middle, "MENTION_2", s.right))
                instance_context.append(context)
        only_context_data.append(' '.join(instance_context))
    if verbose:
        print(len(data))
        print(len(only_context_data))
        print(data[0])
        print(only_context_data[0])
    return only_context_data

# %%
# Transform dataset to features
train_data_featurized = SelectContext(train_data, use_lemmas=False, use_tags=True)

# Transform labels to nimeric values
le = LabelEncoder()
train_labels_featurized = le.fit_transform(train_labels)

# Fit model one vs rest logistic regression    
clf = make_pipeline(CountVectorizer(), LogisticRegression())
# Out:
# thirty and his life and career were riding high . In 1941 , shortly after the death of his father , Mercer began an intense affair with nineteen-year-old MENTION_1 while she was engaged to composer MENTION_2 . Garland married Rose to temporarily stop the affair , but the effect on Mercer lingered , adding to the emotional depth of his lyrics . Their affair
# NUM CCONJ ADJ NOUN CCONJ NOUN VERB VERB ADJ PUNCT ADP NUM PUNCT ADV ADP DET NOUN ADP ADJ NOUN PUNCT PROPN VERB DET ADJ NOUN ADP NUM PUNCT NOUN PUNCT ADJ MENTION_1 ADP PRON VERB VERB ADP NOUN MENTION_2 PUNCT PROPN VERB PROPN PART ADV VERB DET NOUN PUNCT CCONJ DET NOUN ADP PROPN VERB PUNCT VERB ADP DET ADJ NOUN ADP ADJ NOUN PUNCT ADJ NOUN
# Latest activity 4 Other Sweet-Treat Wikia Summary of a Sweet Adventure Edit Charlie and the Chocolate Factory is a 2005 film adaptation of the 1964 MENTION_1 by MENTION_2 . Directed by Tim Burton , the film stars Freddie Highmore as Charlie Bucket and Johnny Depp as Willy Wonka . The storyline concerns a
# ADJ NOUN NUM ADJ PROPN PUNCT PROPN PROPN PROPN ADP DET PROPN PROPN PROPN PROPN CCONJ DET PROPN PROPN VERB DET NUM NOUN NOUN ADP DET NUM MENTION_1 ADP MENTION_2 PUNCT VERB ADP PROPN PROPN PUNCT DET NOUN VERB PROPN PROPN ADP PROPN PROPN CCONJ PROPN PROPN ADP PROPN PROPN PUNCT DET NOUN VERB DET
# a Screen Actors Guild Award nomination . In 2005 , he played the part of the hard-working Charlie Bucket in Charlie and the Chocolate Factory ( adapted from MENTION_1 by MENTION_2 ) . He was reportedly recommended for the role by the film 's star Johnny Depp , who starred in Finding Neverland and was impressed by the
# DET PROPN PROPN PROPN PROPN NOUN PUNCT ADP NUM PUNCT PRON VERB DET NOUN ADP DET ADV PUNCT VERB PROPN PROPN ADP PROPN CCONJ DET PROPN PROPN PUNCT VERB ADP MENTION_1 ADP MENTION_2 PUNCT PUNCT PRON VERB ADV VERB ADP DET NOUN ADP DET NOUN PART NOUN PROPN PROPN PUNCT NOUN VERB ADP PROPN PROPN CCONJ VERB ADJ ADP DET
# actors who were scheduled to not make it on a Saturday . Both the episode 's title and the episode itself is based off the novel , `` MENTION_1 `` by MENTION_2 . During the episode , the final seven adventurers are eliminated from the challenge at various places in the factory . Leshawna falls into a chocolate river
# NOUN NOUN VERB VERB PART ADV VERB PRON ADP DET PROPN PUNCT CCONJ DET NOUN PART NOUN CCONJ DET NOUN PRON VERB VERB ADP DET NOUN PUNCT PUNCT MENTION_1 PUNCT ADP MENTION_2 PUNCT ADP DET NOUN PUNCT DET ADJ NUM NOUN VERB VERB ADP DET NOUN ADP ADJ NOUN ADP DET NOUN PUNCT PROPN VERB ADP DET NOUN NOUN
# Into The Factory A surprising revelation about Dahl 's masterpiece While researching my first MG Adventure , I took a really close look at the structure of MENTION_1 , which MENTION_2 was apparently inspired to right by his childhood experiences as a chocolate tester at school . I ca n't tell you how surprised I was to find
# ADP DET PROPN DET ADJ NOUN ADP PROPN PART NOUN ADP VERB ADJ ADJ PROPN PROPN PUNCT PRON VERB DET ADV ADJ NOUN ADP DET NOUN ADP MENTION_1 PUNCT ADJ MENTION_2 VERB ADV VERB ADP ADV ADP ADJ NOUN NOUN ADP DET NOUN ADV ADP NOUN PUNCT PRON VERB ADV VERB PRON ADV ADJ PRON VERB PART VERB
# mark this work as a show of great promise . James and the Giant Peach was one of my favorite childhood books , even more so than MENTION_1 , which is also by author MENTION_2 . I was excited to hear about a musical version in the works , particularly when I heard that the folks at Pilobolus , one of my
# VERB DET NOUN ADP DET NOUN ADP ADJ NOUN PUNCT PROPN CCONJ DET PROPN PROPN VERB NUM ADP ADJ ADJ NOUN NOUN PUNCT ADV ADV ADV ADP MENTION_1 PUNCT ADJ VERB ADV ADP NOUN MENTION_2 PUNCT PRON VERB ADJ PART VERB ADP DET ADJ NOUN ADP DET NOUN PUNCT ADV ADV PRON VERB ADP DET NOUN ADP PROPN PUNCT NUM ADP ADJ
# introduced . The Very Hungry Caterpillar and Each Peach Pear Plum were , and remain firm children 's favourites . Puffin further augmented its position with hits such as MENTION_1 by MENTION_2 and Watership Down by Richard Adams . [ 1 ] The 1980s saw Puffin taking full advantage of popular culture with film tie-in publishing , forming close links
# VERB PUNCT DET PROPN PROPN PROPN CCONJ DET PROPN PROPN PROPN VERB PUNCT CCONJ VERB ADJ NOUN PART NOUN PUNCT PROPN ADV VERB ADJ NOUN ADP NOUN ADJ ADP MENTION_1 ADP MENTION_2 CCONJ PROPN PROPN ADP PROPN PROPN PUNCT PUNCT PUNCT PUNCT DET NUM VERB PROPN VERB ADJ NOUN ADP ADJ NOUN ADP NOUN NOUN PUNCT PART NOUN PUNCT VERB ADJ NOUN
# Punjab . He was also the voice of Ray in Bear in the Big Blue House and also provided narration for Tim Burton 's version of MENTION_1 's MENTION_2 . [ 11 ] He reprised his role as the 7 Up Spokesman in the 2011 season finale of The Celebrity Apprentice , where he appeared as
# NOUN PUNCT PRON VERB ADV DET NOUN ADP PROPN ADP PROPN ADP DET PROPN PROPN PROPN CCONJ ADV VERB NOUN ADP PROPN PROPN PART NOUN ADP MENTION_1 PART MENTION_2 PUNCT PUNCT NUM PUNCT PRON VERB ADJ NOUN ADP DET NUM PROPN PROPN ADP DET NUM NOUN NOUN ADP DET PROPN PROPN PUNCT ADV PRON VERB ADP
# to add a quarter of a drop of lemon essential oil and I felt like Violet Beauregarde ( the girl who chews gum all day in MENTION_1 ’ s children ’ s books MENTION_2 ) as the taste of the Dragonwell was followed closely by the peppermint and the lemon came through on the taste right at the end .
# PART VERB DET NOUN ADP DET NOUN ADP NOUN ADJ NOUN CCONJ PRON VERB ADP PROPN PROPN PUNCT DET NOUN NOUN VERB VERB DET NOUN ADP MENTION_1 PUNCT PART NOUN PART PART NOUN MENTION_2 PUNCT ADP DET NOUN ADP DET PROPN VERB VERB ADV ADP DET NOUN CCONJ DET NOUN VERB PART ADP DET NOUN ADV ADP DET NOUN PUNCT
# Chocolate Factory Charlie and the Chocolate Factory is a 2005 fantasy film directed by Tim Burton and starring Johnny Depp . Based on the 1964 MENTION_1 childre MENTION_2 , the film also stars Freddie Highmore as Charlie Bucket and is the second film adaptation of the book . It is also the second film
# PROPN PROPN PROPN CCONJ DET PROPN PROPN VERB DET NUM NOUN NOUN VERB ADP PROPN PROPN CCONJ VERB PROPN PROPN PUNCT VERB ADP DET NUM MENTION_1 NOUN MENTION_2 PUNCT DET NOUN ADV VERB PROPN PROPN ADP PROPN PROPN CCONJ VERB DET ADJ NOUN NOUN ADP DET NOUN PUNCT PRON VERB ADV DET ADJ NOUN
# from ! ) Master Mime Wild West , Legendary Swords But wait ! There 's More ! I have reason to believe that the next island will be based on MENTION_1 's 1964 book MENTION_2 ( or one of the movie s ) . ... ... ... Hey wait ! Come back ! I have proof ! Look here ... Aanndd ... Ta-da ! Do n't get it ? Okay ... Here
# ADP PUNCT PUNCT PROPN PROPN PROPN PROPN PUNCT PROPN PROPN CCONJ VERB PUNCT ADV VERB ADJ PUNCT PRON VERB NOUN PART VERB ADP DET ADJ NOUN VERB VERB VERB ADP MENTION_1 PART NUM NOUN MENTION_2 PUNCT CCONJ NUM ADP DET NOUN NOUN PUNCT PUNCT PUNCT PUNCT PUNCT INTJ VERB PUNCT VERB ADV PUNCT PRON VERB NOUN PUNCT VERB ADV PUNCT PROPN PUNCT PROPN PUNCT PROPN PUNCT VERB ADV VERB PRON PUNCT INTJ PUNCT ADV
# hollow , or filled with other sweets or fondant . Books and film Chocolate has been the center of several successful book and film adaptations . In 1964 , MENTION_1 published a children ’ s novel titled MENTION_2 . The novel centers on a poor boy named Charlie Bucket who takes a tour through the greatest chocolate factory in the world , owned by
# ADJ PUNCT CCONJ VERB ADP ADJ NOUN CCONJ ADJ PUNCT NOUN CCONJ NOUN PROPN VERB VERB DET NOUN ADP ADJ ADJ NOUN CCONJ NOUN NOUN PUNCT ADP NUM PUNCT MENTION_1 VERB DET NOUN PART PART NOUN VERB MENTION_2 PUNCT DET ADJ NOUN ADP DET ADJ NOUN VERB PROPN PROPN NOUN VERB DET NOUN ADP DET ADJ NOUN NOUN ADP DET NOUN PUNCT VERB ADP
# item : gnauga hide ( 10.1 % chance ) * You gain 9 < substat > . Occurs at Thugnderdome . References `` Strike that . Reverse it . '' is a reference to MENTION_1 's 1964 children 's book , MENTION_2 where Willy Wonka occasionally reversed what he meant . The gnauga itself refers to Naugahyde and its mascot , Naugahyde itself being pleather . Early Naugahyde marketing
# NOUN PUNCT VERB NOUN PUNCT NUM NOUN NOUN PUNCT PUNCT PRON VERB NUM X NOUN X PUNCT VERB ADP PROPN PUNCT NOUN PUNCT VERB DET PUNCT VERB PRON PUNCT PUNCT VERB DET NOUN ADP MENTION_1 PART NUM NOUN PART NOUN PUNCT MENTION_2 ADV PROPN PROPN ADV VERB NOUN PRON VERB PUNCT DET NOUN PRON VERB ADP PROPN CCONJ ADJ NOUN PUNCT NOUN PRON VERB NOUN PUNCT ADJ NOUN NOUN
# 8300 Pleasant Plains Road in Towson . Theater-goers are invited to enjoy the sweet story of Willy , Charlie Bucket , and the Oompa Loompas , all based on MENTION_1 's 1964 children 's novel MENTION_2 . Contact : Stephen Jasper or Maureen Partilla , Pleasant Plains Elementary School , 410.887.3549 Monday , April 30 Red , White , and Blue prevails at the Kingsville Elementary School
# NUM PROPN PROPN PROPN ADP PROPN PUNCT NOUN PUNCT NOUN VERB VERB PART VERB DET ADJ NOUN ADP PROPN PUNCT PROPN PROPN PUNCT CCONJ DET PROPN PROPN PUNCT DET VERB ADP MENTION_1 PART NUM NOUN PART ADJ MENTION_2 PUNCT NOUN PUNCT PROPN PROPN CCONJ PROPN PROPN PUNCT PROPN PROPN PROPN PROPN PUNCT NUM PROPN PUNCT PROPN NUM PROPN PUNCT PROPN PUNCT CCONJ PROPN VERB ADP DET PROPN PROPN PROPN
# chocolate candies , usually variants of their standard fare . Books and film Chocolate has been the center of several successful book and film adaptations . In 1964 , MENTION_1 published a children 's novel titled MENTION_2 . The novel centers on a poor boy named Charlie Bucket who takes a tour through the greatest chocolate factory in the world , owned by
# NOUN NOUN PUNCT ADV NOUN ADP ADJ ADJ NOUN PUNCT NOUN CCONJ NOUN PROPN VERB VERB DET NOUN ADP ADJ ADJ NOUN CCONJ NOUN NOUN PUNCT ADP NUM PUNCT MENTION_1 VERB DET NOUN PART NOUN VERB MENTION_2 PUNCT DET ADJ NOUN ADP DET ADJ NOUN VERB PROPN PROPN NOUN VERB DET NOUN ADP DET ADJ NOUN NOUN ADP DET NOUN PUNCT VERB ADP
# Contact Email2 Contact Url Subscribe to Blog Remember my Info Photo of `` Ptasie mleczko , '' a Polish chocolate ~ Wikimedia Commons The most satirical of all MENTION_1 novels for children are MENTION_2 and its sequel , Charlie and the Great Glass Elevator . In addition to his intense scrutiny of many prevalent issues in society , the author completes his scintillating
# NOUN NOUN NOUN PROPN PROPN ADP PROPN VERB ADJ PROPN PROPN ADP PUNCT PROPN NOUN PUNCT PUNCT DET ADJ NOUN PUNCT PROPN PROPN DET ADV ADJ ADP DET MENTION_1 NOUN ADP NOUN VERB MENTION_2 CCONJ ADJ NOUN PUNCT PROPN CCONJ DET PROPN PROPN PROPN PUNCT ADP NOUN ADP ADJ ADJ NOUN ADP ADJ ADJ NOUN ADP NOUN PUNCT DET NOUN VERB ADJ NOUN
# sauses etc . Page 547 ' ... engulfed in thick , slick , sour-smelling mayonnaise . ' The whole Kit 's experience in the mayonnaise factory is very much reminiscent to MENTION_1 's MENTION_2 . Cazzo , cretino Literally , `` Dick , cretin . '' Cazzo is a common Italian interjectionary obscenity , especially in the south . `` Cazzo , cretino , '' is akin to someone saying , `` Well
# NOUN X PUNCT NOUN NUM PUNCT PUNCT VERB ADP ADJ PUNCT ADJ PUNCT ADJ PUNCT VERB NOUN PUNCT PUNCT DET ADJ NOUN PART NOUN ADP DET NOUN NOUN VERB ADV ADV ADJ ADP MENTION_1 PART MENTION_2 PUNCT ADJ PUNCT ADJ ADV PUNCT PUNCT PROPN PUNCT NOUN PUNCT PUNCT PROPN VERB DET ADJ ADJ ADJ NOUN PUNCT ADV ADP DET NOUN PUNCT PUNCT ADJ PUNCT NOUN PUNCT PUNCT VERB ADJ ADP NOUN VERB PUNCT PUNCT INTJ
# a poor boy who wins the opportunity to tour the most eccentric and wonderful candy factory of all . Directed by Mel Stuart . Written by MENTION_1 , based on his book MENTION_2 . It 's everybody 's non-pollutionary , anti-institutionary , pro-confectionery factory of fun ! Taglines Contents 1 Willy Wonka 2 Oompa Loompas 3 Dialogue 4 Taglines 5 Cast 6 External
# DET ADJ NOUN NOUN VERB DET NOUN PART VERB DET ADV ADJ CCONJ ADJ NOUN NOUN ADP DET PUNCT VERB ADP PROPN PROPN PUNCT VERB ADP MENTION_1 PUNCT VERB ADP ADJ NOUN MENTION_2 PUNCT PRON VERB NOUN PART ADJ PUNCT ADJ PUNCT ADV PUNCT ADJ PUNCT ADJ PUNCT NOUN NOUN ADP NOUN PUNCT PROPN NOUN NUM PROPN PROPN NUM PROPN PROPN NUM PROPN NUM PROPN NUM PROPN NUM ADJ
# children were grateful to be able to stay together with the Edwards ' as their children . Trivia Edit Patricia Neal who played Julia was married to MENTION_1 , author of MENTION_2 and other famous children 's books . ? What Julia told Reverend Alden to read at her funeral was read at Michael Landon 's funeral . ? Read
# NOUN VERB ADJ PART VERB ADJ PART VERB ADV ADP DET PROPN PUNCT ADP ADJ NOUN PUNCT PROPN PROPN PROPN PROPN NOUN VERB PROPN VERB VERB ADP MENTION_1 PUNCT NOUN ADP MENTION_2 CCONJ ADJ ADJ NOUN PART NOUN PUNCT PUNCT NOUN PROPN VERB PROPN PROPN PART VERB ADP ADJ NOUN VERB VERB ADP PROPN PROPN PART NOUN PUNCT PUNCT VERB
# used . However , a few times an Ames room has also been shown explicitly . An Ames room is depicted in the 1971 film adaptation of the MENTION_1 novel MENTION_2 . The 1960s television show Voyage to the Bottom of the Sea used an Ames room in one episode to show , rather than just declare ,
# VERB PUNCT ADV PUNCT DET ADJ NOUN DET PROPN NOUN VERB ADV VERB VERB ADV PUNCT DET PROPN NOUN VERB VERB ADP DET NUM NOUN NOUN ADP DET MENTION_1 ADJ MENTION_2 PUNCT DET NUM NOUN NOUN PROPN ADP DET NOUN ADP DET PROPN VERB DET PROPN NOUN ADP NUM NOUN PART VERB PUNCT ADV ADP ADV VERB PUNCT
# in touch . Follow Letters of Note ... RSS | Email | Twitter Tumblr | Facebook Monday , 12 October 2009 Unrest at the Chocolate Factory 1964 : MENTION_1 's MENTION_2 is released , its Oompa Loompa characters depicted as a 3,000 strong tribe of black pygmies ( Pic ) , imported by Willy Wonka from the African
# ADP NOUN PUNCT VERB NOUN ADP NOUN PUNCT PROPN PROPN PROPN PROPN PROPN PROPN NOUN PROPN PROPN PUNCT NUM PROPN NUM PROPN ADP DET PROPN PROPN NUM PUNCT MENTION_1 PART MENTION_2 VERB VERB PUNCT ADJ PROPN PROPN NOUN VERB ADP DET NUM ADJ NOUN ADP ADJ NOUN PUNCT PROPN PUNCT PUNCT VERB ADP PROPN PROPN ADP DET ADJ
# various places claim the title , such as parts of southern Kham in northwestern Yunnan province , including the tourist destinations of Lijiang and Zhongdian . Places like MENTION_1 and MENTION_2 also claim the real Shangri-La was in its territory . In 2001 , Tibet Autonomous Region put forward a proposal that the three regions optimise all Shangri-la
# ADJ NOUN VERB DET NOUN PUNCT ADJ ADP NOUN ADP ADJ PROPN ADP ADJ PROPN NOUN PUNCT VERB DET NOUN NOUN ADP PROPN CCONJ PROPN PUNCT NOUN ADP MENTION_1 CCONJ MENTION_2 ADV VERB DET ADJ PROPN PUNCT PROPN VERB ADP ADJ NOUN PUNCT ADP NUM PUNCT PROPN PROPN PROPN VERB PART DET NOUN ADP DET NUM NOUN VERB DET PROPN PUNCT PROPN
# more research . Some taxonomists group snub-nosed monkeys together with the Pygathrix genus . Snub-nosed monkeys live in Asia , with a range covering southern China ( especially MENTION_1 , MENTION_2 , Yunnan , and Guizhou ) as well as the northern part of Vietnam . 09/03/16 08:11:15 from radarchive ( originally from shelbot ) 153 notes archive
# ADJ NOUN PUNCT DET NOUN NOUN NOUN PUNCT VERB NOUN ADV ADP DET PROPN NOUN PUNCT ADJ PUNCT VERB NOUN VERB ADP PROPN PUNCT ADP DET NOUN VERB ADJ PROPN PUNCT ADV MENTION_1 PUNCT MENTION_2 PUNCT PROPN PUNCT CCONJ PROPN PUNCT ADV ADV ADP DET ADJ NOUN ADP PROPN PUNCT NUM NUM ADP ADJ PUNCT ADV ADP NOUN PUNCT NUM NOUN ADJ
# full rounds , Zoe believes she would have aimed it at Daniel . She begs Lacy to help her escape soon , before she does something rash . Notes MENTION_1 is a non-fiction work by MENTION_2 . Among its themes are man 's tendency towards self-destruction , and that the more primitive parts of the brain ( the `` ghost in the machine '' ) can override
# ADJ NOUN PUNCT PROPN VERB PRON VERB VERB VERB PRON ADP PROPN PUNCT PRON VERB PROPN PART VERB ADJ VERB ADV PUNCT ADP PRON VERB NOUN ADJ PUNCT NOUN MENTION_1 VERB DET ADJ PUNCT NOUN NOUN ADP MENTION_2 PUNCT ADP ADJ NOUN VERB NOUN PART NOUN ADP NOUN PUNCT NOUN PUNCT CCONJ ADP DET ADV ADJ NOUN ADP DET NOUN PUNCT DET PUNCT NOUN ADP DET NOUN PUNCT PUNCT VERB VERB
# their ghost , they retain their humanity and individuality . The concept of the ghost was borrowed by Masamune Shirow from an essay on structuralism , `` MENTION_1 `` by MENTION_2 . The title The Ghost in the Machine itself was originally used by an English philosopher , Gilbert Ryle to mock the paradox of conventional
# ADJ NOUN PUNCT PRON VERB ADJ NOUN CCONJ NOUN PUNCT DET NOUN ADP DET NOUN VERB VERB ADP PROPN PROPN ADP DET NOUN ADP NOUN PUNCT PUNCT MENTION_1 PUNCT ADP MENTION_2 PUNCT DET NOUN DET PROPN ADP DET NOUN PRON VERB ADV VERB ADP DET ADJ NOUN PUNCT PROPN PROPN PART VERB DET NOUN ADP ADJ
# experience over a series of blogposts . This post shares the underlying principle of holocracy . Holocracy ? Its roots stem from an observation from psychologist and philosopher MENTION_1 , who , in his book MENTION_2 ( 1967 ) spoke about holons , individual units that whole unto themselves and are also are part of the whole . Simply said a business can be
# NOUN ADP DET NOUN ADP NOUN PUNCT DET NOUN VERB DET VERB NOUN ADP NOUN PUNCT PROPN PUNCT ADJ NOUN VERB ADP DET NOUN ADP NOUN CCONJ NOUN MENTION_1 PUNCT NOUN PUNCT ADP ADJ NOUN MENTION_2 PUNCT NUM PUNCT VERB ADP NOUN PUNCT ADJ NOUN ADJ VERB ADP PRON CCONJ VERB ADV VERB NOUN ADP DET NOUN PUNCT ADV VERB DET NOUN VERB VERB
# | Search Arthur Koestler Some general properties of self-regulating open hierarchic order ( SOHO ) ( 1969 ) from PanArchy Note The idea of the `` holon '' was introduced by MENTION_1 in MENTION_2 ( 1967 ) and was presented again at the Alpbach Symposium ( 1968 ) in a paper titled : `` Beyond Atomism and Holism - the concept of the holon .
# PROPN PROPN PROPN PROPN DET ADJ NOUN ADP NOUN PUNCT VERB ADJ ADJ NOUN PUNCT PROPN PUNCT PUNCT NUM PUNCT ADP PROPN VERB DET NOUN ADP DET PUNCT NOUN PUNCT VERB VERB ADP MENTION_1 ADP MENTION_2 PUNCT NUM PUNCT CCONJ VERB VERB ADV ADP DET PROPN PROPN PUNCT NUM PUNCT ADP DET NOUN VERB PUNCT PUNCT ADP PROPN CCONJ PROPN PUNCT DET NOUN ADP DET NOUN PUNCT
# application of Stafford Beer to second-order cybernetics and viable system theory , but also Niklas Luhmann in his social systems theory . The word was coined by MENTION_1 in his book MENTION_2 . Koestler was compelled by two observations in proposing the notion of the holon . The first observation was influenced by Nobel Prize winner Herbert A .
# NOUN ADP PROPN PROPN ADP ADJ PUNCT NOUN NOUN CCONJ ADJ NOUN NOUN PUNCT CCONJ ADV PROPN PROPN ADP ADJ ADJ NOUN NOUN PUNCT DET NOUN VERB VERB ADP MENTION_1 ADP ADJ NOUN MENTION_2 PUNCT PROPN VERB VERB ADP NUM NOUN ADP VERB DET NOUN ADP DET NOUN PUNCT DET ADJ NOUN VERB VERB ADP PROPN PROPN NOUN PROPN PROPN PUNCT
# to function in parallel with physical action , but where their means of interaction are unknown or , at best , speculative . The argument was further developed by MENTION_1 ( MENTION_2 , 1967 ) . Such examples imply that ignorance of one kind or another is effectively `` designed into '' global models -- in a questionable manner of which
# PART VERB ADP NOUN ADP ADJ NOUN PUNCT CCONJ ADV ADJ NOUN ADP NOUN VERB ADJ CCONJ PUNCT ADP ADJ PUNCT ADJ PUNCT DET NOUN VERB ADV VERB ADP MENTION_1 PUNCT MENTION_2 PUNCT NUM PUNCT PUNCT ADJ NOUN VERB ADP NOUN ADP NUM NOUN CCONJ DET VERB ADV PUNCT VERB ADP PUNCT ADJ NOUN PUNCT ADP DET ADJ NOUN ADP ADJ
# Greek : , holon neuter form of a `` whole '' is something that is simultaneously a whole and a part . The word was coined by MENTION_1 in his book MENTION_2 ( 1967 , p. 48 ) . Koestler was compelled by two observations in proposing the notion of the holon . The first observation was influenced by Nobel Prize winner
# ADJ PUNCT PUNCT NOUN NOUN NOUN ADP DET PUNCT NOUN PUNCT VERB NOUN ADJ VERB ADV DET NOUN CCONJ DET NOUN PUNCT DET NOUN VERB VERB ADP MENTION_1 ADP ADJ NOUN MENTION_2 PUNCT NUM PUNCT NOUN NUM PUNCT PUNCT PROPN VERB VERB ADP NUM NOUN ADP VERB DET NOUN ADP DET NOUN PUNCT DET ADJ NOUN VERB VERB ADP PROPN PROPN NOUN
# swell . 2005/02/15 : Rabbit Redux , John Updike : I liked it better than the first book in this series . Definitely some good stuff here . 2005/01/21 : MENTION_1 , MENTION_2 : Interesting and worth reading . Do/did most middle-class Americans really live like this ? 2005/10/22 : Zuckerman Bound , Philip Roth : More good stuff . 2005/10/18 : Lila
# INTJ PUNCT NOUN PUNCT NOUN PROPN PUNCT PROPN PROPN PUNCT PRON VERB PRON ADV ADP DET ADJ NOUN ADP DET NOUN PUNCT ADV DET ADJ NOUN ADV PUNCT NUM PUNCT MENTION_1 PUNCT MENTION_2 PUNCT ADJ CCONJ ADJ NOUN PUNCT VERB SYM VERB ADJ ADJ PUNCT NOUN PROPN ADV VERB ADP DET PUNCT NOUN PUNCT PROPN PROPN PUNCT PROPN PROPN PUNCT ADV ADJ NOUN PUNCT NUM PUNCT PROPN
# government . Not only are Glenn Beck and Sean Hannity preaching a political gospel with religious zeal , but millions of Americans are also devoted followers of MENTION_1 , Bill O'Reilly , Michael Savage , MENTION_2 , Ann Coulter , Laura Ingraham , Mark Levin and a host of other conservative radio talk show hosts across the country . In a poll
# NOUN PUNCT ADV ADV VERB PROPN PROPN CCONJ PROPN PROPN VERB DET ADJ NOUN ADP ADJ NOUN PUNCT CCONJ NOUN ADP PROPN VERB ADV VERB NOUN ADP MENTION_1 PUNCT PROPN PROPN PUNCT PROPN PROPN PUNCT MENTION_2 PUNCT PROPN PROPN PUNCT PROPN PROPN PUNCT PROPN PROPN CCONJ DET NOUN ADP ADJ ADJ NOUN NOUN NOUN NOUN ADP DET NOUN PUNCT ADP DET NOUN
# American business magnate , philanthropist , author , and is chairman of Microsoft , the software company . Gates was born in Seattle , Washington , to MENTION_1 and MENTION_2 , of English , German , and Scotch-Irish descent . His family was upper middle class ; his father was a prominent lawyer , his mother served on
# ADJ NOUN NOUN PUNCT NOUN PUNCT NOUN PUNCT CCONJ VERB NOUN ADP PROPN PUNCT DET NOUN NOUN PUNCT PROPN VERB VERB ADP PROPN PUNCT PROPN PUNCT ADP MENTION_1 CCONJ MENTION_2 PUNCT ADP ADJ PUNCT ADJ PUNCT CCONJ ADJ PUNCT ADJ NOUN PUNCT ADJ NOUN VERB ADJ ADJ NOUN PUNCT ADJ NOUN VERB DET ADJ NOUN PUNCT ADJ NOUN VERB ADP
# Slim 's wealth until next year . [ 12 ] < SCRIPT type= '' text/javascript '' > // < /SCRIPT > Early life William Henry Gates III was born in Seattle , Washington , to MENTION_1 ( now Sr. ) and MENTION_2 . His family was wealthy ; his father was a prominent lawyer , his mother served on the board of directors for First Interstate Bank and the
# PROPN PART NOUN ADP ADJ NOUN PUNCT PUNCT NUM PUNCT X PROPN PROPN PUNCT NOUN SYM NOUN PUNCT X X X PUNCT X ADJ NOUN PROPN PROPN PROPN PROPN VERB VERB ADP PROPN PUNCT PROPN PUNCT ADP MENTION_1 PUNCT ADV PROPN PUNCT PUNCT CCONJ MENTION_2 PUNCT ADJ NOUN VERB ADJ PUNCT ADJ NOUN VERB DET ADJ NOUN PUNCT ADJ NOUN VERB ADP DET NOUN ADP NOUN ADP PROPN PROPN PROPN CCONJ DET
# Philanthropy 3.2 Recognition 3.3 Investments 4 Bibliography 5 Notes 6 References 7 External links Early life Gates was born in Seattle , Washington , to MENTION_1 and MENTION_2 . His family was upper middle class ; his father was a prominent lawyer , his mother served on the board of directors for First Interstate BancSystem
# NOUN NUM PROPN NUM PROPN NUM PROPN NUM PROPN NUM NOUN NUM ADJ NOUN ADJ NOUN PROPN VERB VERB ADP PROPN PUNCT PROPN PUNCT ADP MENTION_1 CCONJ MENTION_2 PUNCT ADJ NOUN VERB ADJ ADJ NOUN PUNCT ADJ NOUN VERB DET ADJ NOUN PUNCT ADJ NOUN VERB ADP DET NOUN ADP NOUN ADP PROPN PROPN PROPN
# New Mexico police in 1977 after a traffic violation ( details of which have been lost over time ) . Gates was born in Seattle , Washington , to MENTION_1 and MENTION_2 . His parents are of English , German , and Scots-Irish descent . [ 13 ] [ 14 ] His father was a prominent lawyer , and his
# PROPN PROPN NOUN ADP NUM ADP DET NOUN NOUN PUNCT NOUN ADP ADJ VERB VERB VERB ADP NOUN PUNCT PUNCT PROPN VERB VERB ADP PROPN PUNCT PROPN PUNCT ADP MENTION_1 CCONJ MENTION_2 PUNCT ADJ NOUN VERB ADP ADJ PUNCT ADJ PUNCT CCONJ NOUN PUNCT ADJ NOUN PUNCT PUNCT NUM PUNCT PUNCT NUM PUNCT ADJ NOUN VERB DET ADJ NOUN PUNCT CCONJ ADJ
# and scientific research programs through the Bill & Melinda Gates Foundation , established in 2000 . William Henry Gates III was born in Seattle , Washington to MENTION_1 ( now Sr. ) and MENTION_2 . His family was wealthy ; his father was a prominent lawyer , his mother served on the board of directors for First Interstate Bank and the
# CCONJ ADJ NOUN NOUN ADP DET PROPN CCONJ PROPN PROPN PROPN PUNCT VERB ADP NUM PUNCT PROPN PROPN PROPN PROPN VERB VERB ADP PROPN PUNCT PROPN ADP MENTION_1 PUNCT ADV PROPN PUNCT PUNCT CCONJ MENTION_2 PUNCT ADJ NOUN VERB ADJ PUNCT ADJ NOUN VERB DET ADJ NOUN PUNCT ADJ NOUN VERB ADP DET NOUN ADP NOUN ADP PROPN PROPN PROPN CCONJ DET
# 4.3 Investments 5 Bibliography 6 Notes 7 References 8 Further reading 9 External links Early life Gates was born in Seattle , Washington , to MENTION_1 and MENTION_2 , who was of Scottish descent . [ 8 ] . His family was upper middle class ; his father was a prominent lawyer , his mother served
# NUM PROPN NUM PROPN NUM PROPN NUM NOUN NUM ADV VERB NUM ADJ NOUN ADJ NOUN PROPN VERB VERB ADP PROPN PUNCT PROPN PUNCT ADP MENTION_1 CCONJ MENTION_2 PUNCT NOUN VERB ADP ADJ NOUN PUNCT PUNCT NUM PUNCT PUNCT ADJ NOUN VERB ADJ ADJ NOUN PUNCT ADJ NOUN VERB DET ADJ NOUN PUNCT ADJ NOUN VERB
# full-time day at Microsoft was June 27 , 2008 . He remains at Microsoft as non-executive chairman . Early life Gates was born in Seattle , Washington , to MENTION_1 and MENTION_2 , of English , German , and Scotch-Irish descent . [ 9 ] [ 10 ] His family was upper middle class ; his father was a prominent lawyer ,
# ADJ PUNCT NOUN NOUN ADP PROPN VERB PROPN NUM PUNCT NUM PUNCT PRON VERB ADP PROPN ADP ADJ PUNCT NOUN NOUN PUNCT ADJ NOUN PROPN VERB VERB ADP PROPN PUNCT PROPN PUNCT ADP MENTION_1 CCONJ MENTION_2 PUNCT ADP ADJ PUNCT ADJ PUNCT CCONJ ADJ PUNCT ADJ NOUN PUNCT PUNCT NUM PUNCT PUNCT NUM PUNCT ADJ NOUN VERB ADJ ADJ NOUN PUNCT ADJ NOUN VERB DET ADJ NOUN PUNCT
# 4.3 Investments 5 Bibliography 6 Notes 7 References 8 Further reading 9 External links Early life Gates was born in Seattle , Washington , to MENTION_1 and MENTION_2 , of English , German , and Scotch-Irish descent . [ 8 ] [ 9 ] His family was upper middle class ; his father was a
# NUM PROPN NUM PROPN NUM PROPN NUM NOUN NUM ADV VERB NUM ADJ NOUN ADJ NOUN PROPN VERB VERB ADP PROPN PUNCT PROPN PUNCT ADP MENTION_1 CCONJ MENTION_2 PUNCT ADP ADJ PUNCT ADJ PUNCT CCONJ ADJ PUNCT ADJ NOUN PUNCT PUNCT NUM PUNCT PUNCT NUM PUNCT ADJ NOUN VERB ADJ ADJ NOUN PUNCT ADJ NOUN VERB DET
# New Mexico police in 1977 after a traffic violation ( details of which have been lost over time ) . Gates was born in Seattle , Washington , to MENTION_1 and MENTION_2 . His parents are of English , German , and Scotch-Irish descent . [ 10 ] [ 11 ] His father was a prominent lawyer , and his mother served on the
# PROPN PROPN NOUN ADP NUM ADP DET NOUN NOUN PUNCT NOUN ADP ADJ VERB VERB VERB ADP NOUN PUNCT PUNCT PROPN VERB VERB ADP PROPN PUNCT PROPN PUNCT ADP MENTION_1 CCONJ MENTION_2 PUNCT ADJ NOUN VERB ADP ADJ PUNCT ADJ PUNCT CCONJ ADJ PUNCT ADJ NOUN PUNCT PUNCT NUM PUNCT PUNCT NUM PUNCT ADJ NOUN VERB DET ADJ NOUN PUNCT CCONJ ADJ NOUN VERB ADP DET
# to fourteen . Evidently there 's only so much the cinema-going sensibility can stand . I read a review which suggested that this book represents the flipside to MENTION_1 , and I think there 's a lot of truth in that : MENTION_2 's book uses some ripe language and bluntly carnal descriptions of the sexual act to tell a story that is , at its heart , pretty conventional
# ADP NUM PUNCT ADV ADV VERB ADV ADV ADJ DET NOUN PUNCT VERB NOUN VERB VERB PUNCT PRON VERB DET NOUN ADJ VERB ADP DET NOUN VERB DET NOUN ADP MENTION_1 PUNCT CCONJ PRON VERB ADV VERB DET NOUN ADP NOUN ADP DET PUNCT MENTION_2 PART NOUN VERB DET ADJ NOUN CCONJ ADV ADJ NOUN ADP DET ADJ NOUN PART VERB DET NOUN ADJ VERB PUNCT ADP ADJ NOUN PUNCT ADV ADJ
# for one hundred and eighty-days in Susa to show off the vast wealth of his kingdom and the beauty and wonder of his majesty . The MENTION_1 ordered his queen , MENTION_2 to come before him and his guests wearing her crown to show off how beautiful she was . But when the king 's command was delivered , Queen
# ADP NUM NUM CCONJ NUM PUNCT NOUN ADP PROPN PART VERB PART DET ADJ NOUN ADP ADJ NOUN CCONJ DET NOUN CCONJ NOUN ADP ADJ NOUN PUNCT DET MENTION_1 VERB ADJ NOUN PUNCT MENTION_2 PART VERB ADP PRON CCONJ ADJ NOUN VERB ADJ NOUN PART VERB PART ADV ADJ PRON VERB PUNCT CCONJ ADV DET NOUN PART NOUN VERB VERB PUNCT PROPN
# and themes but a simple enough plot and humor to appeal to children . It made notable use of popular music ; the soundtrack includes music by MENTION_1 , Eels , MENTION_2 , The Proclaimers , Jason Wade , The Baha Men , and John Cale ( covering Leonard Cohen ) . During June 2008 , the American Film Institute
# CCONJ NOUN CCONJ DET ADJ ADJ NOUN CCONJ NOUN PART VERB ADP NOUN PUNCT PRON VERB ADJ NOUN ADP ADJ NOUN PUNCT DET NOUN VERB NOUN ADP MENTION_1 PUNCT PROPN PUNCT MENTION_2 PUNCT DET PROPN PUNCT PROPN PROPN PUNCT DET PROPN PROPN PUNCT CCONJ PROPN PROPN PUNCT VERB PROPN PROPN PUNCT PUNCT ADP PROPN NUM PUNCT DET PROPN PROPN PROPN
# gazes at the enormity , the detail , and craftsmanship . Inside the Cathedral of Málaga The north tower rises 84 meters and is the second-highest cathedral in MENTION_1 , behind the Giralda of MENTION_2 . The south tower is unfinished . There are disputes on where the funds disappeared to , but because it is unfinished , the Cathedral has been nicknamed
# NOUN ADP DET NOUN PUNCT DET NOUN PUNCT CCONJ NOUN PUNCT ADP DET PROPN ADP PROPN DET NOUN NOUN VERB NUM NOUN CCONJ VERB DET ADV PUNCT ADJ NOUN ADP MENTION_1 PUNCT ADP DET PROPN ADP MENTION_2 PUNCT DET ADJ NOUN VERB ADJ PUNCT ADV VERB NOUN ADP ADV DET NOUN VERB ADP PUNCT CCONJ ADP PRON VERB ADJ PUNCT DET PROPN VERB VERB VERB
# And then there ’ s the Planta Solar 20 ( PS20 ) solar power plant , which is a solar thermal energy plant in Sanlucar la Mayor near MENTION_1 in MENTION_2 , Spain . It is the world ’ s most powerful solar power tower . The 20 megawatt ( MW ) solar power tower produces electricity with large movable mirrors called heliostats
# CCONJ ADV ADV PUNCT VERB DET PROPN PROPN NUM PUNCT PROPN PUNCT ADJ NOUN NOUN PUNCT ADJ VERB DET ADJ ADJ NOUN NOUN ADP PROPN PROPN PROPN ADP MENTION_1 ADP MENTION_2 PUNCT PROPN PUNCT PRON VERB DET NOUN PUNCT VERB ADV ADJ ADJ NOUN NOUN PUNCT DET NUM NOUN PUNCT PROPN PUNCT ADJ NOUN NOUN VERB NOUN ADP ADJ ADJ NOUN VERB NOUN
# to 6:45 p.m. PDT . Sandra 's daughter , Laura Cerna , a single mother and teacher , was murdered on Monday , August 30 , 2010 while living in MENTION_1 , an historic city in MENTION_2 , about 340 miles southwest of Madrid , Spain . View slideshow : Mother of murdered Laura Cerna warns others The 49-year-old woman was brutally stabbed multiple
# ADP NUM NOUN PROPN PUNCT PROPN PART NOUN PUNCT PROPN PROPN PUNCT DET ADJ NOUN CCONJ NOUN PUNCT VERB VERB ADP PROPN PUNCT PROPN NUM PUNCT NUM ADP VERB ADP MENTION_1 PUNCT DET ADJ NOUN ADP MENTION_2 PUNCT ADV NUM NOUN ADV ADP PROPN PUNCT PROPN PUNCT PROPN NOUN PUNCT NOUN ADP VERB PROPN PROPN VERB NOUN DET NUM PUNCT ADJ NOUN VERB ADV VERB ADJ
# by dabby at 1:39 PM No comments : Labels : architecture humor , crazy architecture , toilet shaped house Alamillo Bridge by Calatrava The Alamillo Bridge in MENTION_1 , MENTION_2 ( Spain ) spans the Guadalquivir River . Construction of the bridge began in 1989 and was completed in 1992 by Santiago Calatrava . It
# ADP NOUN ADP NUM NOUN DET NOUN PUNCT NOUN PUNCT NOUN NOUN PUNCT ADJ NOUN PUNCT NOUN VERB NOUN PROPN PROPN ADP PROPN PROPN PROPN PROPN ADP MENTION_1 PUNCT MENTION_2 PUNCT PROPN PUNCT VERB DET PROPN PROPN PUNCT NOUN ADP DET NOUN VERB ADP NUM CCONJ VERB VERB ADP NUM ADP PROPN PROPN PUNCT PRON
# art and architecture , karachi , pakistan , dabeer , sustainable architecture , humorous architecture , green architecture , music Friday , January 4 , 2008 Alamillo Bridge by Calatrava The Alamillo Bridge in MENTION_1 , MENTION_2 ( Spain ) spans the Guadalquivir River . Construction of the bridge began in 1989 and was completed in 1992 by Santiago Calatrava . It
# NOUN CCONJ NOUN PUNCT NOUN PUNCT NOUN PUNCT VERB PUNCT ADJ NOUN PUNCT ADJ NOUN PUNCT ADJ NOUN PUNCT NOUN PROPN PUNCT PROPN NUM PUNCT NUM PROPN PROPN ADP PROPN PROPN PROPN PROPN ADP MENTION_1 PUNCT MENTION_2 PUNCT PROPN PUNCT VERB DET PROPN PROPN PUNCT NOUN ADP DET NOUN VERB ADP NUM CCONJ VERB VERB ADP NUM ADP PROPN PROPN PUNCT PRON
# $ 100,000 when she stopped trading after ten months . [ 91 ] The couple also began their ill-fated investment in the Whitewater Development Corporation real estate venture with MENTION_1 and MENTION_2 at this time . [ 90 ] On February 27 , 1980 , Rodham gave birth to a daughter , Chelsea , her only child . In November 1980 , Bill
# SYM NUM ADV PRON VERB VERB ADP NUM NOUN PUNCT PUNCT NUM PUNCT DET NOUN ADV VERB ADJ ADV PUNCT VERB NOUN ADP DET PROPN PROPN PROPN ADJ NOUN NOUN ADP MENTION_1 CCONJ MENTION_2 ADP DET NOUN PUNCT PUNCT NUM PUNCT ADP PROPN NUM PUNCT NUM PUNCT PROPN VERB NOUN ADP DET NOUN PUNCT PROPN PUNCT ADJ ADJ NOUN PUNCT ADP PROPN NUM PUNCT PROPN
# First Lady . The Clintons had lost their late-1970s investment in the Whitewater Development Corporation ; [ 156 ] at the same time , their partners in that investment , MENTION_1 and MENTION_2 , operated Madison Guaranty , a savings and loan institution that retained the legal services of Rose Law Firm [ 156 ] and may have been improperly
# PROPN PROPN PUNCT DET PROPN VERB VERB ADJ NOUN NOUN ADP DET PROPN PROPN PROPN PUNCT PUNCT NUM PUNCT ADP DET ADJ NOUN PUNCT ADJ NOUN ADP DET NOUN PUNCT MENTION_1 CCONJ MENTION_2 PUNCT VERB PROPN PROPN PUNCT DET NOUN CCONJ NOUN NOUN ADJ VERB DET ADJ NOUN ADP PROPN PROPN NOUN PUNCT NUM PUNCT CCONJ VERB VERB VERB ADV
# most often , simply Whitewater ) was an American politics controversy that began with the real estate investments of Bill and Hillary Clinton and their associates , MENTION_1 and MENTION_2 in the Whitewater Development Corporation , a failed business venture in the 1970s and 1980s . Solution to Today 's Puzzle Legend : `` CD '' Cryptic Definition ; `` DD '' Double
# ADV ADV PUNCT ADV PROPN PUNCT VERB DET ADJ NOUN NOUN ADJ VERB ADP DET ADJ NOUN NOUN ADP PROPN CCONJ PROPN PROPN CCONJ ADJ NOUN PUNCT MENTION_1 CCONJ MENTION_2 ADP DET PROPN PROPN PROPN PUNCT DET VERB NOUN NOUN ADP DET NOUN CCONJ NOUN PUNCT NOUN ADP NOUN PART PROPN NOUN PUNCT PUNCT NOUN PUNCT PROPN PROPN PUNCT PUNCT PROPN PUNCT ADJ
# nov 1993 The Whitewater controversy was an American political controversy that began with the real estate dealings of Bill and Hillary Clinton and their associates MENTION_1 and MENTION_2 in the Whitewater Development Corporation , a failed business venture in the 1970s and 1980s . In November 1993 , David Hale , the source of criminal
# NOUN NUM DET PROPN NOUN VERB DET ADJ ADJ NOUN ADJ VERB ADP DET ADJ NOUN NOUN ADP PROPN CCONJ PROPN PROPN CCONJ ADJ NOUN MENTION_1 CCONJ MENTION_2 ADP DET PROPN PROPN PROPN PUNCT DET VERB NOUN NOUN ADP DET NOUN CCONJ NOUN PUNCT ADP PROPN NUM PUNCT PROPN PROPN PUNCT DET NOUN ADP ADJ
# most often , simply Whitewater ) was an American politics controversy that began with the real estate investments of Bill and Hillary Clinton and their associates , MENTION_1 and MENTION_2 in the Whitewater Development Corporation , a failed business venture in the 1970s and 1980s . A New York Times article published during the 1992 U.S .
# ADV ADV PUNCT ADV PROPN PUNCT VERB DET ADJ NOUN NOUN ADJ VERB ADP DET ADJ NOUN NOUN ADP PROPN CCONJ PROPN PROPN CCONJ ADJ NOUN PUNCT MENTION_1 CCONJ MENTION_2 ADP DET PROPN PROPN PROPN PUNCT DET VERB NOUN NOUN ADP DET NOUN CCONJ NOUN PUNCT DET PROPN PROPN PROPN NOUN VERB ADP DET NUM PROPN PUNCT
# serious , music-based segments , including : The Million Dollar Band : This was a jam-session segment , airing from 1980 through 1988 , composed of the following all-star musicians : MENTION_1 , MENTION_2 , Roy Clark , Floyd Cramer , Charlie McCoy , Danny Davis , Jethro Burns , and Johnny Gimble . A singer-songwriter segment , where one
# ADJ PUNCT NOUN PUNCT VERB NOUN PUNCT VERB PUNCT DET PROPN PROPN PROPN PUNCT DET VERB DET NOUN PUNCT NOUN NOUN PUNCT VERB ADP NUM ADP NUM PUNCT VERB ADP DET VERB DET PUNCT NOUN NOUN PUNCT MENTION_1 PUNCT MENTION_2 PUNCT PROPN PROPN PUNCT PROPN PROPN PUNCT PROPN PROPN PUNCT PROPN PROPN PUNCT PROPN PROPN PUNCT CCONJ PROPN PROPN PUNCT DET NOUN PUNCT NOUN NOUN PUNCT ADV NUM
# Hot Fuzz 's Simon Pegg and Nick Frost ( both of whom are prolific Twitter users out of interest ) . The film co-stars Jason Bateman , MENTION_1 , MENTION_2 and Sigourney Weaver , features the voice of Seth Rogen as the title character , and is directed by Superbad 's Greg Mottola ( instead of Pegg
# PROPN PROPN PART PROPN PROPN CCONJ PROPN PROPN PUNCT DET ADP NOUN VERB ADJ PROPN NOUN ADP ADP NOUN PUNCT PUNCT DET NOUN NOUN PUNCT NOUN PROPN PROPN PUNCT MENTION_1 PUNCT MENTION_2 CCONJ PROPN PROPN PUNCT VERB DET NOUN ADP PROPN PROPN ADP DET NOUN NOUN PUNCT CCONJ VERB VERB ADP PROPN PART PROPN PROPN PUNCT ADV ADP PROPN
# something better comes along . And it 's sweetly raunchy without getting too deep in the muck , though it 's probably not for the kids . And anything with MENTION_1 and MENTION_2 in it is worth watching . * Did I mention that Mottola directed a few episodes of the late , lamented `` Arrested Development ? '' That helps
# NOUN ADJ VERB ADV PUNCT CCONJ PRON VERB ADV ADJ ADP VERB ADV ADJ ADP DET NOUN PUNCT ADP PRON VERB ADV ADV ADP DET NOUN PUNCT CCONJ NOUN ADP MENTION_1 CCONJ MENTION_2 ADP PRON VERB ADJ VERB PUNCT PUNCT VERB PRON VERB ADP PROPN VERB DET ADJ NOUN ADP DET ADJ PUNCT VERB PUNCT VERB PROPN PUNCT PUNCT DET VERB
# Goldman Sachs International ( a registered UK broker-dealer , a subsidiary of Goldman Sachs ) . Until June 2009 he was non-executive chairman of BP being replaced by MENTION_1 formely chief executive officer of MENTION_2 . Sutherland was a director of the Royal Bank of Scotland Group until he was asked to leave the board when it had to be
# PROPN PROPN PROPN PUNCT DET ADJ PROPN NOUN PUNCT NOUN PUNCT DET NOUN ADP PROPN PROPN PUNCT PUNCT ADP PROPN NUM PRON VERB ADJ PUNCT NOUN NOUN ADP PROPN VERB VERB ADP MENTION_1 ADV ADJ ADJ NOUN ADP MENTION_2 PUNCT PROPN VERB DET NOUN ADP DET PROPN PROPN ADP PROPN PROPN ADP PRON VERB VERB PART VERB DET NOUN ADV PRON VERB PART VERB
# currently the largest LTE proponent . Ericsson expects 80 % of mobile broadband services will be enabled by cellular by 2012 , using HSPA and LTE technologies . MENTION_1 CEO MENTION_2 said the bulk of mobile broadband deployments in the coming five years will be based on HSPA . But Huawei faces little competition in the market
# ADV DET ADJ NOUN NOUN PUNCT PROPN VERB NUM NOUN ADP ADJ NOUN NOUN VERB VERB VERB ADP ADJ ADP NUM PUNCT VERB PROPN CCONJ PROPN NOUN PUNCT MENTION_1 NOUN MENTION_2 VERB DET NOUN ADP ADJ NOUN NOUN ADP DET VERB NUM NOUN VERB VERB VERB ADP PROPN PUNCT CCONJ PROPN VERB ADJ NOUN ADP DET NOUN
# solution , despite the vendor lockdown . Ericsson expects 80 % of mobile broadband services will be enabled by cellular by 2012 , using HSPA and LTE technologies . MENTION_1 CEO MENTION_2 said the bulk of mobile broadband deployments in the coming five years will be based on HSPA . According to Unstrung , Svanberg forecast 3.5 billion
# NOUN PUNCT ADP DET NOUN NOUN PUNCT PROPN VERB NUM NOUN ADP ADJ NOUN NOUN VERB VERB VERB ADP ADJ ADP NUM PUNCT VERB PROPN CCONJ PROPN NOUN PUNCT MENTION_1 NOUN MENTION_2 VERB DET NOUN ADP ADJ NOUN NOUN ADP DET VERB NUM NOUN VERB VERB VERB ADP PROPN PUNCT VERB ADP PROPN PUNCT PROPN VERB NUM NUM
# Global Mobile Suppliers Association . Ericsson expects 80 % of mobile broadband services will be enabled by cellular by 2012 , using HSPA and LTE technologies . MENTION_1 CEO MENTION_2 said the bulk of mobile broadband deployments in the coming five years will be based on HSPA . According to Unstrung , Svanberg forecast 3.5 billion
# PROPN PROPN PROPN PROPN PUNCT PROPN VERB NUM NOUN ADP ADJ NOUN NOUN VERB VERB VERB ADP ADJ ADP NUM PUNCT VERB PROPN CCONJ PROPN NOUN PUNCT MENTION_1 NOUN MENTION_2 VERB DET NOUN ADP ADJ NOUN NOUN ADP DET VERB NUM NOUN VERB VERB VERB ADP PROPN PUNCT VERB ADP PROPN PUNCT PROPN VERB NUM NUM
# he despises in a rape trial . But if he does n't do it , the judge will have him disbarred . Directed by Norman Jewison . Written by MENTION_1 and MENTION_2 . This man needs the best lawyer in town . But the problem is ... he is the best lawyer in town . Contents 1 Arthur Kirkland 2
# PRON VERB ADP DET NOUN NOUN PUNCT CCONJ ADP PRON VERB ADV VERB PRON PUNCT DET NOUN VERB VERB PRON VERB PUNCT VERB ADP PROPN PROPN PUNCT VERB ADP MENTION_1 CCONJ MENTION_2 PUNCT DET NOUN VERB DET ADJ NOUN ADP NOUN PUNCT CCONJ DET NOUN VERB PUNCT PRON VERB DET ADJ NOUN ADP NOUN PUNCT NOUN NUM PROPN PROPN NUM
# could not happen . A priori arguments for this reason could never prove the existence of God . A posteriori arguments have been criticized by Hume , MENTION_1 , MENTION_2 , Edwards and many others to show that this argument is not a proof of the existence of God . I intend to use the Bible
# VERB ADV VERB PUNCT DET X NOUN ADP DET NOUN VERB ADV VERB DET NOUN ADP PROPN PUNCT DET ADJ NOUN VERB VERB VERB ADP PROPN PUNCT MENTION_1 PUNCT MENTION_2 PUNCT PROPN CCONJ ADJ NOUN PART VERB ADP DET NOUN VERB ADV DET NOUN ADP DET NOUN ADP PROPN PUNCT PRON VERB PART VERB DET PROPN
# a Hurricane replica . Of the parks along Windsor 's waterfront , the largest is the five-kilometre ( three mile ) stretch overlooking the Detroit skyline . It stretches from the MENTION_1 to the MENTION_2 Distillery . The western portion of the park contains the Odette Sculpture Park which features over 30 large-scale contemporary sculptures for public viewing , along with the
# DET PROPN NOUN PUNCT ADP DET NOUN ADP PROPN PART NOUN PUNCT DET ADJ VERB DET NUM PUNCT NOUN PUNCT NUM NOUN PUNCT VERB VERB DET PROPN NOUN PUNCT PRON VERB ADP DET MENTION_1 ADP DET MENTION_2 PROPN PUNCT DET ADJ NOUN ADP DET NOUN VERB DET PROPN PROPN PROPN ADJ VERB ADP NUM ADJ PUNCT NOUN ADJ NOUN ADP ADJ NOUN PUNCT ADP ADP DET
# has been the home of numerous writers , musicians , artists , and actors , including Bob Dylan , Virgil Thomson , Charles Bukowski , MENTION_1 , Leonard Cohen , MENTION_2 , Iggy Pop , Jobriath , and Larry Rivers . Though the Hotel Chelsea no longer accepts new long-term residencies , the building is still home
# VERB VERB DET NOUN ADP ADJ NOUN PUNCT NOUN PUNCT NOUN PUNCT CCONJ NOUN PUNCT VERB PROPN PROPN PUNCT PROPN PROPN PUNCT PROPN PROPN PUNCT MENTION_1 PUNCT PROPN PROPN PUNCT MENTION_2 PUNCT PROPN PROPN PUNCT PROPN PUNCT CCONJ PROPN PROPN PUNCT ADP DET PROPN PROPN ADV ADV VERB ADJ ADJ PUNCT NOUN NOUN PUNCT DET NOUN VERB ADV ADV
# body-mapped subject . A bedroom that comes to life with the story of Peter Pan . A touchscreen coffee table containing an interactive original copy of MENTION_1 's MENTION_2 . A kitchen featuring a countertop voice-activated cookbook , an internet-connected bulletin board , and Siemens appliances , including the Liftmatic Oven . Rock Band and video games in
# NOUN PUNCT VERB NOUN PUNCT DET NOUN ADJ VERB ADP NOUN ADP DET NOUN ADP PROPN PROPN PUNCT DET ADJ NOUN NOUN VERB DET ADJ ADJ NOUN ADP MENTION_1 PART MENTION_2 PUNCT DET NOUN VERB DET ADJ NOUN PUNCT VERB NOUN PUNCT DET NOUN PUNCT VERB NOUN NOUN PUNCT CCONJ PROPN NOUN PUNCT VERB DET PROPN PROPN PUNCT PROPN PROPN CCONJ NOUN NOUN ADP
# Noche Home Blog Links Alice 's Adventures under Ground Dec 5 , '11 3:47 AM for everyone Click on the leftmost image to see a copy of MENTION_1 's MENTION_2 from Project Gutenberg . Tags : lewis carroll Prev : Roy Lichtenstein at Christie 's Next : BSP commemorates Rizal 's 150th birthday 2 Comments Chronological Reverse Threaded
# PROPN PROPN PROPN PROPN PROPN PART PROPN ADP PROPN PROPN NUM PUNCT PUNCT NUM NUM NOUN ADP NOUN VERB ADP DET ADJ NOUN PART VERB DET NOUN ADP MENTION_1 PART MENTION_2 ADP PROPN PROPN PUNCT NOUN PUNCT VERB NOUN PROPN PUNCT PROPN PROPN ADP PROPN PART ADJ PUNCT NOUN VERB PROPN PART ADJ NOUN NUM NOUN PROPN NOUN ADJ
# Alabama , and in the meantime her husband is treasoning her with a porn star , Candy Suxxx . This is believed to be a reference to MENTION_1 , the wife of former US President MENTION_2 and his womanizing habits . v • g • d • e Grand Theft Auto : Vice City characters Protagonist Tommy Vercetti Major
# PROPN PUNCT CCONJ ADP DET NOUN ADJ NOUN VERB VERB PRON ADP DET NOUN NOUN PUNCT PROPN PROPN PUNCT DET VERB VERB PART VERB DET NOUN ADP MENTION_1 PUNCT DET NOUN ADP ADJ PROPN PROPN MENTION_2 CCONJ ADJ NOUN NOUN PUNCT PUNCT ADV NOUN ADV VERB ADV PROPN PROPN PROPN PROPN PUNCT PROPN PROPN NOUN PROPN PROPN PROPN PROPN
# and sang `` Second-Hand Clothes '' , mimicking the song `` Second-Hand Rose '' . The skit helped to restore her reputation . Reagan and her husband with her predecessor as First Lady , MENTION_1 , widow of MENTION_2 , in 1985 . Nancy and Jackie were often compared due to their glamour , in contrast to the intervening First Ladies . Nancy Reagan reflected on the
# CCONJ VERB PUNCT PROPN PUNCT PROPN PROPN PUNCT PUNCT VERB DET NOUN PUNCT PROPN PUNCT PROPN PROPN PUNCT PUNCT DET NOUN VERB PART VERB ADJ NOUN PUNCT PROPN CCONJ ADJ NOUN ADP ADJ NOUN ADP PROPN PROPN PUNCT MENTION_1 PUNCT NOUN ADP MENTION_2 PUNCT ADP NUM PUNCT PROPN CCONJ PROPN VERB ADV VERB ADP ADP ADJ NOUN PUNCT ADP NOUN ADP DET VERB PROPN PROPN PUNCT PROPN PROPN VERB ADP DET
# LBJ » Lee Harvey Oswald » Marilyn Monroe » William Holden The shocker is not LBJ killing JFK . The shocker was she was a slut ! MENTION_1 , the widow of President MENTION_2 , believed Vice President Lyndon Johnson and a “ cabal of Texas tycoons ” plotted and carried out the assassination of her philandering husband , London ’ s Daily Mail
# PROPN PUNCT PROPN PROPN PROPN PUNCT PROPN PROPN PUNCT PROPN PROPN DET NOUN VERB ADV PROPN VERB PROPN PUNCT DET NOUN VERB PRON VERB DET NOUN PUNCT MENTION_1 PUNCT DET NOUN ADP PROPN MENTION_2 PUNCT VERB PROPN PROPN PROPN PROPN CCONJ DET PUNCT NOUN ADP PROPN NOUN PUNCT VERB CCONJ VERB PART DET NOUN ADP ADJ VERB NOUN PUNCT PROPN PUNCT PART PROPN PROPN
# he designed the wedding dress for Queen Fabiola of Belgium made of ivory duchess satin trimmed with white mink at the collar and the hips . MENTION_1 famously upset MENTION_2 for buying Balenciaga 's expensive creations while he was President because he feared that the American public might think the purchases too lavish . Her haute couture
# PRON VERB DET NOUN NOUN ADP PROPN PROPN ADP PROPN VERB ADP ADJ ADJ NOUN VERB ADP ADJ NOUN ADP DET NOUN CCONJ DET NOUN PUNCT MENTION_1 ADV VERB MENTION_2 ADP VERB PROPN PART ADJ NOUN ADP PRON VERB PROPN ADP PRON VERB ADP DET ADJ NOUN VERB VERB DET NOUN ADV ADJ PUNCT ADJ NOUN NOUN
# VIDEO - http : //www.musicfootnotes.com/lana-del-rey-national-anthem-video The music video for the song premiered on June 27 , 2012 and depicts Del Rey as Marilyn Monroe and MENTION_1 and A $ AP Rocky as MENTION_2 . Del Rey cited the video as `` definitely the most beautiful thing '' she 's ever done . As of June 29 , 2012 , it has received
# NOUN PUNCT NOUN PUNCT X SYM NOUN PUNCT NOUN PUNCT NOUN PUNCT ADJ PUNCT NOUN PUNCT NOUN DET NOUN NOUN ADP DET NOUN VERB ADP PROPN NUM PUNCT NUM CCONJ NOUN PROPN PROPN ADP PROPN PROPN CCONJ MENTION_1 CCONJ DET SYM PROPN PROPN ADP MENTION_2 PUNCT PROPN PROPN VERB DET NOUN ADP PUNCT ADV DET ADV ADJ NOUN PUNCT PRON VERB ADV VERB PUNCT ADP ADP PROPN NUM PUNCT NUM PUNCT PRON VERB VERB
# : - ) “ The one thing I do not want to be called is First Lady . It sounds like a saddle horse . ” Jacqueline Kennedy Onassis MENTION_1 , the wife of MENTION_2 , 35th president of the USA , and in an unprecedented move by an American first lady , she probagated her more friendly 'Jackie ' neck name to
# PUNCT PUNCT PUNCT PUNCT DET NUM NOUN PRON VERB ADV VERB PART VERB VERB VERB PROPN PROPN PUNCT PRON VERB ADP DET NOUN NOUN PUNCT PUNCT PROPN PROPN PROPN MENTION_1 PUNCT DET NOUN ADP MENTION_2 PUNCT ADJ NOUN ADP DET PROPN PUNCT CCONJ ADP DET ADJ NOUN ADP DET ADJ ADJ NOUN PUNCT PRON VERB PRON ADV ADJ PUNCT PROPN PART NOUN NOUN ADP
# was Del Rey 's fifth single from her album July 2012 . The music video for the song premiered June 27 2012 and depicted Del Rey as MENTION_1 and A $ AP Rocky as MENTION_2 and the video has received 5m views on YouTube . Newton Faulkner 's third studio album Write It On Your Skin which contained two Nexus songs
# ...
# NOUN ADP PROPN PROPN PROPN ADP PROPN CCONJ PROPN PROPN PUNCT PROPN PROPN PROPN ADP PROPN PUNCT NOUN ADP PROPN PROPN PROPN ADP PROPN CCONJ MENTION_1 PUNCT PROPN MENTION_2 PUNCT NOUN ADP PROPN PROPN CCONJ PROPN PROPN PUNCT PROPN PROPN PUNCT NOUN ADP PROPN PROPN CCONJ PROPN PROPN PROPN PUNCT NOUN ADP PROPN PROPN
# James I of Scotland , son of King Robert III of Scotland and Annabella Drummond . King Robert III of Scotland , son of King MENTION_1 and MENTION_2 . King Robert II of Scotland , son of Marjorie Bruce and Walter Stewart . Walter Stewart , son of James Stewart and Cecilia de
# PROPN PROPN ADP PROPN PUNCT NOUN ADP PROPN PROPN PROPN ADP PROPN CCONJ PROPN PROPN PUNCT PROPN PROPN PROPN ADP PROPN PUNCT NOUN ADP PROPN MENTION_1 CCONJ MENTION_2 PUNCT PROPN PROPN PROPN ADP PROPN PUNCT NOUN ADP PROPN PROPN CCONJ PROPN PROPN PUNCT PROPN PROPN PUNCT NOUN ADP PROPN PROPN CCONJ PROPN ADP
# James I of Scotland , son of King Robert III of Scotland and Annabella Drummond . King Robert III of Scotland , son of King MENTION_1 and MENTION_2 . King Robert II of Scotland , son of Marjorie Bruce and Walter Stewart , 6th High Steward of Scotland . Walter Stewart , 6th High Steward
# PROPN PROPN ADP PROPN PUNCT NOUN ADP PROPN PROPN PROPN ADP PROPN CCONJ PROPN PROPN PUNCT PROPN PROPN PROPN ADP PROPN PUNCT NOUN ADP PROPN MENTION_1 CCONJ MENTION_2 PUNCT PROPN PROPN PROPN ADP PROPN PUNCT NOUN ADP PROPN PROPN CCONJ PROPN PROPN PUNCT ADJ PROPN PROPN ADP PROPN PUNCT PROPN PROPN PUNCT ADJ PROPN PROPN
# him `` a very nice letter of appreciation on State Department stationery '' . The lyrics from another track , `` The Hula Hula Boys `` , were excerpted in MENTION_1 's 1983 book , MENTION_2 . The Envoy was the first Zevon album to feature his son Jordan Zevon . After the disappointing reception for The Envoy , Zevon was
# PRON PUNCT DET ADV ADJ NOUN ADP NOUN ADP PROPN PROPN NOUN PUNCT PUNCT DET NOUN ADP DET NOUN PUNCT PUNCT DET PROPN PROPN PROPN PUNCT PUNCT VERB VERB ADP MENTION_1 PART NUM NOUN PUNCT MENTION_2 PUNCT DET PROPN VERB DET ADJ PROPN NOUN PART VERB ADJ NOUN PROPN PROPN PUNCT ADP DET ADJ NOUN ADP DET PROPN PUNCT PROPN VERB
# Habib sent him `` a very nice letter of appreciation on State Department stationery '' . The lyrics from another track , `` The Hula Hula Boys , '' were excerpted in MENTION_1 's 1983 book , MENTION_2 . In 1983 , the recently divorced Zevon became engaged to Philadelphia DJ Anita Gevinson and moved to the East Coast . [ 8 ] After the disappointing reception for
# PROPN VERB PRON PUNCT DET ADV ADJ NOUN ADP NOUN ADP PROPN PROPN NOUN PUNCT PUNCT DET NOUN ADP DET NOUN PUNCT PUNCT DET PROPN PROPN PROPN PUNCT PUNCT VERB VERB ADP MENTION_1 PART NUM NOUN PUNCT MENTION_2 PUNCT ADP NUM PUNCT DET ADV VERB PROPN VERB ADJ ADP PROPN PROPN PROPN PROPN CCONJ VERB ADP DET PROPN PROPN PUNCT PUNCT NUM PUNCT ADP DET ADJ NOUN ADP
# January 29 , 2010 Altamont have teamed up with legendary illustrator Ralph Steadman for a collection of t-shirts . The series uses illustrations that Steadman created for MENTION_1 's novel MENTION_2 . The book is based around Steadman and Thompson 's trip to Hawaii in 1980 and in true Hunter S. fashion , it involves drugs , fishing and
# PROPN NUM PUNCT NUM PROPN VERB VERB PART ADP ADJ NOUN PROPN PROPN ADP DET NOUN ADP NOUN PUNCT NOUN PUNCT DET NOUN VERB NOUN ADJ PROPN VERB ADP MENTION_1 PART ADJ MENTION_2 PUNCT DET NOUN VERB VERB ADP PROPN CCONJ PROPN PART NOUN ADP PROPN ADP NUM CCONJ ADP ADJ PROPN PROPN NOUN PUNCT PRON VERB NOUN PUNCT VERB CCONJ
# edition of the Globe Magazine , dating back to 1937 ! Another intersting organic-feel type design work is the one done by Ralph Steadman to illustrate MENTION_1 ‘ s “ MENTION_2 “ . The series “ Things I learned in my life so far ” by Stefan Sagmeister ( an important figure in the world of graphic
# NOUN ADP DET PROPN PROPN PUNCT VERB ADV ADP NUM PUNCT DET VERB ADJ PUNCT NOUN NOUN NOUN NOUN VERB DET NUM VERB ADP PROPN PROPN PART VERB MENTION_1 PRON NOUN PUNCT MENTION_2 PUNCT PUNCT DET NOUN PUNCT NOUN PRON VERB ADP ADJ NOUN ADV ADV PUNCT ADP PROPN PROPN PUNCT DET ADJ NOUN ADP DET NOUN ADP NOUN
# , with a precursor in the League of the Rhine ) . Napoleon was its `` protector . '' On 6 August , following an ultimatum by Napoleon , MENTION_1 gave up his title of Emperor and declared the MENTION_2 dissolved . In the years that followed , 23 more German states joined the Confederation ; Francis 's Habsburg dynasty would rule the remainder of the empire as Austria .
# PUNCT ADP DET NOUN ADP DET PROPN ADP DET PROPN PUNCT PUNCT PROPN VERB ADJ PUNCT NOUN PUNCT PUNCT ADP NUM PROPN PUNCT VERB DET NOUN ADP PROPN PUNCT MENTION_1 VERB PART ADJ NOUN ADP PROPN CCONJ VERB DET MENTION_2 VERB PUNCT ADP DET NOUN ADJ VERB PUNCT NUM ADJ ADJ NOUN VERB DET PROPN PUNCT PROPN PART PROPN NOUN VERB VERB DET NOUN ADP DET NOUN ADP PROPN PUNCT
# way at an early age ... '' posted by s at 7.8.06 Sunday , August 6 , 2006 Franz II , Heiliger Römischer Kaiser In 1806 , 200 years ago , the MENTION_1 went out of existence as MENTION_2 abdicated . posted by s at 6.8.06 Nuke 'm till they glow , shoot 'em in the dark ... On Aug. 6 , 1945 , during World War II , the United
# NOUN ADP DET ADJ NOUN PUNCT PUNCT VERB ADP NOUN ADP PROPN PROPN PUNCT PROPN NUM PUNCT NUM PROPN PROPN PUNCT PROPN PROPN PROPN ADP NUM PUNCT NUM NOUN ADV PUNCT DET MENTION_1 VERB ADP ADP NOUN ADP MENTION_2 VERB PUNCT VERB ADP NOUN ADP NUM PROPN PUNCT NOUN ADP PRON VERB PUNCT VERB PRON ADP DET NOUN PUNCT ADP PROPN NUM PUNCT NUM PUNCT ADP PROPN PROPN PROPN PUNCT DET PROPN
# MOCA mural dispute , MOCA censorship of mural , protest mural in Los Angeles Monday , January 3 , 2011 Violent Tendancies I just finished watching ' MENTION_1 , ' the second of the MENTION_2 trilogy . The Millennium Trilogy is a sensation so you have probably heard something about the plot . The stories central character is Lisbeth Salander , a
# PROPN NOUN NOUN PUNCT PROPN NOUN ADP NOUN PUNCT NOUN NOUN ADP PROPN PROPN PROPN PUNCT PROPN NUM PUNCT NUM PROPN PROPN PRON ADV VERB VERB PUNCT MENTION_1 PUNCT PUNCT DET NOUN ADP DET MENTION_2 NOUN PUNCT DET PROPN PROPN VERB DET NOUN ADP PRON VERB ADV VERB NOUN ADP DET NOUN PUNCT DET NOUN ADJ NOUN VERB PROPN PROPN PUNCT DET
# read . A few months ago I read `` The Girl with the Dragon Tattoo `` and have been looking forward to reading the sequel , `` MENTION_1 `` , ( TGWPWF ) both by MENTION_2 . ( BTW ... read about the author . A very interesting life..an death ! ) Well I was not disappointed with the second book . Perhaps even better than the first ,
# VERB PUNCT DET ADJ NOUN ADV PRON VERB PUNCT DET PROPN ADP DET PROPN PROPN PUNCT CCONJ VERB VERB VERB ADV ADP VERB DET NOUN PUNCT PUNCT MENTION_1 PUNCT PUNCT PUNCT PROPN PUNCT CCONJ ADP MENTION_2 PUNCT PUNCT ADV PUNCT VERB ADP DET NOUN PUNCT DET ADV ADJ NOUN PUNCT DET NOUN PUNCT PUNCT INTJ PRON VERB ADV ADJ ADP DET ADJ NOUN PUNCT ADV ADV ADJ ADP DET ADJ PUNCT
# Comment » The Girl With the Dragon Tattoo Trilogy Posted on January 14 , 2011 by 7aki Fadi I read The girl with the Dragon Tattoo , MENTION_1 and The girl who kicked the hornets nest by MENTION_2 and thought they were OK. What interested me was the author more than the books themselves ; did you know that the author died back in
# PROPN PUNCT DET PROPN ADP DET PROPN PROPN PROPN VERB ADP PROPN NUM PUNCT NUM ADP PROPN PROPN PRON VERB DET NOUN ADP DET PROPN PROPN PUNCT MENTION_1 CCONJ DET NOUN NOUN VERB DET NOUN NOUN ADP MENTION_2 CCONJ VERB PRON VERB ADJ PUNCT NOUN VERB PRON VERB DET NOUN ADJ ADP DET NOUN PRON PUNCT VERB PRON VERB ADP DET NOUN VERB ADV ADP
# Reflections and Reviews Kitchen Notes Blogroll Monday , 14 June 2010 Ikea restaurant - cute but carnivorous I have recently finished reading the second novel in MENTION_1 's Millennium trilogy , MENTION_2 . It is set in Stockholm , a city of which I know nothing . The streets , the police force , the newspapers are all foreign to me
# NOUN CCONJ PROPN PROPN PROPN PROPN PROPN PUNCT NUM PROPN NUM PROPN NOUN PUNCT ADJ CCONJ ADJ PRON VERB ADV VERB VERB DET ADJ NOUN ADP MENTION_1 PART PROPN NOUN PUNCT MENTION_2 PUNCT PRON VERB VERB ADP PROPN PUNCT DET NOUN ADP ADJ PRON VERB NOUN PUNCT DET NOUN PUNCT DET NOUN NOUN PUNCT DET NOUN VERB ADV ADJ ADP PRON
# , a financial-crime mystery of sorts , on our Kindles . The book is part 1 of a 3 part series written by the late Swedish author MENTION_1 . Books 1 and 2 , MENTION_2 , are available on Kindle and for purchase in bookstores in the US . Book 3 , The Girl Who Kicked the Hornet ’ s Nest , is not
# PUNCT DET ADJ PUNCT NOUN NOUN ADP NOUN PUNCT ADP ADJ PROPN PUNCT DET NOUN VERB NOUN NUM ADP DET NUM NOUN NOUN VERB ADP DET ADJ ADJ NOUN MENTION_1 PUNCT NOUN NUM CCONJ NUM PUNCT MENTION_2 PUNCT VERB ADJ ADP PROPN CCONJ ADP NOUN ADP NOUN ADP DET PROPN PUNCT NOUN NUM PUNCT DET PROPN NOUN VERB DET NOUN PUNCT VERB PROPN PUNCT VERB ADV
# biscuits/cookies , blog events , chocolate Monday , 14 June 2010 Ikea restaurant - cute but carnivorous I have recently finished reading the second novel in MENTION_1 's Millennium trilogy , MENTION_2 . It is set in Stockholm , a city of which I know nothing . The streets , the police force , the newspapers are all foreign to me
# NOUN SYM NOUN PUNCT NOUN NOUN PUNCT NOUN PROPN PUNCT NUM PROPN NUM PROPN NOUN PUNCT ADJ CCONJ ADJ PRON VERB ADV VERB VERB DET ADJ NOUN ADP MENTION_1 PART PROPN NOUN PUNCT MENTION_2 PUNCT PRON VERB VERB ADP PROPN PUNCT DET NOUN ADP ADJ PRON VERB NOUN PUNCT DET NOUN PUNCT DET NOUN NOUN PUNCT DET NOUN VERB ADV ADJ ADP PRON
# the Classical and Romantic eras in Western classical music , and remains one of the most respected and influential composers of all time . Born in MENTION_1 , then in the MENTION_2 ( now in modern-day Germany ) , he moved to Vienna , Austria , in his early twenties and settled there , studying with Joseph Haydn and quickly
# DET ADJ CCONJ ADJ NOUN ADP ADJ ADJ NOUN PUNCT CCONJ VERB NUM ADP DET ADV ADJ CCONJ ADJ NOUN ADP DET NOUN PUNCT VERB ADP MENTION_1 PUNCT ADV ADP DET MENTION_2 PUNCT ADV ADP ADJ PUNCT NOUN PROPN PUNCT PUNCT PRON VERB ADP PROPN PUNCT PROPN PUNCT ADP ADJ ADJ NOUN CCONJ VERB ADV PUNCT VERB ADP PROPN PROPN CCONJ ADV
# the Classical and Romantic eras in Western classical music , and remains one of the most acclaimed and influential composers of all time . Born in MENTION_1 , of the MENTION_2 and a part of the Holy Roman Empire of the German Nation in present-day Germany , he moved to Vienna in his early twenties and settled
# DET ADJ CCONJ ADJ NOUN ADP ADJ ADJ NOUN PUNCT CCONJ VERB NUM ADP DET ADV ADJ CCONJ ADJ NOUN ADP DET NOUN PUNCT VERB ADP MENTION_1 PUNCT ADP DET MENTION_2 CCONJ DET NOUN ADP DET PROPN PROPN PROPN ADP DET ADJ NOUN ADP ADJ PUNCT NOUN PROPN PUNCT PRON VERB ADP PROPN ADP ADJ ADJ NOUN CCONJ VERB
# the Classical and Romantic eras in Western art music , he remains one of the most famous and influential composers of all time . Born in MENTION_1 , then the capital of the MENTION_2 and part of the Holy Roman Empire , Beethoven moved to Vienna in his early 20s , studying with Joseph Haydn and quickly gaining a reputation
# DET ADJ CCONJ ADJ NOUN ADP ADJ NOUN NOUN PUNCT PRON VERB NUM ADP DET ADV ADJ CCONJ ADJ NOUN ADP DET NOUN PUNCT VERB ADP MENTION_1 PUNCT ADV DET NOUN ADP DET MENTION_2 CCONJ NOUN ADP DET PROPN PROPN PROPN PUNCT PROPN VERB ADP PROPN ADP ADJ ADJ NOUN PUNCT VERB ADP PROPN PROPN CCONJ ADV VERB DET NOUN
# who wrote them down . Posted by Lahiru thilakarathna at 8:00 PM No comments : Email This BlogThis ! Share to Twitter Share to Facebook Beethoven Born in MENTION_1 , which was then capital of the MENTION_2 and a part of the Holy Roman Empire of the German Nation in present-day Germany , he moved to Vienna in his early twenties and
# NOUN VERB PRON PART PUNCT VERB ADP PROPN NOUN ADP NUM NOUN DET NOUN PUNCT NOUN DET PROPN PUNCT VERB ADP PROPN PROPN ADP PROPN PROPN VERB ADP MENTION_1 PUNCT ADJ VERB ADV NOUN ADP DET MENTION_2 CCONJ DET NOUN ADP DET PROPN PROPN PROPN ADP DET ADJ NOUN ADP ADJ PUNCT NOUN PROPN PUNCT PRON VERB ADP PROPN ADP ADJ ADJ NOUN CCONJ
# the Classical and Romantic eras in Western classical music , and remains one of the most respected and influential composers of all time . Born in MENTION_1 , then in the MENTION_2 ( now in modern-day Germany ) , he moved to Vienna in his early twenties and settled there , studying with Joseph Haydn and quickly gaining a reputation as
# DET ADJ CCONJ ADJ NOUN ADP ADJ ADJ NOUN PUNCT CCONJ VERB NUM ADP DET ADV ADJ CCONJ ADJ NOUN ADP DET NOUN PUNCT VERB ADP MENTION_1 PUNCT ADV ADP DET MENTION_2 PUNCT ADV ADP ADJ PUNCT NOUN PROPN PUNCT PUNCT PRON VERB ADP PROPN ADP ADJ ADJ NOUN CCONJ VERB ADV PUNCT VERB ADP PROPN PROPN CCONJ ADV VERB DET NOUN ADP
# the Classical and Romantic eras in Western classical music , and remains one of the most famous and influential composers of all time . Born in MENTION_1 , then the capital of the MENTION_2 and a part of the Holy Roman Empire of the German Nation in present-day Germany , he moved to Vienna in his early twenties and
# DET ADJ CCONJ ADJ NOUN ADP ADJ ADJ NOUN PUNCT CCONJ VERB NUM ADP DET ADV ADJ CCONJ ADJ NOUN ADP DET NOUN PUNCT VERB ADP MENTION_1 PUNCT ADV DET NOUN ADP DET MENTION_2 CCONJ DET NOUN ADP DET PROPN PROPN PROPN ADP DET ADJ NOUN ADP ADJ PUNCT NOUN PROPN PUNCT PRON VERB ADP PROPN ADP ADJ ADJ NOUN CCONJ
# and the 19th-century Herbert Spencer . [ 25 ] Lectures on History was well-received and was employed by many educational institutions , such as New College at Hackney , MENTION_1 , Princeton , Yale , and MENTION_2 . [ 26 ] Priestley designed two Charts to serve as visual study aides for his Lectures . [ 27 ] These charts are in fact timelines ; they have
# --------------------------------------------------------------------------
# KeyboardInterrupt                        Traceback (most recent call last)
# <ipython-input-184-eec19faacf89> in <module>()
#       1 # Transform dataset to features
# ----> 2 train_data_featurized = SelectContext(train_data, use_lemmas=False, use_tags=True)
#       3
#       4 # Transform labels to nimeric values
#       5 le = LabelEncoder()
#
# <ipython-input-183-39d04a2dd693> in SelectContext(data, use_lemmas, use_tags, verbose)
#      14                 instance_context.append(context)
#      15             if use_tags:
# ---> 16                 context = tag_tokens(s.left + " MENTION_1 " + s.middle + " MENTION_2 " + s.right)
#      17 #                 context = ' '.join((tag_tokens(s.left), "m1", tag_tokens(s.middle), "m2", tag_tokens(s.right)))
#      18                 instance_context.append(context)
#
# <ipython-input-182-cbcff2421a0b> in tag_tokens(ex)
#       2     print(ex)
#       3     tagged_ex = []
# ----> 4     doc = nlp(ex)
#       5
#       6     for w in doc:
#
# /Applications/anaconda3/lib/python3.7/site-packages/spacy/language.py in __call__(self, text, disable)
#     338             raise ValueError(Errors.E088.format(length=len(text),
#     339                                                 max_length=self.max_length))
# --> 340         doc = self.make_doc(text)
#     341         for name, proc in self.pipeline:
#     342             if name in disable:
#
# /Applications/anaconda3/lib/python3.7/site-packages/spacy/language.py in make_doc(self, text)
#     370
#     371     def make_doc(self, text):
# --> 372         return self.tokenizer(text)
#     373
#     374     def update(self, docs, golds, drop=0., sgd=None, losses=None):
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer.__call__()
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer._tokenize()
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer._attach_tokens()
#
# vocab.pyx in spacy.vocab.Vocab.get()
#
# vocab.pyx in spacy.vocab.Vocab._new_lexeme()
#
# /Applications/anaconda3/lib/python3.7/site-packages/spacy/lang/lex_attrs.py in like_url(text)
#      87     if text.startswith('http://') or text.startswith('https://'):
#      88         return True
# ---> 89     elif text.startswith('www.') and len(text) >= 5:
#      90         return True
#      91     if text[0] == '.' or text[-1] == '.':
#
# KeyboardInterrupt:

# %%
##################################################################################################
# 3. TRAIN CLASSIFIER AND EVALUATE (CV)
##################################################################################################

def print_statistics_header():
    print('{:20s} {:>10s} {:>10s} {:>10s} {:>10s}'.format(
        'relation', 'precision', 'recall', 'f-score', 'support'))
    print('{:20s} {:>10s} {:>10s} {:>10s} {:>10s}'.format(
        '-' * 18, '-' * 9, '-' * 9, '-' * 9, '-' * 9))

def print_statistics_row(rel, result):
    print('{:20s} {:10.3f} {:10.3f} {:10.3f} {:10d}'.format(rel, *result))

def print_statistics_footer(avg_result):
    print('{:20s} {:>10s} {:>10s} {:>10s} {:>10s}'.format(
        '-' * 18, '-' * 9, '-' * 9, '-' * 9, '-' * 9))
    print('{:20s} {:10.3f} {:10.3f} {:10.3f} {:10d}'.format('macro-average', *avg_result))

def macro_average_results(results):
    avg_result = [np.average([r[i] for r in results.values()]) for i in range(3)]
    avg_result.append(np.sum([r[3] for r in results.values()]))
    return avg_result

def average_results(results):
    avg_result = [np.average([r[i] for r in results]) for i in range(3)]
    avg_result.append(np.sum([r[3] for r in results]))
    return avg_result
    
def evaluateCV(classifier, label_encoder, X, y, verbose=True):
    results = {}
    for rel in le.classes_:
            results[rel] = []
    if verbose:
        print_statistics_header()
        kfold = StratifiedKFold(n_splits = 5, shuffle=True, random_state=0) 
        for train_index, test_index in kfold.split(X, y):
            #print("TRAIN:", train_index, "TEST:", test_index)
            X_train, X_test = [X[i] for i in train_index], [X[i] for i in test_index]
            y_train, y_test = [y[i] for i in train_index], [y[i] for i in test_index]
            clf.fit(X_train, y_train)
            pred_labels = classifier.predict(X_test)
            stats = precision_recall_fscore_support(y_test, pred_labels, beta=0.5)
            #print(stats)
            for rel in label_encoder.classes_:
                rel_id = label_encoder.transform([rel])[0]
            #print(rel_id,rel)
                stats_rel = [stat[rel_id] for stat in stats]
                results[rel].append(stats_rel)
        for rel in label_encoder.classes_:
            results[rel] = average_results(results[rel])
            if verbose:
                print_statistics_row(rel, results[rel])
    avg_result = macro_average_results(results)
    if verbose:
        print_statistics_footer(avg_result)
    return avg_result[2]  # return f_0.5 score as summary statistic

# %%
evaluateCV(clf,le,train_data_featurized,train_labels_featurized)
# Out:
# relation              precision     recall    f-score    support
# ------------------    ---------  ---------  ---------  ---------
# NO_REL                    0.662      0.717      0.672       2300
# author                    0.817      0.815      0.817       2653
# capital                   0.879      0.639      0.817        510
# has_spouse                0.859      0.903      0.868       3019
# worked_at                 0.732      0.609      0.703       1178
# ------------------    ---------  ---------  ---------  ---------
# macro-average             0.790      0.736      0.775       9660
# 0.7753647029950688

# %%
# A check for the average F1 score

f_scorer = make_scorer(fbeta_score, beta=0.5, average='macro')

def evaluateCV_check(classifier, X, y, verbose=True):
    kfold = StratifiedKFold(n_splits = 5, shuffle=True, random_state=0) 
    scores = cross_val_score(classifier, X, y, cv=kfold, scoring = f_scorer)
    print("\nCross-validation scores (StratifiedKFold): ", scores)
    print("Mean cv score (StratifiedKFold): ", scores.mean())

# %%
evaluateCV_check(clf,train_data_featurized,train_labels_featurized)

# %%
##################################################################################################
# 4. TEST PREDICTIONS and ANALYSIS
##################################################################################################

# Fit final model on the full train data
clf.fit(train_data_featurized, train_labels_featurized)

# Predict on test set
test_data, test_labels = load_data('../data/test-covered.json.txt', verbose=False)
print(len(test_labels))
test_data_featurized = SelectContext(test_data, verbose=False)
test_label_predicted = clf.predict(test_data_featurized)
print(len(test_label_predicted))
# Deprecation warning explained: https://stackoverflow.com/questions/49545947/sklearn-deprecationwarning-truth-value-of-an-array
test_label_predicted_decoded = le.inverse_transform(test_label_predicted)
print(len(test_label_predicted_decoded))
print(test_label_predicted_decoded[:2])
f = open("outputs/test_labels.txt", 'w', encoding="utf-8")
for label in test_label_predicted_decoded:
    f.write(label+'\n')

# %%
# Feature analisys - print N most informative
# !! Make changes in this function when you change the pipleine!!
def printNMostInformative(classifier,label_encoder,N):
    """Prints features with the highest coefficient values, per class"""
    feature_names = classifier.named_steps['countvectorizer'].get_feature_names()

    coef = classifier.named_steps['logisticregression'].coef_    
    print(coef.shape)
    for rel in label_encoder.classes_:
        rel_id = label_encoder.transform([rel])[0]
        coef_rel = coef[rel_id]
        coefs_with_fns = sorted(zip(coef_rel, feature_names))
        top_features = coefs_with_fns[-N:]
        print("\nClass {} best: ".format(rel))
        for feat in top_features:
            print(feat)        
        
print("Top features used to predict: ")
# show the top features
printNMostInformative(clf,le,2)
